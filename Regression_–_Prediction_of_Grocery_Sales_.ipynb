# %% [markdown]
# # **Regression – Prediction of Grocery Sales**
# - **Author:** Yvon Bilodeau
# - **Last updated:** August 2022
# ---

# %% [markdown]
# ## **Project Desciption**

# %% [markdown]
# ### **Overview**

# %% [markdown]
# The data scientists at BigMart have collected 2013 sales data for 1559 products across 10 stores in different cities. Also, certain attributes of each product and store have been defined. The aim is to build a predictive model and predict the sales of each product at a particular outlet.
#
# Using this model, BigMart will try to understand the properties of products and outlets which play a key role in increasing sales.

# %% [markdown]
# ### **Data Source**

# %% [markdown]
# The data was sourced from [analyticsvidhya.com](https://datahack.analyticsvidhya.com/contest/practice-problem-big-mart-sales-iii/)
#
# There are 8523 rows, and 12 columns.
# The rows represent 8523 observations, and the columns represent 11 features and 1 target variable.

# %% [markdown]
# ### **Data Dictionary**

# %% [markdown]
# - **Item_Identifier:** Unique product ID
# - **Item_Weight Weight:** of product
# - **Item_Fat_Content:** Whether the product is low fat or regular
# - **Item_Visibility:** The percentage of total display area of all products in store allocated to the particular product
# - **Item_Type:** The category to which the product belongs
# - **Item_MRP:** Maximum Retail Price (list price) of the product
# - **Outlet_Identifier:** Unique store ID
# - **Outlet_Establishment_Year:** The year in which store was established
# - **Outlet_Size:** The size of the store in terms of ground area covered
# - **Outlet_Location_Type:** The type of area in which the store is located
# - **Outlet_Type:** Whether the outlet is a grocery store or some sort of supermarket
# - **Item_Outlet_Sales:** Sales of the product in the particular store. This is the target variable to be predicted.

# %% [markdown]
# ## **Import Libraries | Load the Dataset**

# %% [markdown]
# ### **Import Libraries**

# %%
import numpy as np
import pandas as pd
from scipy import stats

import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter
import seaborn as sns

import missingno as msno

# Preprocessing
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split

# Dummy Regression
from sklearn.dummy import DummyRegressor
# Linear Regression
from sklearn.linear_model import LinearRegression
# Lasso Regression
from sklearn.linear_model import Lasso
# Ridge Regression
from sklearn.linear_model import Ridge
# Elastic Net Regression
from sklearn.linear_model import ElasticNet
# Decision Trees
from sklearn.tree import DecisionTreeRegressor
# Bagged Trees
from sklearn.ensemble import BaggingRegressor
# Suport Vector Regression
from sklearn.svm import LinearSVR
# K Neighbors Regression
from sklearn.neighbors import KNeighborsRegressor
# Random Forests
from sklearn.ensemble import RandomForestRegressor
# Gradient Boost
from sklearn.ensemble import GradientBoostingRegressor
# Light Gradient Boost
from lightgbm import LGBMRegressor
# XGBoost - eXtreme Gradient Boost
from xgboost import XGBRegressor

# Import GridSearch for Model Hypertuning
from sklearn.model_selection import GridSearchCV

# Regression Metrics
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# Set global scikit-learn configuration 
from sklearn import set_config
# Display estimators as a diagram in a Jupyter lab or notebook context
set_config(display=None) # {‘text’, ‘diagram’}, default=None

# Calculate the correlation/strength-of-association of features
# in a data-set with 
# ! pip install dython
from dython.nominal import associations

# %%
# Set display options
# Display all columns
pd.set_option('display.max_column', None)
# Display full width of field
pd.set_option('display.max_colwidth', None)
# Display table across entire available view
pd.set_option('display.width', -1)
# Display all rows
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### **Load the Dataset**

# %%
# Load the dataset
url = 'https://raw.githubusercontent.com/YBilodeau/Regression---Prediction-of-Grocery-Sales/main/Data/Grocery_Sales.csv'
df = pd.read_csv(url)

# %%
# Create versions of the dataset to prevent data leakage
eda_df = df.copy()
ml_df = df.copy()

# %% [markdown]
# ## **Inspect the Data**

# %% [markdown]
# ### **Display the Row and Column Count**

# %%
# Display the number of rows and columns for the dataframe
df.shape
print(f'There are {df.shape[0]} rows, and {df.shape[1]} columns.')
print(f'The rows represent {df.shape[0]} observations, and the columns represent {df.shape[1]-1} features and 1 target variable.')
# Out:
# There are 8523 rows, and 12 columns.
# The rows represent 8523 observations, and the columns represent 11 features and 1 target variable.

# %% [markdown]
# ### **Display Data Types**

# %%
# Display the column names and datatypes for each column
# Columns with mixed datatypes are identified as an object datatype
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %% [markdown]
# ### **Display Column Names, Count of Non-Null Values, and Data Types**

# %%
# Display the column names, count of non-null values, and their datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# ## **Clean the Data**

# %% [markdown]
# ### **Display First (5) Rows**

# %%
# Display the first (5) rows of the dataframe
df.head().style.format({ "Item_MRP":          "${:,.2f}",
                         "Item_Outlet_Sales": "${:,.2f}",
                         "Item_Visibility":    "{:.2%}",
                         "Item_Weight":        "{:.6}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_c7ba7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7ba7_level0_col0" class="col_heading level0 col0" >Item_Identifier</th>
#       <th id="T_c7ba7_level0_col1" class="col_heading level0 col1" >Item_Weight</th>
#       <th id="T_c7ba7_level0_col2" class="col_heading level0 col2" >Item_Fat_Content</th>
#       <th id="T_c7ba7_level0_col3" class="col_heading level0 col3" >Item_Visibility</th>
#       <th id="T_c7ba7_level0_col4" class="col_heading level0 col4" >Item_Type</th>
#       <th id="T_c7ba7_level0_col5" class="col_heading level0 col5" >Item_MRP</th>
#       <th id="T_c7ba7_level0_col6" class="col_heading level0 col6" >Outlet_Identifier</th>
#       <th id="T_c7ba7_level0_col7" class="col_heading level0 col7" >Outlet_Establishment_Year</th>
#       <th id="T_c7ba7_level0_col8" class="col_heading level0 col8" >Outlet_Size</th>
#       <th id="T_c7ba7_level0_col9" class="col_heading level0 col9" >Outlet_Location_Type</th>
#       <th id="T_c7ba7_level0_col10" class="col_heading level0 col10" >Outlet_Type</th>
#       <th id="T_c7ba7_level0_col11" class="col_heading level0 col11" >Item_Outlet_Sales</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7ba7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c7ba7_row0_col0" class="data row0 col0" >FDA15</td>
#       <td id="T_c7ba7_row0_col1" class="data row0 col1" >9.3</td>
#       <td id="T_c7ba7_row0_col2" class="data row0 col2" >Low Fat</td>
#       <td id="T_c7ba7_row0_col3" class="data row0 col3" >1.60%</td>
#       <td id="T_c7ba7_row0_col4" class="data row0 col4" >Dairy</td>
#       <td id="T_c7ba7_row0_col5" class="data row0 col5" >$249.81</td>
#       <td id="T_c7ba7_row0_col6" class="data row0 col6" >OUT049</td>
#       <td id="T_c7ba7_row0_col7" class="data row0 col7" >1999</td>
#       <td id="T_c7ba7_row0_col8" class="data row0 col8" >Medium</td>
#       <td id="T_c7ba7_row0_col9" class="data row0 col9" >Tier 1</td>
#       <td id="T_c7ba7_row0_col10" class="data row0 col10" >Supermarket Type1</td>
#       <td id="T_c7ba7_row0_col11" class="data row0 col11" >$3,735.14</td>
#     </tr>
#     <tr>
#       <th id="T_c7ba7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c7ba7_row1_col0" class="data row1 col0" >DRC01</td>
#       <td id="T_c7ba7_row1_col1" class="data row1 col1" >5.92</td>
#       <td id="T_c7ba7_row1_col2" class="data row1 col2" >Regular</td>
#       <td id="T_c7ba7_row1_col3" class="data row1 col3" >1.93%</td>
#       <td id="T_c7ba7_row1_col4" class="data row1 col4" >Soft Drinks</td>
#       <td id="T_c7ba7_row1_col5" class="data row1 col5" >$48.27</td>
#       <td id="T_c7ba7_row1_col6" class="data row1 col6" >OUT018</td>
#       <td id="T_c7ba7_row1_col7" class="data row1 col7" >2009</td>
#       <td id="T_c7ba7_row1_col8" class="data row1 col8" >Medium</td>
#       <td id="T_c7ba7_row1_col9" class="data row1 col9" >Tier 3</td>
#       <td id="T_c7ba7_row1_col10" class="data row1 col10" >Supermarket Type2</td>
#       <td id="T_c7ba7_row1_col11" class="data row1 col11" >$443.42</td>
#     </tr>
#     <tr>
#       <th id="T_c7ba7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c7ba7_row2_col0" class="data row2 col0" >FDN15</td>
#       <td id="T_c7ba7_row2_col1" class="data row2 col1" >17.5</td>
#       <td id="T_c7ba7_row2_col2" class="data row2 col2" >Low Fat</td>
#       <td id="T_c7ba7_row2_col3" class="data row2 col3" >1.68%</td>
#       <td id="T_c7ba7_row2_col4" class="data row2 col4" >Meat</td>
#       <td id="T_c7ba7_row2_col5" class="data row2 col5" >$141.62</td>
#       <td id="T_c7ba7_row2_col6" class="data row2 col6" >OUT049</td>
#       <td id="T_c7ba7_row2_col7" class="data row2 col7" >1999</td>
#       <td id="T_c7ba7_row2_col8" class="data row2 col8" >Medium</td>
#       <td id="T_c7ba7_row2_col9" class="data row2 col9" >Tier 1</td>
#       <td id="T_c7ba7_row2_col10" class="data row2 col10" >Supermarket Type1</td>
#       <td id="T_c7ba7_row2_col11" class="data row2 col11" >$2,097.27</td>
#     </tr>
#     <tr>
#       <th id="T_c7ba7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c7ba7_row3_col0" class="data row3 col0" >FDX07</td>
#       <td id="T_c7ba7_row3_col1" class="data row3 col1" >19.2</td>
#       <td id="T_c7ba7_row3_col2" class="data row3 col2" >Regular</td>
#       <td id="T_c7ba7_row3_col3" class="data row3 col3" >0.00%</td>
#       <td id="T_c7ba7_row3_col4" class="data row3 col4" >Fruits and Vegetables</td>
#       <td id="T_c7ba7_row3_col5" class="data row3 col5" >$182.09</td>
#       <td id="T_c7ba7_row3_col6" class="data row3 col6" >OUT010</td>
#       <td id="T_c7ba7_row3_col7" class="data row3 col7" >1998</td>
#       <td id="T_c7ba7_row3_col8" class="data row3 col8" >nan</td>
#       <td id="T_c7ba7_row3_col9" class="data row3 col9" >Tier 3</td>
#       <td id="T_c7ba7_row3_col10" class="data row3 col10" >Grocery Store</td>
#       <td id="T_c7ba7_row3_col11" class="data row3 col11" >$732.38</td>
#     </tr>
#     <tr>
#       <th id="T_c7ba7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c7ba7_row4_col0" class="data row4 col0" >NCD19</td>
#       <td id="T_c7ba7_row4_col1" class="data row4 col1" >8.93</td>
#       <td id="T_c7ba7_row4_col2" class="data row4 col2" >Low Fat</td>
#       <td id="T_c7ba7_row4_col3" class="data row4 col3" >0.00%</td>
#       <td id="T_c7ba7_row4_col4" class="data row4 col4" >Household</td>
#       <td id="T_c7ba7_row4_col5" class="data row4 col5" >$53.86</td>
#       <td id="T_c7ba7_row4_col6" class="data row4 col6" >OUT013</td>
#       <td id="T_c7ba7_row4_col7" class="data row4 col7" >1987</td>
#       <td id="T_c7ba7_row4_col8" class="data row4 col8" >High</td>
#       <td id="T_c7ba7_row4_col9" class="data row4 col9" >Tier 3</td>
#       <td id="T_c7ba7_row4_col10" class="data row4 col10" >Supermarket Type1</td>
#       <td id="T_c7ba7_row4_col11" class="data row4 col11" >$994.71</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# - The data appears to have loaded correctly.

# %% [markdown]
# ### **Display the Descriptive Statistics**

# %%
# Display the descriptive statistics for the numeric columns
df.describe()
# Out:
#        Item_Weight  \
# count  7060.000000
# mean     12.857645
# std       4.643456
# min       4.555000
# 25%       8.773750
# 50%      12.600000
# 75%      16.850000
# max      21.350000
#
#        Item_Visibility  \
# count      8523.000000
# mean          0.066132
# std           0.051598
# min           0.000000
# 25%           0.026989
# 50%           0.053931
# 75%           0.094585
# max           0.328391
#
#           Item_MRP  \
# count  8523.000000
# mean    140.992782
# std      62.275067
# min      31.290000
# 25%      93.826500
# 50%     143.012800
# 75%     185.643700
# max     266.888400
#
#        Outlet_Establishment_Year  \
# count                8523.000000
# mean                 1997.831867
# std                     8.371760
# min                  1985.000000
# 25%                  1987.000000
# 50%                  1999.000000
# 75%                  2004.000000
# max                  2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
# Display the descriptive statistics for the non-numeric columns
df.describe(exclude="number")
# Out:
#        Item_Identifier  \
# count             8523
# unique            1559
# top              FDW13
# freq                10
#
#        Item_Fat_Content  \
# count              8523
# unique                5
# top             Low Fat
# freq               5089
#
#                     Item_Type  \
# count                    8523
# unique                     16
# top     Fruits and Vegetables
# freq                     1232
#
#        Outlet_Identifier  \
# count               8523
# unique                10
# top               OUT027
# freq                 935
#
#        Outlet_Size  \
# count         6113
# unique           3
# top         Medium
# freq          2793
#
#        Outlet_Location_Type  \
# count                  8523
# unique                    3
# top                  Tier 3
# freq                   3350
#
#               Outlet_Type
# count                8523
# unique                  4
# top     Supermarket Type1
# freq                 5577

# %% [markdown]
# ### **Remove Unnecessary Columns**

# %% [markdown]
# #### **'Item_Identifier' column**

# %%
# Calculate the count of unique values and the cardinality for this column
unique_values = df.Item_Identifier.nunique()
cardinality = (unique_values/(df.shape[0])*100)
# Display the count of unique values and the cardinality for this column
print(f'This column has {unique_values} unique values which is {cardinality:,.0f}% cardinality.')
# Out:
# This column has 1559 unique values which is 18% cardinality.

# %% [markdown]
# - The high cardinality of this object column feature may adversely impact machine learning model prediction performance and processing times, as well as exagerate it's feature importance.
# - For EDA purposes, the eda-df may retain this feature.
# - For Machine Learning, the ml_df may drop this feature after analyzing it's impact, both with and without.

# %% [markdown]
# ### **Remove Unecessary Rows**

# %%
# Display the number of duplicate rows in the dataset
print(f'There are {df.duplicated().sum()} duplicate rows.')
# Out:
# There are 0 duplicate rows.

# %% [markdown]
# - No duplicates were found or dropped.

# %% [markdown]
# ### **Missing Values**

# %%
# Display missing values by column
msno.matrix(df, figsize=(16,3), labels=True, 
            fontsize=12, sort="descending", color=(0,0,0));

# %%
# Display the count of missing values by column
print(df.isna().sum())
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
# Display the percentage of missing values by column
print(df.isna().sum()/len(df)*100)
# Out:
# Item_Identifier               0.000000
# Item_Weight                  17.165317
# Item_Fat_Content              0.000000
# Item_Visibility               0.000000
# Item_Type                     0.000000
# Item_MRP                      0.000000
# Outlet_Identifier             0.000000
# Outlet_Establishment_Year     0.000000
# Outlet_Size                  28.276428
# Outlet_Location_Type          0.000000
# Outlet_Type                   0.000000
# Item_Outlet_Sales             0.000000
# dtype: float64

# %% [markdown]
# #### **'Item Weight' column**

# %% [markdown]
# - 'Item_Weight' has 1643 (17.16%) missing values.
# - All identical 'Item_Identifier's should have the same 'Item_Weight'. The missing values can be imputed from other 'Item_Identifier's that have the same value.
# - For EDA, the eda_df can apply this step now.
# - For Machine Learning, the ml_df will perform this step after the train_test_splt utilizing 'Item_Identifier's from the Train dataset only to prevent data leakage.

# %%
# Loop through index values of the dataframe
for ind in eda_df.index:
    # Create a filter to select the Item_Identifier corresponding to the index
    item_filter = eda_df['Item_Identifier'] == eda_df.loc[ind,'Item_Identifier']

    # Calculate the rounded value of the mean 'Item_Weight' of this rows 'Item_Identifier' 
    mean_item_weight = round(eda_df.loc[item_filter,'Item_Weight'].mean(), 3)

    # Assign mean_item_weight to the 'Item_Weight' column of this row
    eda_df.loc[ind,'Item_Weight'] = mean_item_weight
    
    #print(ind, df['Item_Identifier'][ind], df['Item_Weight'][ind], item_weight, "\n")

# %%
# Identify any remaining 'Item_Identifier's without 'Item_Weight' for the eda_df
print(eda_df.Item_Weight.isnull().sum())
eda_df[eda_df.Item_Weight.isnull()]
# Out:
# 4
#      Item_Identifier  \
# 927            FDN52
# 1922           FDK57
# 4187           FDE52
# 5022           FDQ60
#
#       Item_Weight  \
# 927           NaN
# 1922          NaN
# 4187          NaN
# 5022          NaN
#
#      Item_Fat_Content  \
# 927           Regular
# 1922          Low Fat
# 4187          Regular
# 5022          Regular
#
#       Item_Visibility  \
# 927          0.130933
# 1922         0.079904
# 4187         0.029742
# 5022         0.191501
#
#          Item_Type  \
# 927   Frozen Foods
# 1922   Snack Foods
# 4187         Dairy
# 5022  Baking Goods
#
#       Item_MRP  \
# 927    86.9198
# 1922  120.0440
# 4187   88.9514
# 5022  121.2098
#
#      Outlet_Identifier  \
# 927             OUT027
# 1922            OUT027
# 4187            OUT027
# 5022            OUT019
#
#       Outlet_Establishment_Year  \
# 927                        1985
# 1922                       1985
# 4187                       1985
# 5022                       1985
#
#      Outlet_Size  \
# 927       Medium
# 1922      Medium
# 4187      Medium
# 5022       Small
#
#      Outlet_Location_Type  \
# 927                Tier 3
# 1922               Tier 3
# 4187               Tier 3
# 5022               Tier 1
#
#             Outlet_Type  \
# 927   Supermarket Type3
# 1922  Supermarket Type3
# 4187  Supermarket Type3
# 5022      Grocery Store
#
#       Item_Outlet_Sales
# 927           1569.9564
# 1922          4434.2280
# 4187          3453.5046
# 5022           120.5098

# %% [markdown]
# - For EDA, the eda_df the remaining (4) values can be imputed from the median value of the column.
#
# - For Machine Learning, the ml_df the remaining (4) values can be imputed using SimpleImputer(strategy='median') during preprocessing, but after the train_test_split in order to avoid data leakage.

# %%
median_item_weight = eda_df['Item_Weight'].median()
eda_df['Item_Weight'].fillna(median_item_weight, inplace=True)

# %%
# Confirm there are no remaining 'Item_Identifier's without 'Item_Weight' for the eda_df
print(eda_df.Item_Weight.isnull().sum())
# Out:
# 0

# %% [markdown]
# #### **'Outlet_Size' column**
# - 'Outlet_Size' has 2410 missing values out of 8523 rows, which is significant (28%).

# %%
# Display the unique values for the column
print(df['Outlet_Size'].unique())
# Out:
# ['Medium' nan 'High' 'Small']

# %%
# Group the unique values by 'Outlet_Type' and 'Outlet_Location_Type'
df.groupby(['Outlet_Type','Outlet_Location_Type'])['Outlet_Size'].unique()
# Out:
# Outlet_Type        Outlet_Location_Type
# Grocery Store      Tier 1                          [Small]
#                    Tier 3                            [nan]
# Supermarket Type1  Tier 1                  [Medium, Small]
#                    Tier 2                     [nan, Small]
#                    Tier 3                           [High]
# Supermarket Type2  Tier 3                         [Medium]
# Supermarket Type3  Tier 3                         [Medium]
# Name: Outlet_Size, dtype: object

# %% [markdown]
# - It does not appear that we can impute 'Outlet_Size' from 'Outlet_Type' and/or 'Outlet_Location_Type'.
# - Missing values will be replaced with 'Unknown' for this Object Data Type.

# %%
# Replace missing values with 'Unknown'
df.Outlet_Size.fillna('Unknown',inplace=True)
eda_df.Outlet_Size.fillna('Unknown',inplace=True)
ml_df.Outlet_Size.fillna('Unknown',inplace=True)

# %%
# Confirm missing values have been replaced
print(df['Outlet_Size'].unique())
print(eda_df['Outlet_Size'].unique())
print(ml_df['Outlet_Size'].unique())
# Out:
# ['Medium' 'Unknown' 'High' 'Small']
# ['Medium' 'Unknown' 'High' 'Small']
# ['Medium' 'Unknown' 'High' 'Small']

# %% [markdown]
# ### **Inspect Column Datatypes for Errors**

# %% [markdown]
# Ensure all columns match the data types listed in the data dictionary.

# %%
 # Display column names and datatypes
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
# Display first (5) rows
df.head()
# Out:
#   Item_Identifier  \
# 0           FDA15
# 1           DRC01
# 2           FDN15
# 3           FDX07
# 4           NCD19
#
#    Item_Weight  \
# 0         9.30
# 1         5.92
# 2        17.50
# 3        19.20
# 4         8.93
#
#   Item_Fat_Content  \
# 0          Low Fat
# 1          Regular
# 2          Low Fat
# 3          Regular
# 4          Low Fat
#
#    Item_Visibility  \
# 0         0.016047
# 1         0.019278
# 2         0.016760
# 3         0.000000
# 4         0.000000
#
#                Item_Type  \
# 0                  Dairy
# 1            Soft Drinks
# 2                   Meat
# 3  Fruits and Vegetables
# 4              Household
#
#    Item_MRP  \
# 0  249.8092
# 1   48.2692
# 2  141.6180
# 3  182.0950
# 4   53.8614
#
#   Outlet_Identifier  \
# 0            OUT049
# 1            OUT018
# 2            OUT049
# 3            OUT010
# 4            OUT013
#
#    Outlet_Establishment_Year  \
# 0                       1999
# 1                       2009
# 2                       1999
# 3                       1998
# 4                       1987
#
#   Outlet_Size  \
# 0      Medium
# 1      Medium
# 2      Medium
# 3     Unknown
# 4        High
#
#   Outlet_Location_Type  \
# 0               Tier 1
# 1               Tier 3
# 2               Tier 1
# 3               Tier 3
# 4               Tier 3
#
#          Outlet_Type  \
# 0  Supermarket Type1
# 1  Supermarket Type2
# 2  Supermarket Type1
# 3      Grocery Store
# 4  Supermarket Type1
#
#    Item_Outlet_Sales
# 0          3735.1380
# 1           443.4228
# 2          2097.2700
# 3           732.3800
# 4           994.7052

# %% [markdown]
# - All columns match their datatypes.

# %% [markdown]
# ### **Inspect Column Names for Errors**

# %% [markdown]
# - Check for common syntax errors which may include extra white spaces at the beginning or end of strings or column names.
#
# - Check for typos or inconsistencies in strings that need to be fixed.(example: cat, Cat, cats)

# %%
# Display column names
df.columns
# Out:
# Index(['Item_Identifier',
#        'Item_Weight',
#        'Item_Fat_Content',
#        'Item_Visibility',
#        'Item_Type',
#        'Item_MRP',
#        'Outlet_Identifier',
#        'Outlet_Establishment_Year',
#        'Outlet_Size',
#        'Outlet_Location_Type',
#        'Outlet_Type',
#        'Item_Outlet_Sales'],
#       dtype='object')

# %% [markdown]
# - No issues with column names noted.

# %% [markdown]
# ### **Inspect Column Values for Errors**

# %% [markdown]
# #### **Object Datatypes**

# %% [markdown]
# - Check for common syntax errors which may include extra white spaces at the beginning or end of strings or column names.
#
# - Check for typos or inconsistencies in strings that need to be fixed.

# %%
# Display the descriptive statistics for the non-numeric columns
df.describe(exclude="number")
# Out:
#        Item_Identifier  \
# count             8523
# unique            1559
# top              FDW13
# freq                10
#
#        Item_Fat_Content  \
# count              8523
# unique                5
# top             Low Fat
# freq               5089
#
#                     Item_Type  \
# count                    8523
# unique                     16
# top     Fruits and Vegetables
# freq                     1232
#
#        Outlet_Identifier  \
# count               8523
# unique                10
# top               OUT027
# freq                 935
#
#        Outlet_Size  \
# count         8523
# unique           4
# top         Medium
# freq          2793
#
#        Outlet_Location_Type  \
# count                  8523
# unique                    3
# top                  Tier 3
# freq                   3350
#
#               Outlet_Type
# count                8523
# unique                  4
# top     Supermarket Type1
# freq                 5577

# %%
# Create a series of the datatypes
data_types = df.dtypes
# Create a filter to select only the object datatypes
object_data_types = data_types[(data_types == "object")]
# Display the series of object datatypes
object_data_types
# Out:
# Item_Identifier         object
# Item_Fat_Content        object
# Item_Type               object
# Outlet_Identifier       object
# Outlet_Size             object
# Outlet_Location_Type    object
# Outlet_Type             object
# dtype: object

# %% [markdown]
# ##### **'Item_Identifier' column**

# %%
# Display the unique values from the column
print(df['Item_Identifier'].unique())
# Out:
# ['FDA15' 'DRC01' 'FDN15' ... 'NCF55' 'NCW30' 'NCW05']

# %% [markdown]
# - This column has 1559 unique values, which is too many to
# display.

# %% [markdown]
# ##### **'Item_Fat_Content' column**

# %%
# Display the unique values from the column
print(df['Item_Fat_Content'].unique())
# Out:
# ['Low Fat' 'Regular' 'low fat' 'LF' 'reg']

# %%
df.groupby(['Item_Fat_Content'])['Item_Fat_Content'].count()
# Out:
# Item_Fat_Content
# LF          316
# Low Fat    5089
# Regular    2889
# low fat     112
# reg         117
# Name: Item_Fat_Content, dtype: int64

# %% [markdown]
# The values can be standardized to 'Low Fat' and 'Regular'.
# - Replace 'low fat' and 'LF' with 'Low Fat'.
# - Replace 'reg' with 'Regular'.

# %%
# Define a dictionary with key/value pairs
dict = {"low fat": 'Low Fat', "reg": 'Regular', "LF": 'Low Fat'}

# %%
 # Replace values using dictionary
eda_df.replace({'Item_Fat_Content': dict}, inplace = True)
ml_df.replace({'Item_Fat_Content': dict}, inplace = True)

# %%
# Display unique values to confirm they have been updated
print(eda_df['Item_Fat_Content'].unique())
print(ml_df['Item_Fat_Content'].unique())
# Out:
# ['Low Fat' 'Regular']
# ['Low Fat' 'Regular']

# %% [markdown]
# - Replacement values confirmed.

# %% [markdown]
# ##### **'Item_Type' column**

# %%
# Display the unique values from the column
print(df['Item_Type'].unique())
# Out:
# ['Dairy' 'Soft Drinks' 'Meat' 'Fruits and Vegetables' 'Household'
#  'Baking Goods' 'Snack Foods' 'Frozen Foods' 'Breakfast'
#  'Health and Hygiene' 'Hard Drinks' 'Canned' 'Breads' 'Starchy Foods'
#  'Others' 'Seafood']

# %%
df.groupby(['Item_Type'])['Item_Type'].count()
# Out:
# Item_Type
# Baking Goods              648
# Breads                    251
# Breakfast                 110
# Canned                    649
# Dairy                     682
# Frozen Foods              856
# Fruits and Vegetables    1232
# Hard Drinks               214
# Health and Hygiene        520
# Household                 910
# Meat                      425
# Others                    169
# Seafood                    64
# Snack Foods              1200
# Soft Drinks               445
# Starchy Foods             148
# Name: Item_Type, dtype: int64

# %% [markdown]
# - No issues noted.

# %% [markdown]
# ##### **'Outlet_Identifier' column**

# %%
# Display the unique values from the column
print(df['Outlet_Identifier'].unique())
# Out:
# ['OUT049' 'OUT018' 'OUT010' 'OUT013' 'OUT027' 'OUT045' 'OUT017' 'OUT046'
#  'OUT035' 'OUT019']

# %%
df.groupby(['Outlet_Identifier'])['Outlet_Identifier'].count()
# Out:
# Outlet_Identifier
# OUT010    555
# OUT013    932
# OUT017    926
# OUT018    928
# OUT019    528
# OUT027    935
# OUT035    930
# OUT045    929
# OUT046    930
# OUT049    930
# Name: Outlet_Identifier, dtype: int64

# %% [markdown]
# - No issues noted.

# %% [markdown]
# ##### **'Outlet_Size' column**

# %%
# Display the unique values from the column
print(df['Outlet_Size'].unique())
# Out:
# ['Medium' 'Unknown' 'High' 'Small']

# %%
df.groupby(['Outlet_Size'])['Outlet_Size'].count()
# Out:
# Outlet_Size
# High        932
# Medium     2793
# Small      2388
# Unknown    2410
# Name: Outlet_Size, dtype: int64

# %% [markdown]
# - No issues noted.

# %% [markdown]
# ##### **'Outlet_Location_Type' column**

# %%
# Display the unique values from the column
print(df['Outlet_Location_Type'].unique())
# Out:
# ['Tier 1' 'Tier 3' 'Tier 2']

# %%
df.groupby(['Outlet_Location_Type'])['Outlet_Location_Type'].count()
# Out:
# Outlet_Location_Type
# Tier 1    2388
# Tier 2    2785
# Tier 3    3350
# Name: Outlet_Location_Type, dtype: int64

# %% [markdown]
# - No issues noted.

# %% [markdown]
# ##### **'Outlet_Type' column**

# %%
# Display the unique values from the column
print(df['Outlet_Type'].unique())
# Out:
# ['Supermarket Type1' 'Supermarket Type2' 'Grocery Store'
#  'Supermarket Type3']

# %%
df.groupby(['Outlet_Type'])['Outlet_Type'].count()
# Out:
# Outlet_Type
# Grocery Store        1083
# Supermarket Type1    5577
# Supermarket Type2     928
# Supermarket Type3     935
# Name: Outlet_Type, dtype: int64

# %% [markdown]
# - No issues noted.

# %% [markdown]
# #### **Numerical Datatypes**

# %%
# Display the descriptive statistics for the numeric columns
df.describe().round(3)
# Out:
#        Item_Weight  \
# count     7060.000
# mean        12.858
# std          4.643
# min          4.555
# 25%          8.774
# 50%         12.600
# 75%         16.850
# max         21.350
#
#        Item_Visibility  \
# count         8523.000
# mean             0.066
# std              0.052
# min              0.000
# 25%              0.027
# 50%              0.054
# 75%              0.095
# max              0.328
#
#        Item_MRP  \
# count  8523.000
# mean    140.993
# std      62.275
# min      31.290
# 25%      93.826
# 50%     143.013
# 75%     185.644
# max     266.888
#
#        Outlet_Establishment_Year  \
# count                   8523.000
# mean                    1997.832
# std                        8.372
# min                     1985.000
# 25%                     1987.000
# 50%                     1999.000
# 75%                     2004.000
# max                     2009.000
#
#        Item_Outlet_Sales
# count           8523.000
# mean            2181.289
# std             1706.500
# min               33.290
# 25%              834.247
# 50%             1794.331
# 75%             3101.296
# max            13086.965

# %% [markdown]
# - **'Item_Weight'** -
# No unusual statistics were noted.
# - **'Item_Visibility'** -
# The percentage of total display area of all products in a store allocated to the particular product appears to have an extreme range. (Minimum value of 0.000 and a Maximum value of 0.328)
# - **'Item_MRP'** -
# No unusual statistics were noted.
# - **'Outlet_Establishment_Year'** -
# No unusual statistics were noted.
# - **'Item_Outlet_Sales'** -
# No unusual statistics were noted.

# %% [markdown]
# ## **Exploratory Data Analysis**

# %% [markdown]
# #### **Functions**

# %% [markdown]
# ##### **Statistics Function**

# %%
# Create a function to display supplemental statistics 
def column_statistics(df, column_name, max_unique_values_to_disply=20):
    # Display the count of missing values for this column
    print(f'Missing Values: {df[column_name].isna().sum()} ({round((df[column_name].isna().sum())/(df.shape[0])*100,1)})%')

    # Determine Outliers - Only if this is a numeric column
    if (df[column_name].dtype == 'int64') | (df[column_name].dtype == 'float64'):
        # Create outlier filters
        q1 = df[column_name].quantile(0.25) # 25th percentile
        q3 = df[column_name].quantile(0.75) # 75th percentile
        iqr = q3 - q1 # Interquartile range
        low_limit = q1 - (1.5 * iqr) # low limit
        high_limit = q3 + (1.5 * iqr) # high limit
        # Create outlier dataframes
        low_df = df[(df[column_name] < low_limit)]
        high_df = df[(df[column_name] > high_limit)]
        # Calculate the outlier counts and percentages
        low_oulier_count = low_df.shape[0]
        low_outlier_percentge = round(((low_oulier_count)/(df.shape[0])*100),1)
        high_oulier_count = high_df.shape[0]
        high_outlier_percentge = round(((high_oulier_count)/(df.shape[0])*100),1)
        # Display the outlier counts.
        print(f'Outliers: {low_oulier_count} ({low_outlier_percentge})% low, {high_oulier_count} ({high_outlier_percentge})% high')
        
    # Display the count of unique values for this column
    print(f'Unique values: {df[column_name].nunique()}')

    # Display the unique values including Nan and their counts for this column,
    # if the number of unique values is below the function parameter
    if df[column_name].nunique() < max_unique_values_to_disply:
        print(df[column_name].value_counts(dropna=False))

# %% [markdown]
# ##### **Function to Display Histogram**

# %%
# Create a function to create a Histogram
def hist_plot(df, column_name, unit_of_measure, bin_count):
    feature = df[column_name]
    mean = feature.mean()
    median = feature.median()

    fig, ax = plt.subplots(nrows=1, figsize=(8,4), facecolor='w')
    plt.title(column_name, fontsize = 22, weight='bold')
    
    sns.histplot(data=df, x=column_name, color='#069AF3', 
                 linewidth=2, bins=bin_count)
    
    plt.xlabel(unit_of_measure, fontsize = 16, weight='bold')
    plt.xticks(weight='bold')
    
    ax.set_ylabel('Instances',fontweight='bold',fontsize=14)
    
    ax.set_facecolor('lightblue')
    ax.tick_params(labelcolor='k', labelsize=10)
    # ax.set_yticklabels(ax.get_yticks(), weight='bold')
    
    for axis in ['top','bottom','left','right']:
        ax.spines[axis].set_linewidth(3)

    ax.axvline(mean, color = 'magenta', linewidth=2, label=f'Mean = {mean:,.2f}')
    ax.axvline(median, ls='dotted', color = 'darkmagenta',  linewidth=2, label=f'Median = {median:,.2f}')
    ax.legend();
    plt.tight_layout()
    plt.show;

# %% [markdown]
# ##### **Function to Display a KDE Plot**

# %%
# Create a function to create a KDE Plot
def kde_plot(df, column_name, unit_of_measure, bin_count):
    feature = df[column_name]
    mean = feature.mean()
    median = feature.median()

    fig, ax = plt.subplots(nrows=1, figsize=(8,4), facecolor='w')
    plt.title(column_name, fontsize = 22, weight='bold')
    sns.kdeplot(data=df, x=column_name, color='#069AF3', 
                 linewidth=2, fill=True)
    plt.xlabel(unit_of_measure, fontsize = 16, weight='bold')
    plt.xticks(weight='bold')
    ax.set_ylabel('Density',fontweight='bold',fontsize=14)
    ax.set_facecolor('lightblue')
    ax.tick_params(labelcolor='k', labelsize=10)
    #ax.set_yticklabels(ax.get_yticks(), weight='bold')
    for axis in ['top','bottom','left','right']:
        ax.spines[axis].set_linewidth(3)

    ax.axvline(mean, color = 'magenta', linewidth=2, label=f'Mean = {mean:,.2f}')
    ax.axvline(median, ls='dotted', color = 'darkmagenta',  linewidth=2, label=f'Median = {median:,.2f}')

    ax.legend()
    format = StrMethodFormatter('{x:.5f}') 
    ax.yaxis.set_major_formatter(format);
    plt.tight_layout()
    plt.show;

# %% [markdown]
# ##### **Function to Display a Boxplot**

# %%
# Create a function to create a Boxplot
def box_plot(df, column_name, unit_of_measure, fs=(8,4) ):
    fig, ax = plt.subplots(nrows=1, figsize=fs, facecolor='w')
    plt.title(column_name, fontsize = 22, weight='bold')
    sns.boxplot(data=df, x=column_name, width=.5, color='#069AF3', ax=ax,
                medianprops={'color':'k', 'linewidth':2},
                whiskerprops={'color':'k', 'linewidth':2},
                boxprops={'facecolor':'#069AF3', 
                          'edgecolor':'k', 'linewidth':2},
                capprops={'color':'k', 'linewidth':3},
                flierprops={'marker':'o', 'markersize':8, 
                            'markerfacecolor':'#069AF3', 
                            'markeredgecolor':'k'}); 
    plt.xlabel(unit_of_measure, fontsize = 16, weight='bold')
    plt.xticks(weight='bold')
    ax.set_facecolor('lightblue')
    ax.tick_params(labelcolor='k', labelsize=10)
    #ax.set_yticklabels(ax.get_yticks(), weight='bold')
    for axis in ['top','bottom','left','right']:
        ax.spines[axis].set_linewidth(3)

    plt.tight_layout()
    plt.show;

# %% [markdown]
# ##### **Function to Display Countplot**

# %%
# Create a function to create a Count Plot
def count_plot(df, column_name, label_order, rot=0, fs=(8,4), hza='center'):
    fig, ax = plt.subplots(nrows=1, figsize=fs, facecolor='w')
    plt.title(column_name, fontsize = 22, weight='bold')
    
    sns.countplot(data=df, x=column_name, lw=3, ec='k', 
                  color='#069AF3', order=label_order)
    plt.xlabel('')
    plt.xticks(weight='bold', rotation=rot, ha=hza)
    
    ax.set_ylabel('Instances', fontweight='bold', fontsize=18)
    
    ax.set_facecolor('lightblue')
    ax.tick_params(labelcolor='k', labelsize=12)
    
    #ax.set_yticklabels(ax.get_yticks(), weight='bold')
    
    for axis in ['top','bottom','left','right']:
        ax.spines[axis].set_linewidth(3)
        
    plt.tight_layout()
    plt.show;

# %% [markdown]
# ##### **Function to Display Scatter Plot**

# %%
# Create a function to create a Scatter Plot
def scatter_plot(df, x, y, tit_lab='', x_lab='', y_lab=''):
    palette_dict = {0: 'indigo' , 1: 'magenta'}
    fig, ax = plt.subplots(figsize=(8,4), facecolor='w');
    sns.scatterplot(x=df[x], y=df[y]);
    # Regression Line
    m, b, *_ = stats.linregress(df[x], df[y])
    #ax.plt(xy1=(0,b), slope=m, label=f'$y = {m:.1f}x  {b:+.f}$')
    # Labels
    plt.title(tit_lab, fontsize = 22, weight='bold')
    plt.xlabel(x_lab, fontsize = 14, weight='bold')
    plt.ylabel(y_lab, fontsize = 14, weight='bold');
    # Ticks
    plt.xticks(fontsize = 10, weight='bold')
    plt.yticks(fontsize = 10, weight='bold');
    # Face 
    ax.set_facecolor('lightblue')
    # Axes
    for axis in ['top','bottom','left','right']:
        ax.spines[axis].set_linewidth(3)
    #plt.legend(bbox_to_anchor=(1.23, 1))

    plt.tight_layout()
    plt.show;

# %% [markdown]
# ##### **Function to Display Reg Plot**

# %%
# Create a function to create a Reg Plot
def reg_plot(df, x, y, tit_lab='', x_lab='', y_lab=''):
    palette_dict = {0: 'indigo' , 1: 'magenta'}
    fig, ax = plt.subplots(figsize=(8,4), facecolor='w');
    sns.scatterplot(x=df[x], y=df[y]);
    sns.regplot(data=df, x=x,y=y,
                line_kws={'color':'black'},
                scatter_kws={'s':1}); 
    # Regression Line
    m, b, *_ = stats.linregress(df[x], df[y])
    #ax.plt(xy1=(0,b), slope=m, label=f'$y = {m:.1f}x  {b:+.f}$')
    # Labels
    plt.title(tit_lab, fontsize = 22, weight='bold')
    plt.xlabel(x_lab, fontsize = 14, weight='bold')
    plt.ylabel(y_lab, fontsize = 14, weight='bold');
    # Ticks
    plt.xticks(fontsize = 10, weight='bold')
    plt.yticks(fontsize = 10, weight='bold');
    # Face 
    ax.set_facecolor('lightblue')
    # Axes
    for axis in ['top','bottom','left','right']:
        ax.spines[axis].set_linewidth(3)
    #plt.legend(bbox_to_anchor=(1.23, 1))

    plt.tight_layout()
    plt.show;

# %% [markdown]
# ##### **Function to Display Skew**

# %%
# Creates a function to determine skew
def skew_function(df, column_name):
    feature = df[column_name]
    mean = feature.mean()
    median = feature.median()
    if median < mean:
        print('This feature is positively skewed.')
    else:
        print('This feature is negatively skewed.')

# %% [markdown]
# ##### **Function to Display Kurtosis**

# %%
# Creates a function to determine kurtosis
def kurtosis_function(df, column_name):
    kurt = stats.kurtosis(df[column_name], fisher = False)
    if kurt > 3:
        print(f'This feature is Leptokurtic, because it has kurtosis value of {kurt}')
        if kurt < 3.5:
             print(f'Though we could say it is Mesokurtic, as the value is close to 3.')       
    elif kurt < 3:
        print(f'This feature is Platykurtic, because it has kurtosis value of {kurt}.')
        if kurt > 2.5:
             print(f'Though we could say it is Mesokurtic, as the value is close to 3.')       
    else:
        print(f'This feature is Mesokurtic, because it has kurtosis value of {kurt}.')

# %%
# Creates a function to determine the number of outliers based on z-score
def outlier_function(df, column_name):
    outliers = np.abs(stats.zscore(df[column_name])) > 3
    print(f'This feature has {outliers.sum()} outliers.')

# %% [markdown]
# ##### **Function to Describe Distribution**

# %%
# Determine if this feature has skew, and if so, which direction (+/-)
# Determine the kurtosis of the feature; Mesokurtic, Leptokurtic, or Platykurtic
# Determine the number of outliers for this feature based on zscore
def dist_desc(df, column_name):
    skew_function(df, column_name)
    kurtosis_function(df, column_name)
    outlier_function(df, column_name)

# %% [markdown]
# ### **Categorical Columns**

# %% [markdown]
# #### **Summary Statistics**

# %%
# Display the descriptive statistics for the non-numeric columns
eda_df.describe(exclude=('number'))
# Out:
#        Item_Identifier  \
# count             8523
# unique            1559
# top              FDW13
# freq                10
#
#        Item_Fat_Content  \
# count              8523
# unique                2
# top             Low Fat
# freq               5517
#
#                     Item_Type  \
# count                    8523
# unique                     16
# top     Fruits and Vegetables
# freq                     1232
#
#        Outlet_Identifier  \
# count               8523
# unique                10
# top               OUT027
# freq                 935
#
#        Outlet_Size  \
# count         8523
# unique           4
# top         Medium
# freq          2793
#
#        Outlet_Location_Type  \
# count                  8523
# unique                    3
# top                  Tier 3
# freq                   3350
#
#               Outlet_Type
# count                8523
# unique                  4
# top     Supermarket Type1
# freq                 5577

# %% [markdown]
# #### **'Item_Identifier' column**

# %%
# Display column statistics
eda_df.Item_Identifier.describe()
# Out:
# count      8523
# unique     1559
# top       FDW13
# freq         10
# Name: Item_Identifier, dtype: object

# %%
# Display supplemental column statistics
column_statistics(eda_df, 'Item_Identifier')
# Out:
# Missing Values: 0 (0.0)%
# Unique values: 1559

# %%
# Display normailzed value counts
eda_df['Item_Identifier'].value_counts(normalize=True)
# Out:
# FDW13    0.001173
# FDG33    0.001173
# NCY18    0.001056
# FDD38    0.001056
# DRE49    0.001056
# FDV60    0.001056
# NCQ06    0.001056
# FDF52    0.001056
# FDX04    0.001056
# NCJ30    0.001056
# FDV38    0.001056
# NCF42    0.001056
# FDT07    0.001056
# FDW26    0.001056
# NCL31    0.001056
# FDU12    0.001056
# FDG09    0.001056
# FDQ40    0.001056
# FDX20    0.001056
# NCI54    0.001056
# FDX31    0.001056
# FDP25    0.001056
# FDW49    0.001056
# FDF56    0.001056
# FDO19    0.001056
# DRN47    0.001056
# NCB18    0.001056
# FDE11    0.000939
# NCX05    0.000939
# FDQ39    0.000939
# FDT55    0.000939
# FDO32    0.000939
# FDT40    0.000939
# FDZ20    0.000939
# FDH27    0.000939
# FDY49    0.000939
# FDS33    0.000939
# FDR04    0.000939
# FDR43    0.000939
# FDR59    0.000939
# FDJ55    0.000939
# FDT24    0.000939
# FDY55    0.000939
# FDV09    0.000939
# FDU23    0.000939
# FDY47    0.000939
# DRD25    0.000939
# FDK58    0.000939
# FDL58    0.000939
# FDX58    0.000939
# FDR44    0.000939
# FDP28    0.000939
# FDA39    0.000939
# FDH28    0.000939
# DRF27    0.000939
# FDX21    0.000939
# FDY56    0.000939
# FDF05    0.000939
# FDL20    0.000939
# FDY03    0.000939
# NCK05    0.000939
# FDS55    0.000939
# DRA59    0.000939
# FDG24    0.000939
# NCE54    0.000939
# FDZ21    0.000939
# FDA04    0.000939
# FDW24    0.000939
# FDT49    0.000939
# DRF23    0.000939
# FDD05    0.000939
# FDH10    0.000939
# FDX50    0.000939
# FDT32    0.000939
# FDK20    0.000939
# FDU13    0.000939
# FDN56    0.000939
# FDZ26    0.000939
# FDL34    0.000939
# DRF01    0.000939
# FDG38    0.000939
# NCE31    0.000939
# NCL53    0.000939
# NCB31    0.000939
# NCQ05    0.000939
# FDT21    0.000939
# NCV06    0.000939
# DRJ24    0.000939
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64

# %%
# Display normailzed value counts
eda_df['Item_Type'].value_counts(normalize=True)
# Out:
# Fruits and Vegetables    0.144550
# Snack Foods              0.140795
# Household                0.106770
# Frozen Foods             0.100434
# Dairy                    0.080019
# Canned                   0.076147
# Baking Goods             0.076030
# Health and Hygiene       0.061011
# Soft Drinks              0.052212
# Meat                     0.049865
# Breads                   0.029450
# Hard Drinks              0.025109
# Others                   0.019829
# Starchy Foods            0.017365
# Breakfast                0.012906
# Seafood                  0.007509
# Name: Item_Type, dtype: float64

# %%
categories = ['Fruits and Vegetables', 'Snack Foods','Household', 'Frozen Foods',
              'Dairy','Canned', 'Baking Goods', 'Health and Hygiene',
              'Soft Drinks', 'Meat', 'Breads', 'Hard Drinks', 'Others',
              'Starchy Foods', 'Breakfast', 'Seafood']

# Utilize function to display count plot
count_plot(eda_df, 'Item_Type', categories, rot=45, fs=(14,6), hza='right')

# %% [markdown]
# #### **'Outlet Establishment Year' column**

# %%
# Display column statistics
eda_df['Outlet_Establishment_Year'].describe()
# Out:
# count    8523.000000
# mean     1997.831867
# std         8.371760
# min      1985.000000
# 25%      1987.000000
# 50%      1999.000000
# 75%      2004.000000
# max      2009.000000
# Name: Outlet_Establishment_Year, dtype: float64

# %%
# Display supplemental column statistics
column_statistics(eda_df, 'Outlet_Establishment_Year')
# Out:
# Missing Values: 0 (0.0)%
# Outliers: 0 (0.0)% low, 0 (0.0)% high
# Unique values: 9
# 1985    1463
# 1987     932
# 1999     930
# 1997     930
# 2004     930
# 2002     929
# 2009     928
# 2007     926
# 1998     555
# Name: Outlet_Establishment_Year, dtype: int64

# %%
# Display normailzed value counts
eda_df['Outlet_Establishment_Year'].value_counts(normalize=True)
# Out:
# 1985    0.171653
# 1987    0.109351
# 1999    0.109117
# 1997    0.109117
# 2004    0.109117
# 2002    0.108999
# 2009    0.108882
# 2007    0.108647
# 1998    0.065118
# Name: Outlet_Establishment_Year, dtype: float64

# %%
# Utilize function to display count plot
categories = [1985, 1987, 1997, 1999, 2002, 2004, 2007, 2009]
count_plot(eda_df, 'Outlet_Establishment_Year', categories)

# %% [markdown]
# #### **'Outlet_Size' column**

# %%
# Display column statistics
eda_df['Outlet_Size'].describe()
# Out:
# count       8523
# unique         4
# top       Medium
# freq        2793
# Name: Outlet_Size, dtype: object

# %%
# Display supplemental column statistics
column_statistics(eda_df, 'Outlet_Size')
# Out:
# Missing Values: 0 (0.0)%
# Unique values: 4
# Medium     2793
# Unknown    2410
# Small      2388
# High        932
# Name: Outlet_Size, dtype: int64

# %%
# Display normailzed value counts
eda_df['Outlet_Size'].value_counts(normalize=True)
# Out:
# Medium     0.327702
# Unknown    0.282764
# Small      0.280183
# High       0.109351
# Name: Outlet_Size, dtype: float64

# %%
# Utilize function to display count plot
categories = ['Small', 'Medium', 'High', 'Unknown']
count_plot(eda_df, 'Outlet_Size', categories)

# %% [markdown]
# #### **'Outlet_Location_Type' column**

# %%
# Display column statistics
eda_df['Outlet_Location_Type'].describe()
# Out:
# count       8523
# unique         3
# top       Tier 3
# freq        3350
# Name: Outlet_Location_Type, dtype: object

# %%
# Display supplemental column statistics
column_statistics(eda_df, 'Outlet_Location_Type')
# Out:
# Missing Values: 0 (0.0)%
# Unique values: 3
# Tier 3    3350
# Tier 2    2785
# Tier 1    2388
# Name: Outlet_Location_Type, dtype: int64

# %%
# Display normailzed value counts
eda_df['Outlet_Location_Type'].value_counts(normalize=True)
# Out:
# Tier 3    0.393054
# Tier 2    0.326763
# Tier 1    0.280183
# Name: Outlet_Location_Type, dtype: float64

# %%
# Utilize function to display count plot
categories = ['Tier 1', 'Tier 2', 'Tier 3']
count_plot(eda_df, 'Outlet_Location_Type', categories)

# %% [markdown]
# #### **'Outlet_Type' column**

# %%
# Display column statistics
eda_df['Outlet_Type'].describe()
# Out:
# count                  8523
# unique                    4
# top       Supermarket Type1
# freq                   5577
# Name: Outlet_Type, dtype: object

# %%
# Display supplemental column statistics
column_statistics(eda_df, 'Outlet_Type')
# Out:
# Missing Values: 0 (0.0)%
# Unique values: 4
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: Outlet_Type, dtype: int64

# %%
# Display normailzed value counts
eda_df['Outlet_Type'].value_counts(normalize=True)
# Out:
# Supermarket Type1    0.654347
# Grocery Store        0.127068
# Supermarket Type3    0.109703
# Supermarket Type2    0.108882
# Name: Outlet_Type, dtype: float64

# %%
eda_df['Outlet_Type'].unique()
# Out:
# array(['Supermarket Type1', 'Supermarket Type2', 'Grocery Store',
#        'Supermarket Type3'], dtype=object)

# %%
# Utilize function to display count plot
categories = ['Supermarket Type1', 'Supermarket Type2', 'Supermarket Type3', 'Grocery Store']
count_plot(eda_df, 'Outlet_Type', categories, rot=45, hza='right')

# %% [markdown]
# ### **Numerical Columns**

# %% [markdown]
# #### **Summary Statistics**

# %%
# Display the descriptive statistics for the numeric columns
eda_df.describe()
# Out:
#        Item_Weight  \
# count  8523.000000
# mean     12.875314
# std       4.645010
# min       4.555000
# 25%       8.785000
# 50%      12.650000
# 75%      16.850000
# max      21.350000
#
#        Item_Visibility  \
# count      8523.000000
# mean          0.066132
# std           0.051598
# min           0.000000
# 25%           0.026989
# 50%           0.053931
# 75%           0.094585
# max           0.328391
#
#           Item_MRP  \
# count  8523.000000
# mean    140.992782
# std      62.275067
# min      31.290000
# 25%      93.826500
# 50%     143.012800
# 75%     185.643700
# max     266.888400
#
#        Outlet_Establishment_Year  \
# count                8523.000000
# mean                 1997.831867
# std                     8.371760
# min                  1985.000000
# 25%                  1987.000000
# 50%                  1999.000000
# 75%                  2004.000000
# max                  2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %% [markdown]
# #### **'Item_Weight' column**

# %% [markdown]
# **Statistics**

# %%
# Display column statistics
eda_df.Item_Weight.describe()
# Out:
# count    8523.000000
# mean       12.875314
# std         4.645010
# min         4.555000
# 25%         8.785000
# 50%        12.650000
# 75%        16.850000
# max        21.350000
# Name: Item_Weight, dtype: float64

# %%
# Display supplemental column statistics
column_statistics(eda_df, 'Item_Weight')
# Out:
# Missing Values: 0 (0.0)%
# Outliers: 0 (0.0)% low, 0 (0.0)% high
# Unique values: 415

# %% [markdown]
# **Plots**

# %%
# Utilize function to display histogram plot
hist_plot(eda_df, 'Item_Weight', 'Item Weight (Pounds)', 'auto')

# %%
# Utilize function to display a KDE plot
kde_plot(eda_df, 'Item_Weight', 'Item Weight (Pounds)', 'auto')

# %%
# Utilize function to display histogram plot
box_plot(eda_df, 'Item_Weight', 'Item Weight (Pounds)')

# %%
reg_plot(eda_df, 'Item_Weight', 'Item_Outlet_Sales', tit_lab='Correlation', 
         x_lab='Item Weight (Pounds)', y_lab='Item Outlet Sales (dollars)')

# %% [markdown]
# **Distribution Description**

# %% [markdown]
# - This feature has a continuous distribution.

# %%
# Determine if this feature has skew, and if so, which direction (+/-)
# Determine the kurtosis of the feature; Mesokurtic, Leptokurtic, or Platykurtic
# Determine the number of outliers for this feature based on zscore
dist_desc(df, 'Item_Weight')
# Out:
# This feature is positively skewed.
# This feature is Mesokurtic, because it has kurtosis value of nan.
# This feature has 0 outliers.

# %% [markdown]
# #### **'Item_Visibility' column**

# %% [markdown]
# **Statistics**

# %%
# Display column statistics
eda_df.Item_Visibility.describe()
# Out:
# count    8523.000000
# mean        0.066132
# std         0.051598
# min         0.000000
# 25%         0.026989
# 50%         0.053931
# 75%         0.094585
# max         0.328391
# Name: Item_Visibility, dtype: float64

# %%
# Display supplemental column statistics
column_statistics(eda_df, 'Item_Visibility')
# Out:
# Missing Values: 0 (0.0)%
# Outliers: 0 (0.0)% low, 144 (1.7)% high
# Unique values: 7880

# %% [markdown]
# **Plots**

# %%
# Utilize function to display histogram plot
hist_plot(eda_df, 'Item_Visibility', 'Percentage of display area', 'auto')

# %%
# Utilize function to display a KDE plot
kde_plot(eda_df, 'Item_Visibility', 'Percentage of display area', 'auto')

# %%
# Utilize function to display histogram plot
box_plot(eda_df, 'Item_Visibility', 'Percentage of display area')

# %%
# Utilize function to display regplot 
reg_plot(eda_df, 'Item_Visibility', 'Item_Outlet_Sales', tit_lab='Correlation', 
         x_lab='Item_Visibility (Percentage of display area)', y_lab='Item Outlet Sales (dollars)')

# %% [markdown]
# **Distribution Description**

# %% [markdown]
# - This feature has a continuous distribution.

# %%
# Determine if this feature has skew, and if so, which direction (+/-)
# Determine the kurtosis of the feature; Mesokurtic, Leptokurtic, or Platykurtic
# Determine the number of outliers for this feature based on zscore
dist_desc(df, 'Item_Visibility')
# Out:
# This feature is positively skewed.
# This feature is Leptokurtic, because it has kurtosis value of 4.677756506385917
# This feature has 95 outliers.

# %% [markdown]
# - For EDA, outliers do not need to be removed.
# - For Machine Learning, outliers may be removed from the ml_df to determine if it will improve model performance.

# %% [markdown]
# #### **'Item_MRP' column**

# %% [markdown]
# **Statistics**

# %%
# Display column statistics
eda_df.Item_MRP.describe()
# Out:
# count    8523.000000
# mean      140.992782
# std        62.275067
# min        31.290000
# 25%        93.826500
# 50%       143.012800
# 75%       185.643700
# max       266.888400
# Name: Item_MRP, dtype: float64

# %%
# Display supplemental column statistics
column_statistics(eda_df, 'Item_MRP')
# Out:
# Missing Values: 0 (0.0)%
# Outliers: 0 (0.0)% low, 0 (0.0)% high
# Unique values: 5938

# %% [markdown]
# **Plots**

# %%
# Utilize function to display histogram plot
hist_plot(eda_df, 'Item_MRP', 'Dollars', 'auto')

# %%
# Utilize function to display a KDE plot
kde_plot(eda_df, 'Item_MRP', 'Dollars', 'auto')

# %%
# Utilize function to display histogram plot
box_plot(eda_df, 'Item_MRP', 'Dollars')

# %%
reg_plot(eda_df, 'Item_MRP', 'Item_Outlet_Sales', tit_lab='Correlation', 
         x_lab='Item MRP (dollars)', y_lab='Item Outlet Sales (dollars)')

# %% [markdown]
# **Distribution Description**

# %% [markdown]
# - This feature has a continuous distribution.

# %%
# Determine if this feature has skew, and if so, which direction (+/-)
# Determine the kurtosis of the feature; Mesokurtic, Leptokurtic, or Platykurtic
# Determine the number of outliers for this feature based on zscore
dist_desc(df, 'Item_MRP')
# Out:
# This feature is negatively skewed.
# This feature is Platykurtic, because it has kurtosis value of 2.1100489068493395.
# This feature has 0 outliers.

# %% [markdown]
# #### **'Item_Outlet_Sales' column**

# %% [markdown]
# **Statistics**

# %%
# Display column statistics
eda_df.Item_Outlet_Sales.describe()
# Out:
# count     8523.000000
# mean      2181.288914
# std       1706.499616
# min         33.290000
# 25%        834.247400
# 50%       1794.331000
# 75%       3101.296400
# max      13086.964800
# Name: Item_Outlet_Sales, dtype: float64

# %%
# Display supplemental column statistics
column_statistics(eda_df, 'Item_Outlet_Sales')
# Out:
# Missing Values: 0 (0.0)%
# Outliers: 0 (0.0)% low, 186 (2.2)% high
# Unique values: 3493

# %% [markdown]
# **Plots**

# %%
# Utilize function to display histogram plot
hist_plot(eda_df, 'Item_Outlet_Sales', 'Dollars', 'auto')

# %%
# Utilize function to display a KDE plot
kde_plot(eda_df, 'Item_Outlet_Sales', 'Dollars', 'auto')

# %%
# Utilize function to display histogram plot
box_plot(eda_df, 'Item_Outlet_Sales', 'Dollars')

# %% [markdown]
# **Distribution Description**

# %% [markdown]
# - This feature has a continuous distribution.

# %%
# Determine if this feature has skew, and if so, which direction (+/-)
# Determine the kurtosis of the feature; Mesokurtic, Leptokurtic, or Platykurtic
# Determine the number of outliers for this feature based on zscore
dist_desc(df, 'Item_Outlet_Sales')
# Out:
# This feature is positively skewed.
# This feature is Leptokurtic, because it has kurtosis value of 4.614224991590342
# This feature has 90 outliers.

# %% [markdown]
# - This column is our target column, outliers will not be removed.

# %% [markdown]
# ### **Feature Correlation**

# %%
# Plot Correlation Heatmap
plt.figure(figsize = (8,8),facecolor='w')
corr = eda_df.corr().abs()
mask = np.triu(np.ones_like(corr))
sns.heatmap(corr,square=True, cmap='viridis', annot=True, mask=mask);
plt.title('Correlation Heatmap', fontsize = 16, weight='bold')
plt.xticks(fontsize = 12, weight='bold', rotation=90)
plt.yticks(fontsize = 12, weight='bold', rotation=0);
plt.tight_layout()
plt.show;

# %%
# Calculate the correlation/strength-of-association of features in data-set with 
# both categorical and continuous features using:
# - Pearson's R for continuous-continuous cases
# - Correlation Ratio for categorical-continuous cases 
# - Cramer's V or Theil's U for categorical-categorical cases
associations(eda_df, figsize=(10,10), cmap='viridis', display_columns='Item_Outlet_Sales', hide_rows='Item_Outlet_Sales')
# Out:
# {'corr':                            Item_Outlet_Sales
#  Item_Identifier                     0.653482
#  Item_Weight                         0.013162
#  Item_Fat_Content                    0.018719
#  Item_Visibility                    -0.128625
#  Item_Type                           0.068843
#  Item_MRP                            0.567574
#  Outlet_Identifier                   0.490755
#  Outlet_Establishment_Year          -0.049135
#  Outlet_Size                         0.219439
#  Outlet_Location_Type                0.111828
#  Outlet_Type                         0.489464,
#  'ax': <AxesSubplot:>}

# %%
# Create a list of column names in descending order of
# correlation to the target 'Item_Outlet_Sales'
ml_df_columns = ['Item_Identifier',
                 'Item_MRP',
                 'Outlet_Identifier',
                 'Outlet_Type',
                 'Outlet_Size',
                 'Item_Visibility',
                 'Outlet_Location_Type',
                 'Item_Type',
                 'Item_Weight',
                 'Outlet_Establishment_Year',
                 'Item_Fat_Content']

# %% [markdown]
# ## **Preprocessing for Machine Learning**

# %% [markdown]
# ### **Validation Split**

# %%
# Define features (X) and target (y)
X = ml_df.drop(columns = ['Item_Outlet_Sales'])
y = ml_df['Item_Outlet_Sales']

# %%
# Split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %% [markdown]
# ### **Missing Value Imputation**

# %%
# Loop through index values of the dataframe
for ind in X_train.index:
    # Create a filter to select the Item_Identifier corresponding to the index
    item_filter = X_train['Item_Identifier'] == X_train.loc[ind,'Item_Identifier']

    # Calculate the rounded value of the mean 'Item_Weight' 
    # of this rows 'Item_Identifier' 
    mean_item_weight = round(X_train.loc[item_filter,'Item_Weight'].mean(), 3)

    # Assign mean_item_weight to the 'Item_Weight' column of this row
    X_train.loc[ind,'Item_Weight'] = mean_item_weight

# %%
# Identify any remaining 'Item_Identifier's without 'Item_Weight' for the eda_df
print(X_train.Item_Weight.isnull().sum())
X_train[X_train.Item_Weight.isnull()].head()
# Out:
# 20
#      Item_Identifier  \
# 7387           NCT53
# 4663           FDT47
# 5639           FDZ02
# 8201           FDO03
# 446            FDS09
#
#       Item_Weight  \
# 7387          NaN
# 4663          NaN
# 5639          NaN
# 8201          NaN
# 446           NaN
#
#      Item_Fat_Content  \
# 7387          Low Fat
# 4663          Regular
# 5639          Regular
# 8201          Regular
# 446           Regular
#
#       Item_Visibility  \
# 7387         0.084245
# 4663         0.024390
# 5639         0.037963
# 8201         0.036704
# 446          0.141975
#
#                Item_Type  \
# 7387  Health and Hygiene
# 4663              Breads
# 5639               Dairy
# 8201                Meat
# 446          Snack Foods
#
#       Item_MRP  \
# 7387  164.6526
# 4663   95.9068
# 5639   97.5726
# 8201  228.1352
# 446    49.6008
#
#      Outlet_Identifier  \
# 7387            OUT019
# 4663            OUT027
# 5639            OUT027
# 8201            OUT027
# 446             OUT019
#
#       Outlet_Establishment_Year  \
# 7387                       1985
# 4663                       1985
# 5639                       1985
# 8201                       1985
# 446                        1985
#
#      Outlet_Size  \
# 7387       Small
# 4663      Medium
# 5639      Medium
# 8201      Medium
# 446        Small
#
#      Outlet_Location_Type  \
# 7387               Tier 1
# 4663               Tier 3
# 5639               Tier 3
# 8201               Tier 3
# 446                Tier 1
#
#             Outlet_Type
# 7387      Grocery Store
# 4663  Supermarket Type3
# 5639  Supermarket Type3
# 8201  Supermarket Type3
# 446       Grocery Store

# %%
# Loop through index values of the dataframe
for ind in X_test.index:
    # Create a filter to select the Item_Identifier corresponding to the index
    item_filter = X_train['Item_Identifier'] == X_test.loc[ind,'Item_Identifier']

    # Calculate the rounded value of the mean 'Item_Weight' 
    # of this rows 'Item_Identifier' 
    mean_item_weight = round(X_train.loc[item_filter,'Item_Weight'].mean(), 3)

    # Assign mean_item_weight to the 'Item_Weight' column of this row
    X_test.loc[ind,'Item_Weight'] = mean_item_weight

# %%
# Identify any remaining 'Item_Identifier's without 'Item_Weight'
print(X_test.Item_Weight.isnull().sum())
X_test[X_test.Item_Weight.isnull()].head()
# Out:
# 57
#      Item_Identifier  \
# 7652           FDS09
# 5840           FDG12
# 6186           FDC28
# 7643           FDZ31
# 2321           FDA11
#
#       Item_Weight  \
# 7652          NaN
# 5840          NaN
# 6186          NaN
# 7643          NaN
# 2321          NaN
#
#      Item_Fat_Content  \
# 7652          Regular
# 5840          Regular
# 6186          Low Fat
# 7643          Regular
# 2321          Low Fat
#
#       Item_Visibility  \
# 7652         0.081253
# 5840         0.006352
# 6186         0.054721
# 7643         0.113678
# 2321         0.043327
#
#                   Item_Type  \
# 7652            Snack Foods
# 5840           Baking Goods
# 6186           Frozen Foods
# 7643  Fruits and Vegetables
# 2321           Baking Goods
#
#       Item_MRP  \
# 7652   49.8008
# 5840  120.3098
# 6186  107.8254
# 7643  189.7504
# 2321   95.6436
#
#      Outlet_Identifier  \
# 7652            OUT045
# 5840            OUT018
# 6186            OUT027
# 7643            OUT018
# 2321            OUT045
#
#       Outlet_Establishment_Year  \
# 7652                       2002
# 5840                       2009
# 6186                       1985
# 7643                       2009
# 2321                       2002
#
#      Outlet_Size  \
# 7652     Unknown
# 5840      Medium
# 6186      Medium
# 7643      Medium
# 2321     Unknown
#
#      Outlet_Location_Type  \
# 7652               Tier 2
# 5840               Tier 3
# 6186               Tier 3
# 7643               Tier 3
# 2321               Tier 2
#
#             Outlet_Type
# 7652  Supermarket Type1
# 5840  Supermarket Type2
# 6186  Supermarket Type3
# 7643  Supermarket Type2
# 2321  Supermarket Type1

# %% [markdown]
# - These remaining missing values will be imputed in the pipeline using SimpleImputer(strategy='median')

# %% [markdown]
# ### **Instantiate Column Selectors**

# %%
# Selectors
cat_selector = make_column_selector(dtype_include='object')
num_selector = make_column_selector(dtype_include='number')

# %%
# Display categorical column names
cat_selector(X_train)
# Out:
# ['Item_Identifier',
#  'Item_Fat_Content',
#  'Item_Type',
#  'Outlet_Identifier',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type']

# %%
# Display numerical column names
num_selector(X_train)
# Out:
# ['Item_Weight', 'Item_Visibility', 'Item_MRP', 'Outlet_Establishment_Year']

# %% [markdown]
# ### **Instantiate Transformers**

# %%
# Imputers
freq_imputer = SimpleImputer(strategy='most_frequent')
median_imputer = SimpleImputer(strategy='median')
# Scaler
scaler = StandardScaler()
# One Hot Encoder
ohe = OneHotEncoder(handle_unknown='ignore', sparse=False)

# %% [markdown]
# ### **Instantiate Pipelines**

# %%
# Numeric pipeline
numeric_pipe = make_pipeline(median_imputer, scaler)
numeric_pipe
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='median')),
#                 ('standardscaler', StandardScaler())])

# %%
# Numeric pipeline without scaling
# This will reduce processing time for -
# Tree based models do not require scaling
numeric_no_scaler_pipe = make_pipeline(median_imputer)
numeric_no_scaler_pipe
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='median'))])

# %%
# Categorical pipeline
categorical_pipe = make_pipeline(freq_imputer, ohe)
categorical_pipe
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='most_frequent')),
#                 ('onehotencoder',
#                  OneHotEncoder(handle_unknown='ignore', sparse=False))])

# %% [markdown]
# ### **Instantiate ColumnTransformer**

# %%
# Tuples for Column Transformer
number_tuple = (numeric_pipe, num_selector)
number_no_scaling_tuple = (numeric_no_scaler_pipe, num_selector)
category_tuple = (categorical_pipe, cat_selector)

# %%
# ColumnTransformer
preprocessor = make_column_transformer(number_tuple, 
                                       category_tuple, 
                                       remainder='passthrough')
preprocessor
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('pipeline-1',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x000001B2C8018BE0>),
#                                 ('pipeline-2',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x000001B2C7F96250>)])

# %%
# ColumnTransformer without scaling
no_scaling_preprocessor = make_column_transformer(number_no_scaling_tuple, 
                                                  category_tuple, 
                                                  remainder='passthrough')
no_scaling_preprocessor
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('pipeline-1',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='median'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x000001B2C8018BE0>),
#                                 ('pipeline-2',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x000001B2C7F96250>)])

# %% [markdown]
# ### **Fit and Transform Data**

# %%
# Fit on Train
preprocessor.fit(X_train)
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('pipeline-1',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x000001B2C8018BE0>),
#                                 ('pipeline-2',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x000001B2C7F96250>)])

# %%
# Transform Train and Test
X_train_processed = preprocessor.transform(X_train)
X_test_processed = preprocessor.transform(X_test)

# %%
# Get out the column transformer steps
preprocessor.named_transformers_
# Out:
# {'pipeline-1': Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='median')),
#                  ('standardscaler', StandardScaler())]),
#  'pipeline-2': Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='most_frequent')),
#                  ('onehotencoder',
#                   OneHotEncoder(handle_unknown='ignore', sparse=False))])}

# %%
# Reference the pipeline that has the one hot encoder
cat_pipe = preprocessor.named_transformers_['pipeline-2']

# %%
# Display the feature names out from the one hot encoder
cat_pipe.named_steps['onehotencoder'].get_feature_names_out(cat_selector(X_train))
# Out:
# array(['Item_Identifier_DRA12', 'Item_Identifier_DRA24',
#        'Item_Identifier_DRA59', ..., 'Outlet_Type_Supermarket Type1',
#        'Outlet_Type_Supermarket Type2', 'Outlet_Type_Supermarket Type3'],
#       dtype=object)

# %%
# Extract the feature names from one hot encoder
cat_feature_names = preprocessor.named_transformers_['pipeline-2']\
                            .named_steps['onehotencoder']\
                            .get_feature_names_out(cat_selector(X_train))
cat_feature_names
# Out:
# array(['Item_Identifier_DRA12', 'Item_Identifier_DRA24',
#        'Item_Identifier_DRA59', ..., 'Outlet_Type_Supermarket Type1',
#        'Outlet_Type_Supermarket Type2', 'Outlet_Type_Supermarket Type3'],
#       dtype=object)

# %%
# get final col names which are num features + cat features
final_cols = num_selector(X_train) + list(cat_feature_names)
final_cols
# Out:
# ['Item_Weight',
#  'Item_Visibility',
#  'Item_MRP',
#  'Outlet_Establishment_Year',
#  'Item_Identifier_DRA12',
#  'Item_Identifier_DRA24',
#  'Item_Identifier_DRA59',
#  'Item_Identifier_DRB01',
#  'Item_Identifier_DRB13',
#  'Item_Identifier_DRB24',
#  'Item_Identifier_DRB25',
#  'Item_Identifier_DRB48',
#  'Item_Identifier_DRC01',
#  'Item_Identifier_DRC12',
#  'Item_Identifier_DRC13',
#  'Item_Identifier_DRC25',
#  'Item_Identifier_DRC27',
#  'Item_Identifier_DRC36',
#  'Item_Identifier_DRC49',
#  'Item_Identifier_DRD01',
#  'Item_Identifier_DRD12',
#  'Item_Identifier_DRD13',
#  'Item_Identifier_DRD15',
#  'Item_Identifier_DRD24',
#  'Item_Identifier_DRD25',
#  'Item_Identifier_DRD27',
#  'Item_Identifier_DRD37',
#  'Item_Identifier_DRD49',
#  'Item_Identifier_DRD60',
#  'Item_Identifier_DRE01',
#  'Item_Identifier_DRE03',
#  'Item_Identifier_DRE12',
#  'Item_Identifier_DRE13',
#  'Item_Identifier_DRE15',
#  'Item_Identifier_DRE25',
#  'Item_Identifier_DRE27',
#  'Item_Identifier_DRE37',
#  'Item_Identifier_DRE48',
#  'Item_Identifier_DRE49',
#  'Item_Identifier_DRE60',
#  'Item_Identifier_DRF01',
#  'Item_Identifier_DRF03',
#  'Item_Identifier_DRF13',
#  'Item_Identifier_DRF15',
#  'Item_Identifier_DRF23',
#  'Item_Identifier_DRF25',
#  'Item_Identifier_DRF27',
#  'Item_Identifier_DRF36',
#  'Item_Identifier_DRF37',
#  'Item_Identifier_DRF48',
#  'Item_Identifier_DRF49',
#  'Item_Identifier_DRF51',
#  'Item_Identifier_DRF60',
#  'Item_Identifier_DRG01',
#  'Item_Identifier_DRG03',
#  'Item_Identifier_DRG11',
#  'Item_Identifier_DRG13',
#  'Item_Identifier_DRG15',
#  'Item_Identifier_DRG23',
#  'Item_Identifier_DRG25',
#  'Item_Identifier_DRG27',
#  'Item_Identifier_DRG36',
#  'Item_Identifier_DRG37',
#  'Item_Identifier_DRG39',
#  'Item_Identifier_DRG48',
#  'Item_Identifier_DRG49',
#  'Item_Identifier_DRG51',
#  'Item_Identifier_DRH01',
#  'Item_Identifier_DRH03',
#  'Item_Identifier_DRH11',
#  'Item_Identifier_DRH13',
#  'Item_Identifier_DRH15',
#  'Item_Identifier_DRH23',
#  'Item_Identifier_DRH25',
#  'Item_Identifier_DRH36',
#  'Item_Identifier_DRH37',
#  'Item_Identifier_DRH39',
#  'Item_Identifier_DRH49',
#  'Item_Identifier_DRH51',
#  'Item_Identifier_DRH59',
#  'Item_Identifier_DRI01',
#  'Item_Identifier_DRI03',
#  'Item_Identifier_DRI11',
#  'Item_Identifier_DRI13',
#  'Item_Identifier_DRI23',
#  'Item_Identifier_DRI25',
#  'Item_Identifier_DRI37',
#  'Item_Identifier_DRI39',
#  'Item_Identifier_DRI47',
#  'Item_Identifier_DRI49',
#  'Item_Identifier_DRI51',
#  'Item_Identifier_DRI59',
#  'Item_Identifier_DRJ01',
#  'Item_Identifier_DRJ11',
#  'Item_Identifier_DRJ13',
#  'Item_Identifier_DRJ23',
#  'Item_Identifier_DRJ24',
#  'Item_Identifier_DRJ25',
#  'Item_Identifier_DRJ35',
#  'Item_Identifier_DRJ37',
#  'Item_Identifier_DRJ39',
#  'Item_Identifier_DRJ47',
#  'Item_Identifier_DRJ49',
#  'Item_Identifier_DRJ51',
#  'Item_Identifier_DRJ59',
#  'Item_Identifier_DRK01',
#  'Item_Identifier_DRK11',
#  'Item_Identifier_DRK12',
#  'Item_Identifier_DRK13',
#  'Item_Identifier_DRK23',
#  'Item_Identifier_DRK35',
#  'Item_Identifier_DRK37',
#  'Item_Identifier_DRK39',
#  'Item_Identifier_DRK47',
#  'Item_Identifier_DRK49',
#  'Item_Identifier_DRK59',
#  'Item_Identifier_DRL01',
#  'Item_Identifier_DRL11',
#  'Item_Identifier_DRL23',
#  'Item_Identifier_DRL35',
#  'Item_Identifier_DRL37',
#  'Item_Identifier_DRL47',
#  'Item_Identifier_DRL49',
#  'Item_Identifier_DRL59',
#  'Item_Identifier_DRL60',
#  'Item_Identifier_DRM11',
#  'Item_Identifier_DRM23',
#  'Item_Identifier_DRM35',
#  'Item_Identifier_DRM37',
#  'Item_Identifier_DRM47',
#  'Item_Identifier_DRM48',
#  'Item_Identifier_DRM49',
#  'Item_Identifier_DRM59',
#  'Item_Identifier_DRN11',
#  'Item_Identifier_DRN35',
#  'Item_Identifier_DRN36',
#  'Item_Identifier_DRN37',
#  'Item_Identifier_DRN47',
#  'Item_Identifier_DRN59',
#  'Item_Identifier_DRO35',
#  'Item_Identifier_DRO47',
#  'Item_Identifier_DRO59',
#  'Item_Identifier_DRP35',
#  'Item_Identifier_DRP47',
#  'Item_Identifier_DRQ35',
#  'Item_Identifier_DRY23',
#  'Item_Identifier_DRZ11',
#  'Item_Identifier_DRZ24',
#  'Item_Identifier_FDA01',
#  'Item_Identifier_FDA02',
#  'Item_Identifier_FDA03',
#  'Item_Identifier_FDA04',
#  'Item_Identifier_FDA07',
#  'Item_Identifier_FDA08',
#  'Item_Identifier_FDA09',
#  'Item_Identifier_FDA10',
#  'Item_Identifier_FDA11',
#  'Item_Identifier_FDA13',
#  'Item_Identifier_FDA14',
#  'Item_Identifier_FDA15',
#  'Item_Identifier_FDA16',
#  'Item_Identifier_FDA19',
#  'Item_Identifier_FDA20',
#  'Item_Identifier_FDA21',
#  'Item_Identifier_FDA22',
#  'Item_Identifier_FDA23',
#  'Item_Identifier_FDA25',
#  'Item_Identifier_FDA26',
#  'Item_Identifier_FDA27',
#  'Item_Identifier_FDA28',
#  'Item_Identifier_FDA31',
#  'Item_Identifier_FDA32',
#  'Item_Identifier_FDA33',
#  'Item_Identifier_FDA34',
#  'Item_Identifier_FDA35',
#  'Item_Identifier_FDA36',
#  'Item_Identifier_FDA37',
#  'Item_Identifier_FDA38',
#  'Item_Identifier_FDA39',
#  'Item_Identifier_FDA40',
#  'Item_Identifier_FDA43',
#  'Item_Identifier_FDA44',
#  'Item_Identifier_FDA45',
#  'Item_Identifier_FDA46',
#  'Item_Identifier_FDA47',
#  'Item_Identifier_FDA48',
#  'Item_Identifier_FDA49',
#  'Item_Identifier_FDA50',
#  'Item_Identifier_FDA51',
#  'Item_Identifier_FDA52',
#  'Item_Identifier_FDA55',
#  'Item_Identifier_FDA56',
#  'Item_Identifier_FDA57',
#  'Item_Identifier_FDA58',
#  'Item_Identifier_FDB02',
#  'Item_Identifier_FDB03',
#  'Item_Identifier_FDB04',
#  'Item_Identifier_FDB05',
#  'Item_Identifier_FDB08',
#  'Item_Identifier_FDB09',
#  'Item_Identifier_FDB10',
#  'Item_Identifier_FDB11',
#  'Item_Identifier_FDB12',
#  'Item_Identifier_FDB14',
#  'Item_Identifier_FDB15',
#  'Item_Identifier_FDB16',
#  'Item_Identifier_FDB17',
#  'Item_Identifier_FDB20',
#  'Item_Identifier_FDB21',
#  'Item_Identifier_FDB22',
#  'Item_Identifier_FDB23',
#  'Item_Identifier_FDB26',
#  'Item_Identifier_FDB27',
#  'Item_Identifier_FDB28',
#  'Item_Identifier_FDB29',
#  'Item_Identifier_FDB32',
#  'Item_Identifier_FDB33',
#  'Item_Identifier_FDB34',
#  'Item_Identifier_FDB35',
#  'Item_Identifier_FDB36',
#  'Item_Identifier_FDB37',
#  'Item_Identifier_FDB38',
#  'Item_Identifier_FDB39',
#  'Item_Identifier_FDB40',
#  'Item_Identifier_FDB41',
#  'Item_Identifier_FDB44',
#  'Item_Identifier_FDB45',
#  'Item_Identifier_FDB46',
#  'Item_Identifier_FDB47',
#  'Item_Identifier_FDB49',
#  'Item_Identifier_FDB50',
#  'Item_Identifier_FDB51',
#  'Item_Identifier_FDB52',
#  'Item_Identifier_FDB53',
#  'Item_Identifier_FDB56',
#  'Item_Identifier_FDB57',
#  'Item_Identifier_FDB58',
#  'Item_Identifier_FDB59',
#  'Item_Identifier_FDB60',
#  'Item_Identifier_FDC02',
#  'Item_Identifier_FDC03',
#  'Item_Identifier_FDC04',
#  'Item_Identifier_FDC05',
#  'Item_Identifier_FDC08',
#  'Item_Identifier_FDC09',
#  'Item_Identifier_FDC10',
#  'Item_Identifier_FDC11',
#  'Item_Identifier_FDC14',
#  'Item_Identifier_FDC15',
#  'Item_Identifier_FDC16',
#  'Item_Identifier_FDC17',
#  'Item_Identifier_FDC20',
#  'Item_Identifier_FDC21',
#  'Item_Identifier_FDC22',
#  'Item_Identifier_FDC26',
#  'Item_Identifier_FDC29',
#  'Item_Identifier_FDC32',
#  'Item_Identifier_FDC33',
#  'Item_Identifier_FDC34',
#  'Item_Identifier_FDC35',
#  'Item_Identifier_FDC37',
#  'Item_Identifier_FDC38',
#  'Item_Identifier_FDC39',
#  'Item_Identifier_FDC40',
#  'Item_Identifier_FDC41',
#  'Item_Identifier_FDC44',
#  'Item_Identifier_FDC45',
#  'Item_Identifier_FDC46',
#  'Item_Identifier_FDC47',
#  'Item_Identifier_FDC48',
#  'Item_Identifier_FDC50',
#  'Item_Identifier_FDC51',
#  'Item_Identifier_FDC52',
#  'Item_Identifier_FDC53',
#  'Item_Identifier_FDC56',
#  'Item_Identifier_FDC57',
#  'Item_Identifier_FDC58',
#  'Item_Identifier_FDC59',
#  'Item_Identifier_FDC60',
#  'Item_Identifier_FDD02',
#  'Item_Identifier_FDD03',
#  'Item_Identifier_FDD04',
#  'Item_Identifier_FDD05',
#  'Item_Identifier_FDD08',
#  'Item_Identifier_FDD09',
#  'Item_Identifier_FDD10',
#  'Item_Identifier_FDD11',
#  'Item_Identifier_FDD14',
#  'Item_Identifier_FDD16',
#  'Item_Identifier_FDD17',
#  'Item_Identifier_FDD20',
#  'Item_Identifier_FDD21',
#  'Item_Identifier_FDD22',
#  'Item_Identifier_FDD23',
#  'Item_Identifier_FDD26',
#  'Item_Identifier_FDD28',
#  'Item_Identifier_FDD29',
#  'Item_Identifier_FDD32',
#  'Item_Identifier_FDD33',
#  'Item_Identifier_FDD34',
#  'Item_Identifier_FDD35',
#  'Item_Identifier_FDD36',
#  'Item_Identifier_FDD38',
#  'Item_Identifier_FDD39',
#  'Item_Identifier_FDD40',
#  'Item_Identifier_FDD41',
#  'Item_Identifier_FDD44',
#  'Item_Identifier_FDD45',
#  'Item_Identifier_FDD46',
#  'Item_Identifier_FDD47',
#  'Item_Identifier_FDD48',
#  'Item_Identifier_FDD50',
#  'Item_Identifier_FDD51',
#  'Item_Identifier_FDD52',
#  'Item_Identifier_FDD53',
#  'Item_Identifier_FDD56',
#  'Item_Identifier_FDD57',
#  'Item_Identifier_FDD58',
#  'Item_Identifier_FDD59',
#  'Item_Identifier_FDE02',
#  'Item_Identifier_FDE04',
#  'Item_Identifier_FDE05',
#  'Item_Identifier_FDE08',
#  'Item_Identifier_FDE09',
#  'Item_Identifier_FDE10',
#  'Item_Identifier_FDE11',
#  'Item_Identifier_FDE14',
#  'Item_Identifier_FDE16',
#  'Item_Identifier_FDE17',
#  'Item_Identifier_FDE20',
#  'Item_Identifier_FDE21',
#  'Item_Identifier_FDE22',
#  'Item_Identifier_FDE23',
#  'Item_Identifier_FDE24',
#  'Item_Identifier_FDE26',
#  'Item_Identifier_FDE28',
#  'Item_Identifier_FDE29',
#  'Item_Identifier_FDE32',
#  'Item_Identifier_FDE33',
#  'Item_Identifier_FDE34',
#  'Item_Identifier_FDE35',
#  'Item_Identifier_FDE36',
#  'Item_Identifier_FDE38',
#  'Item_Identifier_FDE39',
#  'Item_Identifier_FDE40',
#  'Item_Identifier_FDE41',
#  'Item_Identifier_FDE44',
#  'Item_Identifier_FDE45',
#  'Item_Identifier_FDE46',
#  'Item_Identifier_FDE47',
#  'Item_Identifier_FDE50',
#  'Item_Identifier_FDE51',
#  'Item_Identifier_FDE52',
#  'Item_Identifier_FDE53',
#  'Item_Identifier_FDE56',
#  'Item_Identifier_FDE57',
#  'Item_Identifier_FDE58',
#  'Item_Identifier_FDE59',
#  'Item_Identifier_FDF02',
#  'Item_Identifier_FDF04',
#  'Item_Identifier_FDF05',
#  'Item_Identifier_FDF08',
#  'Item_Identifier_FDF09',
#  'Item_Identifier_FDF10',
#  'Item_Identifier_FDF11',
#  'Item_Identifier_FDF12',
#  'Item_Identifier_FDF14',
#  'Item_Identifier_FDF16',
#  'Item_Identifier_FDF17',
#  'Item_Identifier_FDF20',
#  'Item_Identifier_FDF21',
#  'Item_Identifier_FDF22',
#  'Item_Identifier_FDF24',
#  'Item_Identifier_FDF26',
#  'Item_Identifier_FDF28',
#  'Item_Identifier_FDF29',
#  'Item_Identifier_FDF32',
#  'Item_Identifier_FDF33',
#  'Item_Identifier_FDF34',
#  'Item_Identifier_FDF35',
#  'Item_Identifier_FDF38',
#  'Item_Identifier_FDF39',
#  'Item_Identifier_FDF40',
#  'Item_Identifier_FDF41',
#  'Item_Identifier_FDF44',
#  'Item_Identifier_FDF45',
#  'Item_Identifier_FDF46',
#  'Item_Identifier_FDF47',
#  'Item_Identifier_FDF50',
#  'Item_Identifier_FDF52',
#  'Item_Identifier_FDF53',
#  'Item_Identifier_FDF56',
#  'Item_Identifier_FDF57',
#  'Item_Identifier_FDF58',
#  'Item_Identifier_FDF59',
#  'Item_Identifier_FDG02',
#  'Item_Identifier_FDG04',
#  'Item_Identifier_FDG05',
#  'Item_Identifier_FDG08',
#  'Item_Identifier_FDG09',
#  'Item_Identifier_FDG10',
#  'Item_Identifier_FDG12',
#  'Item_Identifier_FDG14',
#  'Item_Identifier_FDG16',
#  'Item_Identifier_FDG17',
#  'Item_Identifier_FDG20',
#  'Item_Identifier_FDG21',
#  'Item_Identifier_FDG22',
#  'Item_Identifier_FDG24',
#  'Item_Identifier_FDG26',
#  'Item_Identifier_FDG28',
#  'Item_Identifier_FDG29',
#  'Item_Identifier_FDG31',
#  'Item_Identifier_FDG32',
#  'Item_Identifier_FDG33',
#  'Item_Identifier_FDG34',
#  'Item_Identifier_FDG35',
#  'Item_Identifier_FDG38',
#  'Item_Identifier_FDG40',
#  'Item_Identifier_FDG41',
#  'Item_Identifier_FDG44',
#  'Item_Identifier_FDG45',
#  'Item_Identifier_FDG46',
#  'Item_Identifier_FDG47',
#  'Item_Identifier_FDG50',
#  'Item_Identifier_FDG52',
#  'Item_Identifier_FDG53',
#  'Item_Identifier_FDG56',
#  'Item_Identifier_FDG57',
#  'Item_Identifier_FDG58',
#  'Item_Identifier_FDG59',
#  'Item_Identifier_FDG60',
#  'Item_Identifier_FDH02',
#  'Item_Identifier_FDH04',
#  'Item_Identifier_FDH05',
#  'Item_Identifier_FDH08',
#  'Item_Identifier_FDH09',
#  'Item_Identifier_FDH10',
#  'Item_Identifier_FDH12',
#  'Item_Identifier_FDH14',
#  'Item_Identifier_FDH16',
#  'Item_Identifier_FDH17',
#  'Item_Identifier_FDH19',
#  'Item_Identifier_FDH20',
#  'Item_Identifier_FDH21',
#  'Item_Identifier_FDH22',
#  'Item_Identifier_FDH24',
#  'Item_Identifier_FDH26',
#  'Item_Identifier_FDH27',
#  'Item_Identifier_FDH28',
#  'Item_Identifier_FDH31',
#  'Item_Identifier_FDH32',
#  'Item_Identifier_FDH33',
#  'Item_Identifier_FDH34',
#  'Item_Identifier_FDH35',
#  'Item_Identifier_FDH38',
#  'Item_Identifier_FDH40',
#  'Item_Identifier_FDH41',
#  'Item_Identifier_FDH44',
#  'Item_Identifier_FDH45',
#  'Item_Identifier_FDH46',
#  'Item_Identifier_FDH47',
#  'Item_Identifier_FDH48',
#  'Item_Identifier_FDH50',
#  'Item_Identifier_FDH52',
#  'Item_Identifier_FDH53',
#  'Item_Identifier_FDH56',
#  'Item_Identifier_FDH57',
#  'Item_Identifier_FDH58',
#  'Item_Identifier_FDH60',
#  'Item_Identifier_FDI02',
#  'Item_Identifier_FDI04',
#  'Item_Identifier_FDI05',
#  'Item_Identifier_FDI07',
#  'Item_Identifier_FDI08',
#  'Item_Identifier_FDI09',
#  'Item_Identifier_FDI10',
#  'Item_Identifier_FDI12',
#  'Item_Identifier_FDI14',
#  'Item_Identifier_FDI15',
#  'Item_Identifier_FDI16',
#  'Item_Identifier_FDI19',
#  'Item_Identifier_FDI20',
#  'Item_Identifier_FDI21',
#  'Item_Identifier_FDI22',
#  'Item_Identifier_FDI24',
#  'Item_Identifier_FDI26',
#  'Item_Identifier_FDI27',
#  'Item_Identifier_FDI28',
#  'Item_Identifier_FDI32',
#  'Item_Identifier_FDI33',
#  'Item_Identifier_FDI34',
#  'Item_Identifier_FDI35',
#  'Item_Identifier_FDI36',
#  'Item_Identifier_FDI38',
#  'Item_Identifier_FDI40',
#  'Item_Identifier_FDI41',
#  'Item_Identifier_FDI44',
#  'Item_Identifier_FDI45',
#  'Item_Identifier_FDI46',
#  'Item_Identifier_FDI48',
#  'Item_Identifier_FDI50',
#  'Item_Identifier_FDI52',
#  'Item_Identifier_FDI53',
#  'Item_Identifier_FDI56',
#  'Item_Identifier_FDI57',
#  'Item_Identifier_FDI58',
#  'Item_Identifier_FDI60',
#  'Item_Identifier_FDJ02',
#  'Item_Identifier_FDJ03',
#  'Item_Identifier_FDJ04',
#  'Item_Identifier_FDJ07',
#  'Item_Identifier_FDJ08',
#  'Item_Identifier_FDJ09',
#  'Item_Identifier_FDJ10',
#  'Item_Identifier_FDJ12',
#  'Item_Identifier_FDJ14',
#  'Item_Identifier_FDJ15',
#  'Item_Identifier_FDJ16',
#  'Item_Identifier_FDJ20',
#  'Item_Identifier_FDJ21',
#  'Item_Identifier_FDJ22',
#  'Item_Identifier_FDJ26',
#  'Item_Identifier_FDJ27',
#  'Item_Identifier_FDJ28',
#  'Item_Identifier_FDJ32',
#  'Item_Identifier_FDJ33',
#  'Item_Identifier_FDJ34',
#  'Item_Identifier_FDJ36',
#  'Item_Identifier_FDJ38',
#  'Item_Identifier_FDJ40',
#  'Item_Identifier_FDJ41',
#  'Item_Identifier_FDJ44',
#  'Item_Identifier_FDJ45',
#  'Item_Identifier_FDJ46',
#  'Item_Identifier_FDJ48',
#  'Item_Identifier_FDJ50',
#  'Item_Identifier_FDJ52',
#  'Item_Identifier_FDJ53',
#  'Item_Identifier_FDJ55',
#  'Item_Identifier_FDJ56',
#  'Item_Identifier_FDJ57',
#  'Item_Identifier_FDJ58',
#  'Item_Identifier_FDJ60',
#  'Item_Identifier_FDK02',
#  'Item_Identifier_FDK03',
#  'Item_Identifier_FDK04',
#  'Item_Identifier_FDK08',
#  'Item_Identifier_FDK09',
#  'Item_Identifier_FDK10',
#  'Item_Identifier_FDK14',
#  'Item_Identifier_FDK15',
#  'Item_Identifier_FDK16',
#  'Item_Identifier_FDK20',
#  'Item_Identifier_FDK21',
#  'Item_Identifier_FDK22',
#  'Item_Identifier_FDK24',
#  'Item_Identifier_FDK25',
#  'Item_Identifier_FDK26',
#  'Item_Identifier_FDK27',
#  'Item_Identifier_FDK28',
#  'Item_Identifier_FDK32',
#  'Item_Identifier_FDK33',
#  'Item_Identifier_FDK34',
#  'Item_Identifier_FDK36',
#  'Item_Identifier_FDK38',
#  'Item_Identifier_FDK40',
#  'Item_Identifier_FDK41',
#  'Item_Identifier_FDK43',
#  'Item_Identifier_FDK44',
#  'Item_Identifier_FDK45',
#  'Item_Identifier_FDK46',
#  'Item_Identifier_FDK48',
#  'Item_Identifier_FDK50',
#  'Item_Identifier_FDK51',
#  'Item_Identifier_FDK52',
#  'Item_Identifier_FDK55',
#  'Item_Identifier_FDK56',
#  'Item_Identifier_FDK58',
#  'Item_Identifier_FDK60',
#  'Item_Identifier_FDL02',
#  'Item_Identifier_FDL03',
#  'Item_Identifier_FDL04',
#  'Item_Identifier_FDL08',
#  'Item_Identifier_FDL09',
#  'Item_Identifier_FDL10',
#  'Item_Identifier_FDL12',
#  'Item_Identifier_FDL13',
#  'Item_Identifier_FDL14',
#  'Item_Identifier_FDL15',
#  'Item_Identifier_FDL16',
#  'Item_Identifier_FDL20',
#  'Item_Identifier_FDL21',
#  'Item_Identifier_FDL22',
#  'Item_Identifier_FDL24',
#  'Item_Identifier_FDL25',
#  'Item_Identifier_FDL26',
#  'Item_Identifier_FDL27',
#  'Item_Identifier_FDL28',
#  'Item_Identifier_FDL32',
#  'Item_Identifier_FDL33',
#  'Item_Identifier_FDL34',
#  'Item_Identifier_FDL36',
#  'Item_Identifier_FDL38',
#  'Item_Identifier_FDL39',
#  'Item_Identifier_FDL40',
#  'Item_Identifier_FDL43',
#  'Item_Identifier_FDL44',
#  'Item_Identifier_FDL45',
#  'Item_Identifier_FDL46',
#  'Item_Identifier_FDL48',
#  'Item_Identifier_FDL50',
#  'Item_Identifier_FDL51',
#  'Item_Identifier_FDL52',
#  'Item_Identifier_FDL56',
#  'Item_Identifier_FDL57',
#  'Item_Identifier_FDL58',
#  'Item_Identifier_FDM01',
#  'Item_Identifier_FDM02',
#  'Item_Identifier_FDM03',
#  'Item_Identifier_FDM04',
#  'Item_Identifier_FDM08',
#  'Item_Identifier_FDM09',
#  'Item_Identifier_FDM10',
#  'Item_Identifier_FDM12',
#  'Item_Identifier_FDM13',
#  'Item_Identifier_FDM14',
#  'Item_Identifier_FDM15',
#  'Item_Identifier_FDM20',
#  'Item_Identifier_FDM21',
#  'Item_Identifier_FDM22',
#  'Item_Identifier_FDM24',
#  'Item_Identifier_FDM25',
#  'Item_Identifier_FDM27',
#  'Item_Identifier_FDM28',
#  'Item_Identifier_FDM32',
#  'Item_Identifier_FDM33',
#  'Item_Identifier_FDM34',
#  'Item_Identifier_FDM36',
#  'Item_Identifier_FDM38',
#  'Item_Identifier_FDM39',
#  'Item_Identifier_FDM40',
#  'Item_Identifier_FDM44',
#  'Item_Identifier_FDM45',
#  'Item_Identifier_FDM46',
#  'Item_Identifier_FDM50',
#  'Item_Identifier_FDM51',
#  'Item_Identifier_FDM52',
#  'Item_Identifier_FDM56',
#  'Item_Identifier_FDM57',
#  'Item_Identifier_FDM58',
#  'Item_Identifier_FDM60',
#  'Item_Identifier_FDN01',
#  'Item_Identifier_FDN02',
#  'Item_Identifier_FDN03',
#  'Item_Identifier_FDN04',
#  'Item_Identifier_FDN08',
#  'Item_Identifier_FDN09',
#  'Item_Identifier_FDN10',
#  'Item_Identifier_FDN12',
#  'Item_Identifier_FDN13',
#  'Item_Identifier_FDN15',
#  'Item_Identifier_FDN16',
#  'Item_Identifier_FDN20',
#  'Item_Identifier_FDN21',
#  'Item_Identifier_FDN22',
#  'Item_Identifier_FDN23',
#  'Item_Identifier_FDN24',
#  'Item_Identifier_FDN25',
#  'Item_Identifier_FDN27',
#  'Item_Identifier_FDN28',
#  'Item_Identifier_FDN31',
#  'Item_Identifier_FDN32',
#  'Item_Identifier_FDN33',
#  'Item_Identifier_FDN34',
#  'Item_Identifier_FDN38',
#  'Item_Identifier_FDN39',
#  'Item_Identifier_FDN40',
#  'Item_Identifier_FDN44',
#  'Item_Identifier_FDN45',
#  'Item_Identifier_FDN46',
#  'Item_Identifier_FDN48',
#  'Item_Identifier_FDN49',
#  'Item_Identifier_FDN50',
#  'Item_Identifier_FDN51',
#  'Item_Identifier_FDN56',
#  'Item_Identifier_FDN57',
#  'Item_Identifier_FDN58',
#  'Item_Identifier_FDN60',
#  'Item_Identifier_FDO01',
#  'Item_Identifier_FDO03',
#  'Item_Identifier_FDO04',
#  'Item_Identifier_FDO08',
#  'Item_Identifier_FDO09',
#  'Item_Identifier_FDO10',
#  'Item_Identifier_FDO11',
#  'Item_Identifier_FDO12',
#  'Item_Identifier_FDO13',
#  'Item_Identifier_FDO15',
#  'Item_Identifier_FDO16',
#  'Item_Identifier_FDO19',
#  'Item_Identifier_FDO20',
#  'Item_Identifier_FDO21',
#  'Item_Identifier_FDO22',
#  'Item_Identifier_FDO23',
#  'Item_Identifier_FDO24',
#  'Item_Identifier_FDO25',
#  'Item_Identifier_FDO27',
#  'Item_Identifier_FDO28',
#  'Item_Identifier_FDO31',
#  'Item_Identifier_FDO32',
#  'Item_Identifier_FDO33',
#  'Item_Identifier_FDO34',
#  'Item_Identifier_FDO36',
#  'Item_Identifier_FDO37',
#  'Item_Identifier_FDO38',
#  'Item_Identifier_FDO39',
#  'Item_Identifier_FDO40',
#  'Item_Identifier_FDO44',
#  'Item_Identifier_FDO45',
#  'Item_Identifier_FDO46',
#  'Item_Identifier_FDO48',
#  'Item_Identifier_FDO49',
#  'Item_Identifier_FDO50',
#  'Item_Identifier_FDO51',
#  'Item_Identifier_FDO52',
#  'Item_Identifier_FDO56',
#  'Item_Identifier_FDO57',
#  'Item_Identifier_FDO58',
#  'Item_Identifier_FDO60',
#  'Item_Identifier_FDP01',
#  'Item_Identifier_FDP03',
#  'Item_Identifier_FDP04',
#  'Item_Identifier_FDP07',
#  'Item_Identifier_FDP08',
#  'Item_Identifier_FDP09',
#  'Item_Identifier_FDP10',
#  'Item_Identifier_FDP11',
#  'Item_Identifier_FDP12',
#  'Item_Identifier_FDP13',
#  'Item_Identifier_FDP15',
#  'Item_Identifier_FDP16',
#  'Item_Identifier_FDP19',
#  'Item_Identifier_FDP20',
#  'Item_Identifier_FDP21',
#  'Item_Identifier_FDP22',
#  'Item_Identifier_FDP23',
#  'Item_Identifier_FDP24',
#  'Item_Identifier_FDP25',
#  'Item_Identifier_FDP26',
#  'Item_Identifier_FDP27',
#  'Item_Identifier_FDP28',
#  'Item_Identifier_FDP31',
#  'Item_Identifier_FDP32',
#  'Item_Identifier_FDP33',
#  'Item_Identifier_FDP34',
#  'Item_Identifier_FDP36',
#  'Item_Identifier_FDP37',
#  'Item_Identifier_FDP38',
#  'Item_Identifier_FDP39',
#  'Item_Identifier_FDP40',
#  'Item_Identifier_FDP44',
#  'Item_Identifier_FDP45',
#  'Item_Identifier_FDP46',
#  'Item_Identifier_FDP48',
#  'Item_Identifier_FDP49',
#  'Item_Identifier_FDP51',
#  'Item_Identifier_FDP52',
#  'Item_Identifier_FDP56',
#  'Item_Identifier_FDP57',
#  'Item_Identifier_FDP58',
#  'Item_Identifier_FDP59',
#  'Item_Identifier_FDP60',
#  'Item_Identifier_FDQ01',
#  'Item_Identifier_FDQ03',
#  'Item_Identifier_FDQ04',
#  'Item_Identifier_FDQ07',
#  'Item_Identifier_FDQ08',
#  'Item_Identifier_FDQ09',
#  'Item_Identifier_FDQ10',
#  'Item_Identifier_FDQ11',
#  'Item_Identifier_FDQ12',
#  'Item_Identifier_FDQ13',
#  'Item_Identifier_FDQ14',
#  'Item_Identifier_FDQ15',
#  'Item_Identifier_FDQ16',
#  'Item_Identifier_FDQ19',
#  'Item_Identifier_FDQ20',
#  'Item_Identifier_FDQ21',
#  'Item_Identifier_FDQ22',
#  'Item_Identifier_FDQ23',
#  'Item_Identifier_FDQ24',
#  'Item_Identifier_FDQ25',
#  'Item_Identifier_FDQ26',
#  'Item_Identifier_FDQ27',
#  'Item_Identifier_FDQ28',
#  'Item_Identifier_FDQ31',
#  'Item_Identifier_FDQ32',
#  'Item_Identifier_FDQ33',
#  'Item_Identifier_FDQ34',
#  'Item_Identifier_FDQ36',
#  'Item_Identifier_FDQ37',
#  'Item_Identifier_FDQ39',
#  'Item_Identifier_FDQ40',
#  'Item_Identifier_FDQ44',
#  'Item_Identifier_FDQ45',
#  'Item_Identifier_FDQ46',
#  'Item_Identifier_FDQ47',
#  'Item_Identifier_FDQ48',
#  'Item_Identifier_FDQ49',
#  'Item_Identifier_FDQ51',
#  'Item_Identifier_FDQ52',
#  'Item_Identifier_FDQ55',
#  'Item_Identifier_FDQ56',
#  'Item_Identifier_FDQ57',
#  'Item_Identifier_FDQ58',
#  'Item_Identifier_FDQ59',
#  'Item_Identifier_FDQ60',
#  'Item_Identifier_FDR01',
#  'Item_Identifier_FDR02',
#  'Item_Identifier_FDR03',
#  'Item_Identifier_FDR04',
#  'Item_Identifier_FDR07',
#  'Item_Identifier_FDR08',
#  'Item_Identifier_FDR09',
#  'Item_Identifier_FDR10',
#  'Item_Identifier_FDR11',
#  'Item_Identifier_FDR12',
#  'Item_Identifier_FDR13',
#  'Item_Identifier_FDR14',
#  'Item_Identifier_FDR15',
#  'Item_Identifier_FDR16',
#  'Item_Identifier_FDR19',
#  'Item_Identifier_FDR20',
#  'Item_Identifier_FDR21',
#  'Item_Identifier_FDR22',
#  'Item_Identifier_FDR23',
#  'Item_Identifier_FDR24',
#  'Item_Identifier_FDR25',
#  'Item_Identifier_FDR26',
#  'Item_Identifier_FDR27',
#  'Item_Identifier_FDR28',
#  'Item_Identifier_FDR31',
#  'Item_Identifier_FDR32',
#  'Item_Identifier_FDR33',
#  'Item_Identifier_FDR34',
#  'Item_Identifier_FDR35',
#  'Item_Identifier_FDR36',
#  'Item_Identifier_FDR37',
#  'Item_Identifier_FDR39',
#  'Item_Identifier_FDR40',
#  'Item_Identifier_FDR43',
#  'Item_Identifier_FDR44',
#  'Item_Identifier_FDR45',
#  'Item_Identifier_FDR46',
#  'Item_Identifier_FDR47',
#  'Item_Identifier_FDR48',
#  'Item_Identifier_FDR49',
#  'Item_Identifier_FDR51',
#  'Item_Identifier_FDR52',
#  'Item_Identifier_FDR55',
#  'Item_Identifier_FDR56',
#  'Item_Identifier_FDR57',
#  'Item_Identifier_FDR58',
#  'Item_Identifier_FDR59',
#  'Item_Identifier_FDR60',
#  'Item_Identifier_FDS01',
#  'Item_Identifier_FDS02',
#  'Item_Identifier_FDS03',
#  'Item_Identifier_FDS04',
#  'Item_Identifier_FDS07',
#  'Item_Identifier_FDS08',
#  'Item_Identifier_FDS09',
#  'Item_Identifier_FDS10',
#  'Item_Identifier_FDS11',
#  'Item_Identifier_FDS12',
#  'Item_Identifier_FDS13',
#  'Item_Identifier_FDS14',
#  'Item_Identifier_FDS15',
#  'Item_Identifier_FDS16',
#  'Item_Identifier_FDS19',
#  'Item_Identifier_FDS20',
#  'Item_Identifier_FDS21',
#  'Item_Identifier_FDS22',
#  'Item_Identifier_FDS23',
#  'Item_Identifier_FDS24',
#  'Item_Identifier_FDS25',
#  'Item_Identifier_FDS26',
#  'Item_Identifier_FDS27',
#  'Item_Identifier_FDS28',
#  'Item_Identifier_FDS31',
#  'Item_Identifier_FDS32',
#  'Item_Identifier_FDS33',
#  'Item_Identifier_FDS34',
#  'Item_Identifier_FDS35',
#  'Item_Identifier_FDS36',
#  'Item_Identifier_FDS37',
#  'Item_Identifier_FDS39',
#  'Item_Identifier_FDS40',
#  'Item_Identifier_FDS43',
#  'Item_Identifier_FDS44',
#  'Item_Identifier_FDS45',
#  'Item_Identifier_FDS46',
#  'Item_Identifier_FDS47',
#  'Item_Identifier_FDS48',
#  'Item_Identifier_FDS49',
#  'Item_Identifier_FDS50',
#  'Item_Identifier_FDS51',
#  'Item_Identifier_FDS52',
#  'Item_Identifier_FDS55',
#  'Item_Identifier_FDS56',
#  'Item_Identifier_FDS57',
#  'Item_Identifier_FDS58',
#  'Item_Identifier_FDS59',
#  'Item_Identifier_FDS60',
#  'Item_Identifier_FDT01',
#  'Item_Identifier_FDT02',
#  'Item_Identifier_FDT03',
#  'Item_Identifier_FDT04',
#  'Item_Identifier_FDT07',
#  'Item_Identifier_FDT08',
#  'Item_Identifier_FDT09',
#  'Item_Identifier_FDT10',
#  'Item_Identifier_FDT11',
#  'Item_Identifier_FDT12',
#  'Item_Identifier_FDT13',
#  'Item_Identifier_FDT14',
#  'Item_Identifier_FDT15',
#  'Item_Identifier_FDT16',
#  'Item_Identifier_FDT19',
#  'Item_Identifier_FDT20',
#  'Item_Identifier_FDT21',
#  'Item_Identifier_FDT22',
#  'Item_Identifier_FDT23',
#  'Item_Identifier_FDT24',
#  'Item_Identifier_FDT25',
#  'Item_Identifier_FDT26',
#  'Item_Identifier_FDT27',
#  'Item_Identifier_FDT28',
#  'Item_Identifier_FDT31',
#  'Item_Identifier_FDT32',
#  'Item_Identifier_FDT33',
#  'Item_Identifier_FDT34',
#  'Item_Identifier_FDT35',
#  'Item_Identifier_FDT36',
#  'Item_Identifier_FDT37',
#  'Item_Identifier_FDT39',
#  'Item_Identifier_FDT40',
#  'Item_Identifier_FDT43',
#  'Item_Identifier_FDT44',
#  'Item_Identifier_FDT45',
#  'Item_Identifier_FDT46',
#  'Item_Identifier_FDT47',
#  'Item_Identifier_FDT48',
#  'Item_Identifier_FDT49',
#  'Item_Identifier_FDT50',
#  'Item_Identifier_FDT51',
#  'Item_Identifier_FDT52',
#  'Item_Identifier_FDT55',
#  'Item_Identifier_FDT56',
#  'Item_Identifier_FDT57',
#  'Item_Identifier_FDT58',
#  'Item_Identifier_FDT59',
#  'Item_Identifier_FDT60',
#  'Item_Identifier_FDU01',
#  'Item_Identifier_FDU02',
#  'Item_Identifier_FDU03',
#  'Item_Identifier_FDU04',
#  'Item_Identifier_FDU07',
#  'Item_Identifier_FDU08',
#  'Item_Identifier_FDU09',
#  'Item_Identifier_FDU10',
#  'Item_Identifier_FDU11',
#  'Item_Identifier_FDU12',
#  'Item_Identifier_FDU13',
#  'Item_Identifier_FDU14',
#  'Item_Identifier_FDU15',
#  'Item_Identifier_FDU16',
#  'Item_Identifier_FDU19',
#  'Item_Identifier_FDU20',
#  'Item_Identifier_FDU21',
#  'Item_Identifier_FDU22',
#  'Item_Identifier_FDU23',
#  'Item_Identifier_FDU24',
#  'Item_Identifier_FDU25',
#  'Item_Identifier_FDU26',
#  'Item_Identifier_FDU27',
#  'Item_Identifier_FDU28',
#  'Item_Identifier_FDU31',
#  'Item_Identifier_FDU32',
#  'Item_Identifier_FDU33',
#  'Item_Identifier_FDU34',
#  'Item_Identifier_FDU35',
#  'Item_Identifier_FDU36',
#  'Item_Identifier_FDU37',
#  'Item_Identifier_FDU38',
#  'Item_Identifier_FDU39',
#  'Item_Identifier_FDU40',
#  'Item_Identifier_FDU43',
#  'Item_Identifier_FDU44',
#  ...]

# %% [markdown]
# ### **Inspect the Result**

# %%
# Check for missing values and that data is scaled and one-hot encoded
print(f'There are {np.isnan(X_train_processed).sum().sum()} missing values in X_train_processed.')
print(f'There are {np.isnan(X_test_processed).sum().sum()} missing values in X_test_processed.')
print('\n')
print('All data in X_train_processed are', X_train_processed.dtype)
print('All data in X_test_processed are', X_test_processed.dtype)
print('\n')
print('The shape of X_train_processed is', X_train_processed.shape)
print('The shape of X_test_processed is', X_test_processed.shape)
# Out:
# There are 0 missing values in X_train_processed.
# There are 0 missing values in X_test_processed.
#
#
# All data in X_train_processed are float64
# All data in X_test_processed are float64
#
#
# The shape of X_train_processed is (6392, 1593)
# The shape of X_test_processed is (2131, 1593)

# %%
# Create dataframes from the processed arrays
X_train_df = pd.DataFrame(X_train_processed, columns = final_cols)
X_test_df = pd.DataFrame(X_test_processed, columns = final_cols)

# %%
X_train_df.describe().round(2)
# Out:
#        Item_Weight  \
# count      6392.00
# mean          0.00
# std           1.00
# min          -1.81
# 25%          -0.88
# 50%          -0.06
# 75%           0.88
# max           1.82
#
#        Item_Visibility  \
# count          6392.00
# mean             -0.00
# std               1.00
# min              -1.29
# 25%              -0.76
# 50%              -0.23
# 75%               0.56
# max               5.13
#
#        Item_MRP  \
# count   6392.00
# mean       0.00
# std        1.00
# min       -1.77
# 25%       -0.76
# 50%        0.03
# 75%        0.72
# max        1.99
#
#        Outlet_Establishment_Year  \
# count                    6392.00
# mean                       -0.00
# std                         1.00
# min                        -1.53
# 25%                        -1.29
# 50%                         0.14
# 75%                         0.73
# max                         1.33
#
#        Item_Identifier_DRA12  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRA24  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRA59  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRB01  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRB13  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRB24  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRB25  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRB48  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRC01  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRC12  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRC13  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRC25  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRC27  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRC36  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRC49  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRD01  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRD12  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRD13  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRD15  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRD24  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRD25  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRD27  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRD37  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRD49  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRD60  \
# count                6392.00
# mean                    0.00
# std                     0.01
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRE01  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRE03  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRE12  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRE13  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRE15  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRE25  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRE27  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRE37  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRE48  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRE49  \
# count                6392.00
# mean                    0.00
# std                     0.04
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRE60  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRF01  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRF03  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRF13  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRF15  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRF23  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRF25  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRF27  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRF36  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRF37  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRF48  \
# count                6392.00
# mean                    0.00
# std                     0.01
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRF49  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRF51  \
# count                6392.00
# mean                    0.00
# std                     0.01
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRF60  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRG01  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRG03  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRG11  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRG13  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRG15  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRG23  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRG25  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRG27  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRG36  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRG37  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRG39  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRG48  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRG49  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRG51  \
# count                6392.00
# mean                    0.00
# std                     0.01
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRH01  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRH03  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRH11  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRH13  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRH15  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRH23  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRH25  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRH36  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRH37  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRH39  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRH49  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRH51  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRH59  \
# count                6392.00
# mean                    0.00
# std                     0.01
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRI01  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRI03  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRI11  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRI13  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRI23  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRI25  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRI37  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRI39  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRI47  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRI49  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRI51  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRI59  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRJ01  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRJ11  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRJ13  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRJ23  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRJ24  \
# count                6392.00
# mean                    0.00
# std                     0.04
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRJ25  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRJ35  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRJ37  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRJ39  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRJ47  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRJ49  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRJ51  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRJ59  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRK01  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRK11  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRK12  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRK13  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRK23  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRK35  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRK37  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRK39  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRK47  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRK49  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRK59  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRL01  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRL11  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRL23  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRL35  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRL37  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRL47  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRL49  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRL59  \
# count                6392.00
# mean                    0.00
# std                     0.01
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRL60  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRM11  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRM23  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRM35  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRM37  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRM47  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRM48  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRM49  \
# count                6392.00
# mean                    0.00
# std                     0.01
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRM59  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRN11  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRN35  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRN36  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRN37  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRN47  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRN59  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRO35  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRO47  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRO59  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRP35  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRP47  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRQ35  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRY23  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRZ11  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRZ24  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_FDA01  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_FDA02  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_FDA03  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_FDA04  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_FDA07  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_FDA08  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_FDA09  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_FDA10  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_FDA11  \
# count                6392.00
# mean                    0.00
# std                     0.01
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_FDA13  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_FDA14  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_FDA15  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_FDA16  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_FDA19  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_FDA20  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_FDA21  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_FDA22  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_FDA23  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_FDA25  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# ...
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_NCY41  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_NCY42  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_NCY53  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_NCY54  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_NCZ05  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_NCZ06  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_NCZ17  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_NCZ18  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_NCZ29  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_NCZ30  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_NCZ41  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_NCZ42  \
# count                6392.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_NCZ53  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_NCZ54  \
# count                6392.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Fat_Content_Low Fat  \
# count                   6392.00
# mean                       0.65
# std                        0.48
# min                        0.00
# 25%                        0.00
# 50%                        1.00
# 75%                        1.00
# max                        1.00
#
#        Item_Fat_Content_Regular  \
# count                   6392.00
# mean                       0.35
# std                        0.48
# min                        0.00
# 25%                        0.00
# 50%                        0.00
# 75%                        1.00
# max                        1.00
#
#        Item_Type_Baking Goods  \
# count                 6392.00
# mean                     0.07
# std                      0.26
# min                      0.00
# 25%                      0.00
# 50%                      0.00
# 75%                      0.00
# max                      1.00
#
#        Item_Type_Breads  \
# count           6392.00
# mean               0.03
# std                0.16
# min                0.00
# 25%                0.00
# 50%                0.00
# 75%                0.00
# max                1.00
#
#        Item_Type_Breakfast  \
# count              6392.00
# mean                  0.01
# std                   0.11
# min                   0.00
# 25%                   0.00
# 50%                   0.00
# 75%                   0.00
# max                   1.00
#
#        Item_Type_Canned  \
# count           6392.00
# mean               0.08
# std                0.26
# min                0.00
# 25%                0.00
# 50%                0.00
# 75%                0.00
# max                1.00
#
#        Item_Type_Dairy  \
# count          6392.00
# mean              0.08
# std               0.27
# min               0.00
# 25%               0.00
# 50%               0.00
# 75%               0.00
# max               1.00
#
#        Item_Type_Frozen Foods  \
# count                  6392.0
# mean                      0.1
# std                       0.3
# min                       0.0
# 25%                       0.0
# 50%                       0.0
# 75%                       0.0
# max                       1.0
#
#        Item_Type_Fruits and Vegetables  \
# count                          6392.00
# mean                              0.15
# std                               0.36
# min                               0.00
# 25%                               0.00
# 50%                               0.00
# 75%                               0.00
# max                               1.00
#
#        Item_Type_Hard Drinks  \
# count                6392.00
# mean                    0.03
# std                     0.16
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Type_Health and Hygiene  \
# count                       6392.00
# mean                           0.06
# std                            0.24
# min                            0.00
# 25%                            0.00
# 50%                            0.00
# 75%                            0.00
# max                            1.00
#
#        Item_Type_Household  \
# count              6392.00
# mean                  0.11
# std                   0.31
# min                   0.00
# 25%                   0.00
# 50%                   0.00
# 75%                   0.00
# max                   1.00
#
#        Item_Type_Meat  \
# count         6392.00
# mean             0.05
# std              0.21
# min              0.00
# 25%              0.00
# 50%              0.00
# 75%              0.00
# max              1.00
#
#        Item_Type_Others  \
# count           6392.00
# mean               0.02
# std                0.14
# min                0.00
# 25%                0.00
# 50%                0.00
# 75%                0.00
# max                1.00
#
#        Item_Type_Seafood  \
# count            6392.00
# mean                0.01
# std                 0.08
# min                 0.00
# 25%                 0.00
# 50%                 0.00
# 75%                 0.00
# max                 1.00
#
#        Item_Type_Snack Foods  \
# count                6392.00
# mean                    0.14
# std                     0.35
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Type_Soft Drinks  \
# count                6392.00
# mean                    0.05
# std                     0.22
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Type_Starchy Foods  \
# count                  6392.00
# mean                      0.02
# std                       0.14
# min                       0.00
# 25%                       0.00
# 50%                       0.00
# 75%                       0.00
# max                       1.00
#
#        Outlet_Identifier_OUT010  \
# count                   6392.00
# mean                       0.06
# std                        0.25
# min                        0.00
# 25%                        0.00
# 50%                        0.00
# 75%                        0.00
# max                        1.00
#
#        Outlet_Identifier_OUT013  \
# count                   6392.00
# mean                       0.11
# std                        0.31
# min                        0.00
# 25%                        0.00
# 50%                        0.00
# 75%                        0.00
# max                        1.00
#
#        Outlet_Identifier_OUT017  \
# count                   6392.00
# mean                       0.11
# std                        0.31
# min                        0.00
# 25%                        0.00
# 50%                        0.00
# 75%                        0.00
# max                        1.00
#
#        Outlet_Identifier_OUT018  \
# count                   6392.00
# mean                       0.11
# std                        0.31
# min                        0.00
# 25%                        0.00
# 50%                        0.00
# 75%                        0.00
# max                        1.00
#
#        Outlet_Identifier_OUT019  \
# count                   6392.00
# mean                       0.06
# std                        0.24
# min                        0.00
# 25%                        0.00
# 50%                        0.00
# 75%                        0.00
# max                        1.00
#
#        Outlet_Identifier_OUT027  \
# count                   6392.00
# mean                       0.11
# std                        0.32
# min                        0.00
# 25%                        0.00
# 50%                        0.00
# 75%                        0.00
# max                        1.00
#
#        Outlet_Identifier_OUT035  \
# count                   6392.00
# mean                       0.11
# std                        0.31
# min                        0.00
# 25%                        0.00
# 50%                        0.00
# 75%                        0.00
# max                        1.00
#
#        Outlet_Identifier_OUT045  \
# count                   6392.00
# mean                       0.11
# std                        0.31
# min                        0.00
# 25%                        0.00
# 50%                        0.00
# 75%                        0.00
# max                        1.00
#
#        Outlet_Identifier_OUT046  \
# count                   6392.00
# mean                       0.11
# std                        0.31
# min                        0.00
# 25%                        0.00
# 50%                        0.00
# 75%                        0.00
# max                        1.00
#
#        Outlet_Identifier_OUT049  \
# count                   6392.00
# mean                       0.11
# std                        0.31
# min                        0.00
# 25%                        0.00
# 50%                        0.00
# 75%                        0.00
# max                        1.00
#
#        Outlet_Size_High  \
# count           6392.00
# mean               0.11
# std                0.31
# min                0.00
# 25%                0.00
# 50%                0.00
# 75%                0.00
# max                1.00
#
#        Outlet_Size_Medium  \
# count             6392.00
# mean                 0.33
# std                  0.47
# min                  0.00
# 25%                  0.00
# 50%                  0.00
# 75%                  1.00
# max                  1.00
#
#        Outlet_Size_Small  \
# count            6392.00
# mean                0.28
# std                 0.45
# min                 0.00
# 25%                 0.00
# 50%                 0.00
# 75%                 1.00
# max                 1.00
#
#        Outlet_Size_Unknown  \
# count              6392.00
# mean                  0.28
# std                   0.45
# min                   0.00
# 25%                   0.00
# 50%                   0.00
# 75%                   1.00
# max                   1.00
#
#        Outlet_Location_Type_Tier 1  \
# count                      6392.00
# mean                          0.27
# std                           0.45
# min                           0.00
# 25%                           0.00
# 50%                           0.00
# 75%                           1.00
# max                           1.00
#
#        Outlet_Location_Type_Tier 2  \
# count                      6392.00
# mean                          0.33
# std                           0.47
# min                           0.00
# 25%                           0.00
# 50%                           0.00
# 75%                           1.00
# max                           1.00
#
#        Outlet_Location_Type_Tier 3  \
# count                      6392.00
# mean                          0.40
# std                           0.49
# min                           0.00
# 25%                           0.00
# 50%                           0.00
# 75%                           1.00
# max                           1.00
#
#        Outlet_Type_Grocery Store  \
# count                    6392.00
# mean                        0.12
# std                         0.33
# min                         0.00
# 25%                         0.00
# 50%                         0.00
# 75%                         0.00
# max                         1.00
#
#        Outlet_Type_Supermarket Type1  \
# count                        6392.00
# mean                            0.65
# std                             0.48
# min                             0.00
# 25%                             0.00
# 50%                             1.00
# 75%                             1.00
# max                             1.00
#
#        Outlet_Type_Supermarket Type2  \
# count                        6392.00
# mean                            0.11
# std                             0.31
# min                             0.00
# 25%                             0.00
# 50%                             0.00
# 75%                             0.00
# max                             1.00
#
#        Outlet_Type_Supermarket Type3
# count                        6392.00
# mean                            0.11
# std                             0.32
# min                             0.00
# 25%                             0.00
# 50%                             0.00
# 75%                             0.00
# max                             1.00

# %%
X_test_df.describe().round(2)
# Out:
#        Item_Weight  \
# count      2131.00
# mean         -0.05
# std           0.99
# min          -1.81
# 25%          -0.93
# 50%          -0.06
# 75%           0.81
# max           1.82
#
#        Item_Visibility  \
# count          2131.00
# mean              0.01
# std               1.04
# min              -1.29
# 25%              -0.76
# 50%              -0.24
# 75%               0.56
# max               4.79
#
#        Item_MRP  \
# count   2131.00
# mean      -0.06
# std        0.98
# min       -1.75
# 25%       -0.78
# 50%       -0.15
# 75%        0.64
# max        1.99
#
#        Outlet_Establishment_Year  \
# count                    2131.00
# mean                       -0.01
# std                         0.99
# min                        -1.53
# 25%                        -1.29
# 50%                         0.14
# 75%                         0.73
# max                         1.33
#
#        Item_Identifier_DRA12  \
# count                2131.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRA24  \
# count                2131.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRA59  \
# count                2131.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRB01  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_DRB13  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_DRB24  \
# count                2131.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRB25  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRB48  \
# count                2131.00
# mean                    0.00
# std                     0.04
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRC01  \
# count                2131.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRC12  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_DRC13  \
# count                2131.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRC25  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_DRC27  \
# count                2131.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRC36  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRC49  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_DRD01  \
# count                2131.00
# mean                    0.00
# std                     0.04
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRD12  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_DRD13  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_DRD15  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_DRD24  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRD25  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRD27  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRD37  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRD49  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_DRD60  \
# count                2131.00
# mean                    0.00
# std                     0.05
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRE01  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_DRE03  \
# count                2131.00
# mean                    0.00
# std                     0.04
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRE12  \
# count                2131.00
# mean                    0.00
# std                     0.04
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRE13  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRE15  \
# count                2131.00
# mean                    0.00
# std                     0.04
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRE25  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_DRE27  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_DRE37  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRE48  \
# count                2131.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRE49  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_DRE60  \
# count                2131.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRF01  \
# count                2131.00
# mean                    0.00
# std                     0.04
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRF03  \
# count                2131.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRF13  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRF15  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_DRF23  \
# count                2131.00
# mean                    0.00
# std                     0.04
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRF25  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_DRF27  \
# count                2131.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRF36  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRF37  \
# count                2131.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRF48  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_DRF49  \
# count                2131.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRF51  \
# count                2131.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRF60  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRG01  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRG03  \
# count                2131.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRG11  \
# count                2131.00
# mean                    0.00
# std                     0.04
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRG13  \
# count                2131.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRG15  \
# count                2131.00
# mean                    0.00
# std                     0.04
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRG23  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRG25  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_DRG27  \
# count                2131.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRG36  \
# count                2131.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRG37  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRG39  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRG48  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_DRG49  \
# count                2131.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRG51  \
# count                2131.00
# mean                    0.00
# std                     0.04
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRH01  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_DRH03  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_DRH11  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_DRH13  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRH15  \
# count                2131.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRH23  \
# count                2131.00
# mean                    0.00
# std                     0.04
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRH25  \
# count                2131.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRH36  \
# count                2131.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRH37  \
# count                2131.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRH39  \
# count                2131.00
# mean                    0.00
# std                     0.04
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRH49  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRH51  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRH59  \
# count                2131.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRI01  \
# count                2131.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRI03  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRI11  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRI13  \
# count                2131.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRI23  \
# count                2131.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRI25  \
# count                2131.00
# mean                    0.00
# std                     0.04
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRI37  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRI39  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRI47  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_DRI49  \
# count                2131.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRI51  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRI59  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_DRJ01  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_DRJ11  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_DRJ13  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRJ23  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_DRJ24  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_DRJ25  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRJ35  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_DRJ37  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_DRJ39  \
# count                2131.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRJ47  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRJ49  \
# count                2131.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRJ51  \
# count                2131.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRJ59  \
# count                2131.00
# mean                    0.00
# std                     0.04
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRK01  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRK11  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRK12  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRK13  \
# count                2131.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRK23  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRK35  \
# count                2131.00
# mean                    0.00
# std                     0.05
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRK37  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRK39  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRK47  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRK49  \
# count                2131.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRK59  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_DRL01  \
# count                2131.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRL11  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRL23  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRL35  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRL37  \
# count                2131.00
# mean                    0.00
# std                     0.04
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRL47  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_DRL49  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_DRL59  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRL60  \
# count                2131.00
# mean                    0.00
# std                     0.04
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRM11  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_DRM23  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRM35  \
# count                2131.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRM37  \
# count                2131.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRM47  \
# count                2131.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRM48  \
# count                2131.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRM49  \
# count                2131.00
# mean                    0.00
# std                     0.04
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRM59  \
# count                2131.00
# mean                    0.00
# std                     0.04
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRN11  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRN35  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_DRN36  \
# count                2131.00
# mean                    0.00
# std                     0.04
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRN37  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRN47  \
# count                2131.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRN59  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_DRO35  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_DRO47  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_DRO59  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_DRP35  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRP47  \
# count                2131.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRQ35  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_DRY23  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRZ11  \
# count                2131.00
# mean                    0.00
# std                     0.04
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_DRZ24  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_FDA01  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_FDA02  \
# count                2131.00
# mean                    0.00
# std                     0.04
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_FDA03  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_FDA04  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_FDA07  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_FDA08  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_FDA09  \
# count                2131.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_FDA10  \
# count                2131.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_FDA11  \
# count                2131.00
# mean                    0.00
# std                     0.04
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_FDA13  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_FDA14  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_FDA15  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_FDA16  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_FDA19  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_FDA20  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_FDA21  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_FDA22  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_FDA23  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_FDA25  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# ...
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_NCY41  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_NCY42  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_NCY53  \
# count                2131.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_NCY54  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_NCZ05  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_NCZ06  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_NCZ17  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_NCZ18  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_NCZ29  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_NCZ30  \
# count                2131.00
# mean                    0.00
# std                     0.03
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_NCZ41  \
# count                2131.00
# mean                    0.00
# std                     0.02
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_NCZ42  \
# count                2131.00
# mean                    0.00
# std                     0.04
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Identifier_NCZ53  \
# count                 2131.0
# mean                     0.0
# std                      0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
#
#        Item_Identifier_NCZ54  \
# count                2131.00
# mean                    0.00
# std                     0.04
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Fat_Content_Low Fat  \
# count                   2131.00
# mean                       0.65
# std                        0.48
# min                        0.00
# 25%                        0.00
# 50%                        1.00
# 75%                        1.00
# max                        1.00
#
#        Item_Fat_Content_Regular  \
# count                   2131.00
# mean                       0.35
# std                        0.48
# min                        0.00
# 25%                        0.00
# 50%                        0.00
# 75%                        1.00
# max                        1.00
#
#        Item_Type_Baking Goods  \
# count                 2131.00
# mean                     0.08
# std                      0.27
# min                      0.00
# 25%                      0.00
# 50%                      0.00
# 75%                      0.00
# max                      1.00
#
#        Item_Type_Breads  \
# count           2131.00
# mean               0.04
# std                0.19
# min                0.00
# 25%                0.00
# 50%                0.00
# 75%                0.00
# max                1.00
#
#        Item_Type_Breakfast  \
# count              2131.00
# mean                  0.01
# std                   0.11
# min                   0.00
# 25%                   0.00
# 50%                   0.00
# 75%                   0.00
# max                   1.00
#
#        Item_Type_Canned  \
# count           2131.00
# mean               0.08
# std                0.27
# min                0.00
# 25%                0.00
# 50%                0.00
# 75%                0.00
# max                1.00
#
#        Item_Type_Dairy  \
# count          2131.00
# mean              0.08
# std               0.27
# min               0.00
# 25%               0.00
# 50%               0.00
# 75%               0.00
# max               1.00
#
#        Item_Type_Frozen Foods  \
# count                 2131.00
# mean                     0.11
# std                      0.31
# min                      0.00
# 25%                      0.00
# 50%                      0.00
# 75%                      0.00
# max                      1.00
#
#        Item_Type_Fruits and Vegetables  \
# count                          2131.00
# mean                              0.13
# std                               0.34
# min                               0.00
# 25%                               0.00
# 50%                               0.00
# 75%                               0.00
# max                               1.00
#
#        Item_Type_Hard Drinks  \
# count                2131.00
# mean                    0.02
# std                     0.14
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Type_Health and Hygiene  \
# count                       2131.00
# mean                           0.06
# std                            0.24
# min                            0.00
# 25%                            0.00
# 50%                            0.00
# 75%                            0.00
# max                            1.00
#
#        Item_Type_Household  \
# count               2131.0
# mean                   0.1
# std                    0.3
# min                    0.0
# 25%                    0.0
# 50%                    0.0
# 75%                    0.0
# max                    1.0
#
#        Item_Type_Meat  \
# count         2131.00
# mean             0.06
# std              0.23
# min              0.00
# 25%              0.00
# 50%              0.00
# 75%              0.00
# max              1.00
#
#        Item_Type_Others  \
# count           2131.00
# mean               0.02
# std                0.13
# min                0.00
# 25%                0.00
# 50%                0.00
# 75%                0.00
# max                1.00
#
#        Item_Type_Seafood  \
# count            2131.00
# mean                0.01
# std                 0.10
# min                 0.00
# 25%                 0.00
# 50%                 0.00
# 75%                 0.00
# max                 1.00
#
#        Item_Type_Snack Foods  \
# count                2131.00
# mean                    0.14
# std                     0.34
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Type_Soft Drinks  \
# count                2131.00
# mean                    0.05
# std                     0.23
# min                     0.00
# 25%                     0.00
# 50%                     0.00
# 75%                     0.00
# max                     1.00
#
#        Item_Type_Starchy Foods  \
# count                  2131.00
# mean                      0.01
# std                       0.11
# min                       0.00
# 25%                       0.00
# 50%                       0.00
# 75%                       0.00
# max                       1.00
#
#        Outlet_Identifier_OUT010  \
# count                   2131.00
# mean                       0.07
# std                        0.25
# min                        0.00
# 25%                        0.00
# 50%                        0.00
# 75%                        0.00
# max                        1.00
#
#        Outlet_Identifier_OUT013  \
# count                   2131.00
# mean                       0.11
# std                        0.32
# min                        0.00
# 25%                        0.00
# 50%                        0.00
# 75%                        0.00
# max                        1.00
#
#        Outlet_Identifier_OUT017  \
# count                   2131.00
# mean                       0.11
# std                        0.31
# min                        0.00
# 25%                        0.00
# 50%                        0.00
# 75%                        0.00
# max                        1.00
#
#        Outlet_Identifier_OUT018  \
# count                   2131.00
# mean                       0.11
# std                        0.31
# min                        0.00
# 25%                        0.00
# 50%                        0.00
# 75%                        0.00
# max                        1.00
#
#        Outlet_Identifier_OUT019  \
# count                   2131.00
# mean                       0.07
# std                        0.25
# min                        0.00
# 25%                        0.00
# 50%                        0.00
# 75%                        0.00
# max                        1.00
#
#        Outlet_Identifier_OUT027  \
# count                    2131.0
# mean                        0.1
# std                         0.3
# min                         0.0
# 25%                         0.0
# 50%                         0.0
# 75%                         0.0
# max                         1.0
#
#        Outlet_Identifier_OUT035  \
# count                    2131.0
# mean                        0.1
# std                         0.3
# min                         0.0
# 25%                         0.0
# 50%                         0.0
# 75%                         0.0
# max                         1.0
#
#        Outlet_Identifier_OUT045  \
# count                   2131.00
# mean                       0.11
# std                        0.31
# min                        0.00
# 25%                        0.00
# 50%                        0.00
# 75%                        0.00
# max                        1.00
#
#        Outlet_Identifier_OUT046  \
# count                   2131.00
# mean                       0.11
# std                        0.31
# min                        0.00
# 25%                        0.00
# 50%                        0.00
# 75%                        0.00
# max                        1.00
#
#        Outlet_Identifier_OUT049  \
# count                   2131.00
# mean                       0.12
# std                        0.32
# min                        0.00
# 25%                        0.00
# 50%                        0.00
# 75%                        0.00
# max                        1.00
#
#        Outlet_Size_High  \
# count           2131.00
# mean               0.11
# std                0.32
# min                0.00
# 25%                0.00
# 50%                0.00
# 75%                0.00
# max                1.00
#
#        Outlet_Size_Medium  \
# count             2131.00
# mean                 0.32
# std                  0.47
# min                  0.00
# 25%                  0.00
# 50%                  0.00
# 75%                  1.00
# max                  1.00
#
#        Outlet_Size_Small  \
# count            2131.00
# mean                0.28
# std                 0.45
# min                 0.00
# 25%                 0.00
# 50%                 0.00
# 75%                 1.00
# max                 1.00
#
#        Outlet_Size_Unknown  \
# count              2131.00
# mean                  0.28
# std                   0.45
# min                   0.00
# 25%                   0.00
# 50%                   0.00
# 75%                   1.00
# max                   1.00
#
#        Outlet_Location_Type_Tier 1  \
# count                      2131.00
# mean                          0.30
# std                           0.46
# min                           0.00
# 25%                           0.00
# 50%                           0.00
# 75%                           1.00
# max                           1.00
#
#        Outlet_Location_Type_Tier 2  \
# count                      2131.00
# mean                          0.32
# std                           0.47
# min                           0.00
# 25%                           0.00
# 50%                           0.00
# 75%                           1.00
# max                           1.00
#
#        Outlet_Location_Type_Tier 3  \
# count                      2131.00
# mean                          0.38
# std                           0.49
# min                           0.00
# 25%                           0.00
# 50%                           0.00
# 75%                           1.00
# max                           1.00
#
#        Outlet_Type_Grocery Store  \
# count                    2131.00
# mean                        0.13
# std                         0.34
# min                         0.00
# 25%                         0.00
# 50%                         0.00
# 75%                         0.00
# max                         1.00
#
#        Outlet_Type_Supermarket Type1  \
# count                        2131.00
# mean                            0.66
# std                             0.47
# min                             0.00
# 25%                             0.00
# 50%                             1.00
# 75%                             1.00
# max                             1.00
#
#        Outlet_Type_Supermarket Type2  \
# count                        2131.00
# mean                            0.11
# std                             0.31
# min                             0.00
# 25%                             0.00
# 50%                             0.00
# 75%                             0.00
# max                             1.00
#
#        Outlet_Type_Supermarket Type3
# count                         2131.0
# mean                             0.1
# std                              0.3
# min                              0.0
# 25%                              0.0
# 50%                              0.0
# 75%                              0.0
# max                              1.0

# %% [markdown]
# ---

# %% [markdown]
# ## **Machine Learnng Models**

# %% [markdown]
# ### **Metric Function**

# %%
# Create a dataframe to store model performaance metrics
model_metrics_df =pd.DataFrame()

# %%
# Create a function to take the true and predicted values
# and print MAE, MSE, RMSE, and R2 metrics
def evaluation_model(pipe, model_name='', params=None):
  # Train
  mae = round(mean_absolute_error(y_train, pipe.predict(X_train)),3)
  model_metrics_df.loc[model_name, 'Train MAE'] = mae
  mse = round(mean_squared_error(y_train, pipe.predict(X_train)),3)
  model_metrics_df.loc[model_name, 'Train MSE'] = mse
  rmse = round(np.sqrt(mean_squared_error(y_train, pipe.predict(X_train))),3)
  model_metrics_df.loc[model_name, 'Train RMSE'] = rmse
  r2 = round(r2_score(y_train, pipe.predict(X_train)),7)
  model_metrics_df.loc[model_name, 'Train R2'] = r2
  print(f'{model_name} Train Scores')
  print(f'MAE: {mae:,.2f} \nMSE: {mse:,.2f} \nRMSE: {rmse:,.2f} \nR2: {r2:.4f}\n')

  # Test
  mae = round(mean_absolute_error(y_test, pipe.predict(X_test)),2)
  model_metrics_df.loc[model_name, 'Test MAE'] = round(mae, 2)
  mse = round(mean_squared_error(y_test, pipe.predict(X_test)),2)
  model_metrics_df.loc[model_name, 'Test MSE'] = round(mse, 2)
  rmse = round(np.sqrt(mean_squared_error(y_test, pipe.predict(X_test))),2)
  model_metrics_df.loc[model_name, 'Test RMSE'] = round(rmse, 2)
  r2 = round(r2_score(y_test, pipe.predict(X_test)),7)
  model_metrics_df.loc[model_name, 'Test R2'] = r2
  print(f'{model_name} Test Scores')
  print(f'MAE: {mae:,.2f} \nMSE: {mse:,.2f} \nRMSE: {rmse:,.2f} \nR2: {r2:.4f}\n')

# %% [markdown]
# ### **Baseline Model**

# %%
# Make an instance of the model
dummy = DummyRegressor(strategy='mean')
# Make a model pipeline
dummy_pipe = make_pipeline(preprocessor, dummy)
# Fit the model
dummy_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x000001B2C8018BE0>),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehotencoder',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse=False))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x000001B2C7F96250>)])),
#                 ('dummyregressor', DummyRegressor())])

# %%
# Display model performance metrics
evaluation_model(pipe=dummy_pipe, model_name='Dummy Model')
# Out:
# Dummy Model Train Scores
# MAE: 1,360.22
# MSE: 2,959,455.71
# RMSE: 1,720.31
# R2: 0.0000
#
# Dummy Model Test Scores
# MAE: 1,326.12
# MSE: 2,772,144.46
# RMSE: 1,664.98
# R2: -0.0048

# %% [markdown]
# ### **Linear Regression with Elastic Net Model**

# %%
# Make an instance of the model
el_net_reg = ElasticNet(random_state=42)
# Make a model pipeline
el_net_reg_pipe = make_pipeline(preprocessor, el_net_reg)
# Fit the model
el_net_reg_pipe.fit(X_train, y_train)

# %%
# Display model performance metrics
evaluation_model(pipe=el_net_reg_pipe, model_name='Linear Regression with Elastic Net Model')

# %%
# Looking at options for tuning this model
el_net_reg.get_params()

# %%
# Create dictionary of hyperparamters to test
param_grid = {'elasticnet__alpha': [0.01, 0.1, 1, 3, 3.25, 3.5, 4.0, 10, 100, 1000],
              'elasticnet__l1_ratio': [0.95, 0.96, 0.97, 0.98, 0.99, 1],
              'elasticnet__max_iter': [100000]}

# %%
# Make an instance of the model
grid_pipe = GridSearchCV(el_net_reg_pipe, param_grid)

# %%
# Fit the model
grid_pipe.fit(X_train, y_train)

# %%
grid_pipe.best_params_

# %%
el_net_reg_pipe = grid_pipe.best_estimator_

# %%
# Display model performance metrics
evaluation_model(pipe=el_net_reg_pipe, model_name ='Linear Regression with Elastic Net Model')

# %% [markdown]
# ### **Decision Tree Model**

# %%
# Make an instance of the model
dec_tree = DecisionTreeRegressor(random_state = 42)
# Make a model pipeline
dec_tree_pipe = make_pipeline(no_scaling_preprocessor, dec_tree)
# Fit the model
dec_tree_pipe.fit(X_train, y_train)

# %%
# Display model performance metrics
evaluation_model(pipe=dec_tree_pipe, model_name='Decision Tree Model')

# %% [markdown]
# The evaluation metric used here is the R2.  It  should be clear that the default decision tree had a much higher R2 score on the training data than it did on the test data.  This is an indication that there is extremely high variance and the model is overfit.

# %%
# Looking at options for tuning this model
dec_tree.get_params()

# %%
# What was the depth of our default tree?
dec_tree.get_depth()

# %% [markdown]
# We see that our tree had a depth of 62.
#
# We can also see how many leaf nodes our tree had.

# %%
# How many leaf nodes?
dec_tree.get_n_leaves()

# %% [markdown]
# First, lets try a few options to see how changing this parameter affects our model.

# %%
# High bias underfit model 
# Make an instance of the model
dec_tree = DecisionTreeRegressor(max_depth=2, random_state = 42)
# Make a model pipeline
dec_tree_pipe = make_pipeline(no_scaling_preprocessor, dec_tree)
# Fit the model
dec_tree_pipe.fit(X_train, y_train)

# %%
# Display model performance metrics
evaluation_model(pipe=dec_tree_pipe, model_name='Decision Tree Model')

# %%
# List of values to try for max_depth:
max_depth_range = list(range(2, 20)) # will try every value between 2 and 20
# List to store the score for each value of max_depth:
train_r2 = []
test_r2 = []
for depth in max_depth_range:
    dec_tree = DecisionTreeRegressor(max_depth = depth, 
                             random_state = 42)
    dec_tree_pipe = make_pipeline(no_scaling_preprocessor, dec_tree)
    dec_tree_pipe.fit(X_train, y_train)
    train_score = dec_tree_pipe.score(X_train, y_train)
    test_score = dec_tree_pipe.score(X_test, y_test)
    train_r2.append(train_score)
    test_r2.append(test_score)

# %% [markdown]
# To help us see the results of trying various tree depths, the following code creates a visualization of R2 vs max_depth.

# %%
# Visualize which max_depth leads to the highest r2 score
plt.plot(max_depth_range, train_r2)
plt.plot(max_depth_range, test_r2)
plt.xlabel('max_depth')
plt.ylabel('R2');

# %% [markdown]
# From the image above, it looks like the best score for the model is when the parameter max_depth is 5.

# %%
# Make an instance of the model
dec_tree = DecisionTreeRegressor(max_depth=5, random_state = 42)
# Make a model pipeline
dec_tree_pipe = make_pipeline(no_scaling_preprocessor, dec_tree)
# Fit the model
dec_tree_pipe.fit(X_train, y_train)

# %%
# Display model performance metrics
evaluation_model(pipe=dec_tree_pipe, model_name='Decision Tree Model')

# %%
# Make an instance of the model
dec_tree = DecisionTreeRegressor(random_state = 42)
# Make a model pipeline
dec_tree_pipe = make_pipeline(no_scaling_preprocessor, dec_tree)
# Fit the model
dec_tree_pipe.fit(X_train, y_train)

# %%
# Create dictionary of hyperparamters to test
param_grid = {'decisiontreeregressor__max_depth': range(2,10),
              'decisiontreeregressor__min_samples_leaf': range(2,50),
              'decisiontreeregressor__min_samples_split': range(2,5)}

# %%
# Make an instance of the model
grid_pipe = GridSearchCV(dec_tree_pipe, param_grid)

# %%
# Fit the model
grid_pipe.fit(X_train, y_train)

# %%
grid_pipe.best_params_

# %%
dec_tree_pipe = grid_pipe.best_estimator_

# %%
# Display model performance metrics
evaluation_model(pipe=dec_tree_pipe, model_name='Decision Tree Model')

# %% [markdown]
# ### **Bagged Tree Model**

# %%
# Make an instance of the model
bag_tree = BaggingRegressor(random_state = 42)
# Make a model pipeline
bag_tree_pipe = make_pipeline(no_scaling_preprocessor, bag_tree)
# Fit the model
bag_tree_pipe.fit(X_train, y_train)

# %%
# Display model performance metrics
evaluation_model(pipe=bag_tree_pipe, model_name='Bagged Tree Model')

# %%
# Look at the hyperparameters
bag_tree.get_params()

# %%
# List of estimator values
estimators = [10, 50, 100, 120, 140, 160, 180, 200]
# Data frame to store the scores
scores = pd.DataFrame(index=estimators, columns=['Train Score', 'Test Score'])
# Iterate through the values to find the best number of estimators
for num_estimators in estimators:
   bag_tree = BaggingRegressor(n_estimators=num_estimators, random_state=42)
   bag_tree_pipe = make_pipeline(no_scaling_preprocessor, bag_tree)
   bag_tree_pipe.fit(X_train, y_train)
   train_score = bag_tree_pipe.score(X_train, y_train)
   test_score = bag_tree_pipe.score(X_test, y_test)
   scores.loc[num_estimators, 'Train Score'] = train_score
   scores.loc[num_estimators, 'Test Score'] = test_score

# %%
# Plot the scores
plt.plot(scores['Test Score'])
plt.plot(scores['Train Score'])
plt.show()

# %%
# Sort by test score
scores = scores.sort_values(by='Test Score', ascending=False)
scores.head(10)

# %%
# Make an instance of the model
bag_tree = BaggingRegressor(n_estimators=120, random_state = 42)
# Make a model pipeline
bag_tree_pipe = make_pipeline(no_scaling_preprocessor, bag_tree)
# Fit the model
bag_tree_pipe.fit(X_train, y_train)

# %%
# Display model performance metrics
evaluation_model(pipe=bag_tree_pipe, model_name='Bagged Tree Model')

# %%
# Create dictionary of hyperparamters to test
param_grid = {'baggingregressor__n_estimators': range(110,131,2)}

# %%
# Make an instance of the model
grid_pipe = GridSearchCV(bag_tree_pipe, param_grid)

# %%
# Fit the model
grid_pipe.fit(X_train, y_train)

# %%
grid_pipe.best_params_

# %%
bag_tree_pipe = grid_pipe.best_estimator_

# %%
# Display model performance metrics
evaluation_model(pipe=bag_tree_pipe, model_name='Bagged Tree Model')

# %% [markdown]
# ### **Support Vector Machine Regression Model**

# %%
# Make an instance of the model
sup_vec_mac_reg = LinearSVR(random_state=42)
# Make a model pipeline
sup_vec_mac_reg_pipe = make_pipeline(preprocessor, sup_vec_mac_reg)
# Fit the model
sup_vec_mac_reg_pipe.fit(X_train, y_train)

# %%
# Display model performance metrics
evaluation_model(pipe=sup_vec_mac_reg_pipe, model_name='Support Vector Machine Regression Model')

# %%
# Looking at options for tuning this model
sup_vec_mac_reg.get_params()

# %%
# Create dictionary of hyperparamters to test
param_grid = {'linearsvr__C': [1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200],
              'linearsvr__max_iter': [10000],
              'linearsvr__tol': [0.0001, 0.001, 0.01, .1, 1]}

# %%
# Make an instance of the model
grid_pipe = GridSearchCV(sup_vec_mac_reg_pipe, param_grid)

# %%
# Fit the model
grid_pipe.fit(X_train, y_train)

# %%
grid_pipe.best_params_

# %%
las_reg_pipe = grid_pipe.best_estimator_

# %%
# Display model performance metrics
evaluation_model(pipe=sup_vec_mac_reg_pipe, model_name='Support Vector Machine Regression Model')

# %% [markdown]
# ### **K Nearest Neighbors Model**

# %%
# Make an instance of the model
knn = KNeighborsRegressor()
# Make a model pipeline
knn_pipe = make_pipeline(preprocessor, knn)
# Fit the model
knn_pipe.fit(X_train, y_train)

# %%
# Display model performance metrics
evaluation_model(pipe=knn_pipe, model_name='K Nearest Neighbors Model')

# %%
# Look at the hyperparameters
knn.get_params()

# %%
# Create dictionary of hyperparamters to test
param_grid = {'kneighborsregressor__n_neighbors': range(1,50),
              'kneighborsregressor__leaf_size': [5, 10, 15, 20, 25, 30, 35, 40, 50]}

# %%
# Make an instance of the model
grid_pipe = GridSearchCV(knn_pipe, param_grid)

# %%
# Fit the model
grid_pipe.fit(X_train, y_train)

# %%
grid_pipe.best_params_

# %%
knn_pipe = grid_pipe.best_estimator_

# %%
# Display model performance metrics
evaluation_model(pipe=knn_pipe, model_name='K Nearest Neighbors Model')

# %% [markdown]
# ### **Random Forest Model**

# %%
# Make an instance of the model
ran_for = RandomForestRegressor(random_state=42)
# Make a model pipeline
ran_for_pipe = make_pipeline(no_scaling_preprocessor, ran_for)
# Fit the model
ran_for_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='median'))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x000001B2C8018BE0>),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehotencoder',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse=False))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x000001B2C7F96250>)])),
#                 ('randomforestregressor',
#                  RandomForestRegressor(random_state=42))])

# %%
# Display model performance metrics
evaluation_model(pipe=ran_for_pipe, model_name='Random Forest Model')
# Out:
# Random Forest Model Train Scores
# MAE: 297.96
# MSE: 184,909.78
# RMSE: 430.01
# R2: 0.9375
#
# Random Forest Model Test Scores
# MAE: 768.25
# MSE: 1,228,803.40
# RMSE: 1,108.51
# R2: 0.5546

# %%
# Looking at some hyperparameters that seem tunable
ran_for.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': 1.0,
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 42,
#  'verbose': 0,
#  'warm_start': False}

# %%
est_depths = [estimator.get_depth() for estimator in ran_for.estimators_]
max(est_depths)
# Out:
# 87

# %%
depths = range(1, max(est_depths))
scores = pd.DataFrame(index=depths, columns=['Test Score'])
for depth in depths:    
   ran_for = RandomForestRegressor(max_depth=depth, random_state=42)
   ran_for_pipe = make_pipeline(no_scaling_preprocessor, ran_for)
   ran_for_pipe.fit(X_train, y_train)
   scores.loc[depth, 'Train Score'] = ran_for_pipe.score(X_train, y_train)
   scores.loc[depth, 'Test Score'] = ran_for_pipe.score(X_test, y_test)

# %%
# Plot the scores
plt.plot(scores['Test Score'])
plt.plot(scores['Train Score'])
plt.show()

# %%
# Make an instance of the model
ran_for = RandomForestRegressor(max_depth=5, random_state=42)
# Make a model pipeline
ran_for_pipe = make_pipeline(no_scaling_preprocessor, ran_for)
# Fit the model
ran_for_pipe.fit(X_train, y_train)

# %%
# Display model performance metrics
evaluation_model(pipe=ran_for_pipe, model_name='Random Forest Model')

# %%
# Looking at some hyperparameters that seem tunable
ran_for.get_params()

# %%
# Create dictionary of hyperparamters to test
param_grid = {'randomforestregressor__n_estimators': range(80,95),
               'randomforestregressor__max_depth': [4, 5, 6],
               'randomforestregressor__min_samples_split': [2, 3]}

# %%
# Make an instance of the model
grid_pipe = GridSearchCV(ran_for_pipe, param_grid)

# %%
# Fit the model
grid_pipe.fit(X_train, y_train)

# %%
grid_pipe.best_params_

# %%
ran_for_pipe = grid_pipe.best_estimator_

# %%
# Display model performance metrics
evaluation_model(pipe=ran_for_pipe, model_name='Random Forest Model')

# %% [markdown]
# ### **Gradient Boost Model**

# %%
# Make an instance of the model
gra_bst_reg = GradientBoostingRegressor()
# Make a model pipeline
gra_bst_reg_pipe = make_pipeline(preprocessor, gra_bst_reg)
# Fit the model
gra_bst_reg_pipe.fit(X_train, y_train)

# %%
# Display model performance metrics
evaluation_model(pipe=gra_bst_reg_pipe, model_name='Gradient Boost Regression Model')

# %% [markdown]
# ### **Light Gradient Boosted Machine Model**

# %%
# Make an instance of the model
lt_gra_bst_reg = LGBMRegressor()
# Make a model pipeline
lt_gra_bst_reg_pipe = make_pipeline(preprocessor, lt_gra_bst_reg)
# Fit the model
lt_gra_bst_reg_pipe.fit(X_train, y_train)

# %%
# Display model performance metrics
evaluation_model(pipe=lt_gra_bst_reg_pipe, model_name='Light Gradient Boost Regression Model')

# %% [markdown]
# ### **Extreme Gradient Boosted Machine Model**

# %%
# Make an instance of the model
x_gra_bst_reg = XGBRegressor()
# Make a model pipeline
x_gra_bst_reg_pipe = make_pipeline(preprocessor, x_gra_bst_reg)
# Fit the model
x_gra_bst_reg_pipe.fit(X_train, y_train)

# %%
# Display model performance metrics
evaluation_model(pipe=x_gra_bst_reg_pipe, model_name='eXtreme Gradient Boost Regression Model')

# %% [markdown]
# ## **Model Performance Comparison**

# %%
model_metrics_df.style.format({"Train MAE":  "${:20,.2f}", 
                               "Train MSE":  "${:20,.2f}", 
                               "Train RMSE": "${:20,.2f}",
                               "Train R2":   "{:.4%}",
                               "Test MAE":   "${:20,.2f}",
                               "Test MSE":   "${:20,.2f}",
                               "Test RMSE":  "${:20,.2f}",
                               "Test R2":    "{:.4%}"})
#.background_gradient()
# subset
# bar() 
# dataframe image

# %%
# Display line plot of scores
fig, ax = plt.subplots(nrows=1, figsize=(12,8), facecolor='w')
ax.set_facecolor('lightblue')
plt.title('Model Performnce', fontsize = 22, weight='bold')

sns.lineplot(data=model_metrics_df['Train R2'], color="indigo", linewidth=3, markersize=10, marker='o', label='Train');
sns.lineplot(data=model_metrics_df['Test R2'], color="magenta", linewidth=3, markersize=10, marker='o', label='Test');

plt.xlabel('', fontsize = 16, weight='bold')
plt.xticks(weight='bold', rotation=45, ha='right')

           
ax.set_ylabel('R2 Score', fontweight='bold', fontsize=16)
plt.yticks(weight='bold')
ax.set_ylim(-.10, 1.0)

ax.tick_params(labelcolor='k', labelsize=12)

for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(3);
    
format = StrMethodFormatter('{x:.4f}') 
ax.yaxis.set_major_formatter(format);

plt.tight_layout()
plt.show;

# %%
# Display line plot of scores
fig, ax = plt.subplots(nrows=1, figsize=(12,8), facecolor='w')
ax.set_facecolor('lightblue')
plt.title('Model Performnce', fontsize = 22, weight='bold')

sns.lineplot(data=model_metrics_df['Train RMSE'], color="indigo", linewidth=3, markersize=10, marker='o', label='Train');
sns.lineplot(data=model_metrics_df['Test RMSE'], color="magenta", linewidth=3, markersize=10, marker='o', label='Test');

plt.xlabel('', fontsize = 16, weight='bold')
plt.xticks(weight='bold', rotation=45, ha='right')

ax.set_ylabel('RMSE', fontweight='bold', fontsize=16)
plt.yticks(weight='bold')
ax.set_ylim(200, 2000)

ax.tick_params(labelcolor='k', labelsize=12)

for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(3);
    
format = StrMethodFormatter('${x:,.2f}') 
ax.yaxis.set_major_formatter(format);

plt.tight_layout()
plt.show;

# %% [markdown]
# ## **Feature Importance**

# %%
# # Random Forest Model Feature Importance
# coefs = ran_for_pipe.named_steps['randomforestregressor'].feature_importances_
# importance = pd.Series(coefs, index = final_cols)
# importance.sort_values(ascending = False) * 100
# Out:
# Item_MRP                           4.004791e+01
# Outlet_Type_Grocery Store          1.917298e+01
# Item_Visibility                    5.623958e+00
# Item_Weight                        3.976751e+00
# Outlet_Type_Supermarket Type3      3.815063e+00
# Outlet_Identifier_OUT027           2.722959e+00
# Outlet_Establishment_Year          2.322251e+00
# Item_Type_Snack Foods              3.827945e-01
# Item_Type_Fruits and Vegetables    3.606228e-01
# Outlet_Identifier_OUT035           3.552700e-01
# Outlet_Identifier_OUT045           3.520645e-01
# Outlet_Size_Small                  3.452748e-01
# Item_Type_Frozen Foods             3.066174e-01
# Outlet_Identifier_OUT046           2.985744e-01
# Item_Type_Household                2.899362e-01
# Outlet_Location_Type_Tier 1        2.838967e-01
# Item_Type_Dairy                    2.807325e-01
# Outlet_Size_Medium                 2.786473e-01
# Item_Fat_Content_Low Fat           2.775077e-01
# Outlet_Location_Type_Tier 2        2.774335e-01
# Outlet_Identifier_OUT017           2.729311e-01
# Outlet_Size_Unknown                2.666234e-01
# Outlet_Identifier_OUT049           2.638768e-01
# Item_Fat_Content_Regular           2.625693e-01
# Outlet_Location_Type_Tier 3        2.444220e-01
# Item_Identifier_FDQ19              2.335424e-01
# Item_Type_Soft Drinks              2.249752e-01
# Item_Type_Canned                   2.016045e-01
# Item_Identifier_NCE42              1.913157e-01
# Item_Type_Baking Goods             1.820303e-01
# Item_Type_Starchy Foods            1.812820e-01
# Outlet_Size_High                   1.734654e-01
# Item_Type_Health and Hygiene       1.671832e-01
# Item_Type_Hard Drinks              1.666400e-01
# Item_Identifier_FDZ20              1.652915e-01
# Item_Type_Meat                     1.592192e-01
# Outlet_Type_Supermarket Type1      1.591608e-01
# Item_Type_Breakfast                1.587339e-01
# Outlet_Identifier_OUT013           1.571538e-01
# Item_Identifier_FDF39              1.471007e-01
# Item_Identifier_FDR45              1.409519e-01
# Item_Identifier_NCM05              1.269136e-01
# Item_Identifier_FDA21              1.176650e-01
# Outlet_Identifier_OUT018           1.163010e-01
# Item_Type_Breads                   1.159924e-01
# Outlet_Type_Supermarket Type2      1.054555e-01
# Item_Identifier_FDW56              1.041398e-01
# Item_Identifier_FDJ15              9.372689e-02
# Item_Identifier_NCH18              8.879924e-02
# Item_Identifier_DRM37              8.770603e-02
# Item_Type_Seafood                  8.716561e-02
# Item_Identifier_NCZ54              8.635440e-02
# Item_Identifier_FDP33              8.573227e-02
# Item_Identifier_FDY55              8.454594e-02
# Item_Identifier_DRB01              8.088375e-02
# Item_Identifier_FDD44              7.919289e-02
# Item_Identifier_FDA15              7.855451e-02
# Item_Identifier_DRE60              7.674372e-02
# Item_Identifier_FDU55              7.527557e-02
# Item_Identifier_FDL39              7.501624e-02
# Item_Identifier_FDO11              7.470910e-02
# Item_Type_Others                   7.470513e-02
# Item_Identifier_DRF36              7.374689e-02
# Item_Identifier_FDR34              7.255885e-02
# Item_Identifier_FDT16              7.181708e-02
# Item_Identifier_FDW26              6.414474e-02
# Item_Identifier_FDI38              6.250495e-02
# Item_Identifier_FDH08              6.176141e-02
# Item_Identifier_FDT48              6.048129e-02
# Item_Identifier_FDB56              5.900667e-02
# Item_Identifier_FDR16              5.817431e-02
# Item_Identifier_FDC47              5.675367e-02
# Item_Identifier_FDJ21              5.628186e-02
# Item_Identifier_NCN26              1.069381e-02
# Item_Identifier_NCK19              1.063811e-02
# Item_Identifier_FDM13              1.063579e-02
# Item_Identifier_FDM56              1.060687e-02
# Item_Identifier_FDY39              1.060241e-02
# Item_Identifier_NCQ41              1.045589e-02
# Item_Identifier_FDE24              1.036588e-02
# Item_Identifier_DRD49              1.033001e-02
# Item_Identifier_FDX22              1.030054e-02
# Item_Identifier_DRN47              1.028523e-02
# Item_Identifier_FDR56              1.027404e-02
# Item_Identifier_FDN15              1.026347e-02
# Item_Identifier_FDC57              1.025700e-02
# Item_Identifier_FDJ57              1.023314e-02
# Item_Identifier_FDD22              1.022700e-02
# Item_Identifier_FDC35              1.013598e-02
# Item_Identifier_FDN01              1.013459e-02
# Item_Identifier_FDU37              1.010707e-02
# Item_Identifier_FDQ12              1.009190e-02
# Item_Identifier_FDN44              1.007323e-02
# Item_Identifier_FDU38              1.005166e-02
# Item_Identifier_FDN60              1.000125e-02
# Item_Identifier_FDW57              9.951731e-03
# Item_Identifier_FDC44              9.885093e-03
# Item_Identifier_FDU07              9.838287e-03
# Item_Identifier_FDH20              9.765301e-03
# Item_Identifier_FDV23              9.703732e-03
# Item_Identifier_FDS58              9.672542e-03
# Item_Identifier_FDB36              9.670375e-03
# Item_Identifier_FDW50              9.654859e-03
# Item_Identifier_FDR15              9.646737e-03
# Item_Identifier_FDD33              9.617470e-03
# Item_Identifier_FDZ03              9.581116e-03
# Item_Identifier_FDB33              9.562173e-03
# Item_Identifier_FDX19              9.532068e-03
# Item_Identifier_DRC36              9.483625e-03
# Item_Identifier_FDL45              9.471006e-03
# Item_Identifier_FDK34              9.460704e-03
# Item_Identifier_NCB31              9.434614e-03
# Item_Identifier_NCR17              9.414391e-03
# Item_Identifier_NCN14              9.406563e-03
# Item_Identifier_FDK44              9.402741e-03
# Item_Identifier_FDX26              9.377946e-03
# Item_Identifier_FDV12              9.374742e-03
# Item_Identifier_NCU42              9.374338e-03
# Item_Identifier_FDU26              9.318182e-03
# Item_Identifier_FDN56              9.251113e-03
# Item_Identifier_FDO44              9.227069e-03
# Item_Identifier_FDB02              9.202913e-03
# Item_Identifier_NCU54              9.193754e-03
# Item_Identifier_FDB23              9.185715e-03
# Item_Identifier_DRA24              9.027260e-03
# Item_Identifier_NCS17              8.973117e-03
# Item_Identifier_FDY51              8.970354e-03
# Item_Identifier_NCS05              8.917688e-03
# Item_Identifier_FDS36              8.912994e-03
# Item_Identifier_FDS16              8.903229e-03
# Item_Identifier_FDT11              8.877057e-03
# Item_Identifier_NCH42              8.876224e-03
# Item_Identifier_FDS08              8.843890e-03
# Item_Identifier_DRL11              8.824923e-03
# Item_Identifier_FDY49              8.822789e-03
# Item_Identifier_FDZ60              8.822210e-03
# Item_Identifier_FDS12              8.768752e-03
# Item_Identifier_FDZ25              8.728292e-03
# Item_Identifier_FDF29              8.696306e-03
# Item_Identifier_NCL53              8.695112e-03
# Item_Identifier_FDS59              8.650671e-03
# Item_Identifier_FDS10              8.641551e-03
# Item_Identifier_FDX33              8.614219e-03
# Item_Identifier_FDB53              4.828212e-03
# Item_Identifier_FDB22              4.811645e-03
# Item_Identifier_FDR33              4.796191e-03
# Item_Identifier_NCC31              4.790666e-03
# Item_Identifier_FDO57              4.769234e-03
# Item_Identifier_FDO56              4.765782e-03
# Item_Identifier_FDD35              4.746667e-03
# Item_Identifier_DRM59              4.745854e-03
# Item_Identifier_FDY32              4.735340e-03
# Item_Identifier_FDS11              4.702939e-03
# Item_Identifier_FDV22              4.699603e-03
# Item_Identifier_FDU23              4.696519e-03
# Item_Identifier_NCV05              4.696337e-03
# Item_Identifier_FDS13              4.687024e-03
# Item_Identifier_FDN32              4.672362e-03
# Item_Identifier_FDM03              4.671526e-03
# Item_Identifier_FDE39              4.643540e-03
# Item_Identifier_FDW47              4.618773e-03
# Item_Identifier_FDM14              4.617024e-03
# Item_Identifier_FDC48              4.592991e-03
# Item_Identifier_FDL25              4.584581e-03
# Item_Identifier_FDQ45              4.577552e-03
# Item_Identifier_FDB05              4.569980e-03
# Item_Identifier_DRH37              4.566212e-03
# Item_Identifier_DRG15              4.563907e-03
# Item_Identifier_NCL18              4.563438e-03
# Item_Identifier_FDK32              4.555817e-03
# Item_Identifier_FDZ55              4.551519e-03
# Item_Identifier_FDA37              4.548560e-03
# Item_Identifier_FDY13              4.473618e-03
# Item_Identifier_FDA25              4.458579e-03
# Item_Identifier_FDN40              4.431337e-03
# Item_Identifier_NCT05              4.393033e-03
# Item_Identifier_FDO27              4.385351e-03
# Item_Identifier_NCH55              4.378568e-03
# Item_Identifier_FDZ14              4.375063e-03
# Item_Identifier_FDX35              4.341972e-03
# Item_Identifier_FDS32              4.336101e-03
# Item_Identifier_FDM01              4.312182e-03
# Item_Identifier_FDN08              4.308033e-03
# Item_Identifier_FDQ21              4.293456e-03
# Item_Identifier_FDJ41              4.284876e-03
# Item_Identifier_FDH60              4.280581e-03
# Item_Identifier_FDR03              4.272239e-03
# Item_Identifier_FDB58              4.267787e-03
# Item_Identifier_FDA55              4.244958e-03
# Item_Identifier_FDZ39              4.232090e-03
# Item_Identifier_FDI19              4.230618e-03
# Item_Identifier_DRI25              4.212722e-03
# Item_Identifier_FDG33              4.205329e-03
# Item_Identifier_FDJ36              4.183368e-03
# Item_Identifier_FDR39              4.150437e-03
# Item_Identifier_DRJ39              4.138145e-03
# Item_Identifier_FDH27              4.108377e-03
# Item_Identifier_FDT25              4.107046e-03
# Item_Identifier_FDD56              4.099389e-03
# Item_Identifier_FDY21              4.079209e-03
# Item_Identifier_FDR40              4.065020e-03
# Item_Identifier_NCN42              4.061357e-03
# Item_Identifier_NCM29              4.059278e-03
# Item_Identifier_FDH31              4.049119e-03
# Item_Identifier_FDQ46              4.043429e-03
# Item_Identifier_FDX46              4.042475e-03
# Item_Identifier_DRD13              4.036309e-03
# Item_Identifier_FDP10              4.036156e-03
# Item_Identifier_NCB54              4.034164e-03
# Item_Identifier_FDG53              4.033037e-03
# Item_Identifier_NCA41              4.018407e-03
# Item_Identifier_FDU04              4.005684e-03
# Item_Identifier_DRG37              3.992079e-03
# Item_Identifier_FDK41              3.983534e-03
# Item_Identifier_FDT09              3.982896e-03
# Item_Identifier_FDZ35              3.977214e-03
# Item_Identifier_FDJ53              3.963812e-03
# Item_Identifier_NCA54              3.963765e-03
# Item_Identifier_FDE05              3.949152e-03
# Item_Identifier_FDV35              3.928359e-03
# Item_Identifier_NCC54              3.925329e-03
# Item_Identifier_NCK18              3.917760e-03
# Item_Identifier_NCX17              3.911179e-03
# Item_Identifier_FDU56              3.910530e-03
# Item_Identifier_FDH17              3.904107e-03
# Item_Identifier_NCJ43              3.882584e-03
# Item_Identifier_FDR19              3.878997e-03
# Item_Identifier_FDU47              3.864854e-03
# Item_Identifier_FDV49              3.861459e-03
# Item_Identifier_FDZ28              3.842924e-03
# Item_Identifier_FDX08              3.821705e-03
# Item_Identifier_NCU17              3.810055e-03
# Item_Identifier_FDF57              3.808577e-03
# Item_Identifier_DRD15              3.788322e-03
# Item_Identifier_NCK07              3.752747e-03
# Item_Identifier_NCA42              3.742950e-03
# Item_Identifier_FDW36              3.722238e-03
# Item_Identifier_FDQ57              3.710007e-03
# Item_Identifier_FDW44              3.705567e-03
# Item_Identifier_FDV09              3.700206e-03
# Item_Identifier_FDR28              3.679127e-03
# Item_Identifier_NCJ31              3.670216e-03
# Item_Identifier_DRF48              3.667465e-03
# Item_Identifier_FDA40              3.664127e-03
# Item_Identifier_FDG08              3.662674e-03
# Item_Identifier_NCC30              3.650534e-03
# Item_Identifier_DRH15              3.646040e-03
# Item_Identifier_FDX57              3.636522e-03
# Item_Identifier_FDU16              3.631338e-03
# Item_Identifier_FDC56              3.621367e-03
# Item_Identifier_FDC04              3.611982e-03
# Item_Identifier_FDU03              3.596980e-03
# Item_Identifier_NCT53              3.580703e-03
# Item_Identifier_FDF20              3.560608e-03
# Item_Identifier_NCX54              3.537280e-03
# Item_Identifier_DRH01              3.528490e-03
# Item_Identifier_NCH54              3.514685e-03
# Item_Identifier_FDU40              3.508934e-03
# Item_Identifier_FDO19              3.503806e-03
# Item_Identifier_FDU46              3.496167e-03
# Item_Identifier_FDI09              3.489776e-03
# Item_Identifier_DRZ11              3.485442e-03
# Item_Identifier_FDE26              3.475314e-03
# Item_Identifier_NCQ43              3.438387e-03
# Item_Identifier_DRG13              3.432540e-03
# Item_Identifier_FDD50              3.429211e-03
# Item_Identifier_NCU05              3.378418e-03
# Item_Identifier_FDA31              3.358601e-03
# Item_Identifier_FDU31              3.358176e-03
# Item_Identifier_NCZ17              3.354024e-03
# Item_Identifier_FDZ19              3.339209e-03
# Item_Identifier_FDX01              3.337636e-03
# Item_Identifier_FDV25              3.333421e-03
# Item_Identifier_NCA17              3.329723e-03
# Item_Identifier_FDB34              3.314953e-03
# Item_Identifier_FDK45              3.296152e-03
# Item_Identifier_FDW39              3.292768e-03
# Item_Identifier_FDI16              3.287701e-03
# Item_Identifier_NCH29              3.277810e-03
# Item_Identifier_FDB38              3.271974e-03
# Item_Identifier_FDT28              3.271255e-03
# Item_Identifier_NCA29              3.255289e-03
# Item_Identifier_FDD34              3.227301e-03
# Item_Identifier_DRM23              3.219400e-03
# Item_Identifier_FDA07              3.196724e-03
# Item_Identifier_FDO39              3.173949e-03
# Item_Identifier_FDB60              3.171268e-03
# Item_Identifier_FDD40              3.153037e-03
# Item_Identifier_DRJ23              3.139028e-03
# Item_Identifier_DRH49              3.131565e-03
# Item_Identifier_NCS29              3.127283e-03
# Item_Identifier_FDS33              3.117533e-03
# Item_Identifier_DRI59              3.110714e-03
# Item_Identifier_NCJ19              3.107637e-03
# Item_Identifier_FDB47              3.103672e-03
# Item_Identifier_NCB07              3.098061e-03
# Item_Identifier_NCO05              3.085328e-03
# Item_Identifier_FDW13              3.083711e-03
# Item_Identifier_FDX11              3.050720e-03
# Item_Identifier_FDS02              3.040479e-03
# Item_Identifier_NCX06              3.034437e-03
# Item_Identifier_FDN39              3.032018e-03
# Item_Identifier_FDA28              3.030277e-03
# Item_Identifier_FDH50              3.029970e-03
# Item_Identifier_DRI13              3.023429e-03
# Item_Identifier_FDW09              3.009070e-03
# Item_Identifier_DRE37              2.992251e-03
# Item_Identifier_FDV60              2.989353e-03
# Item_Identifier_FDP19              2.985552e-03
# Item_Identifier_FDN04              2.977608e-03
# Item_Identifier_DRM11              2.976714e-03
# Item_Identifier_FDD05              2.974808e-03
# Item_Identifier_FDP09              2.969082e-03
# Item_Identifier_FDS37              2.927549e-03
# Item_Identifier_FDS28              2.927432e-03
# Item_Identifier_FDD38              2.923095e-03
# Item_Identifier_DRP47              2.919914e-03
# Item_Identifier_NCL06              2.903021e-03
# Item_Identifier_NCH07              2.896191e-03
# Item_Identifier_FDS03              2.892689e-03
# Item_Identifier_FDB28              2.871427e-03
# Item_Identifier_FDU20              2.868317e-03
# Item_Identifier_FDT15              2.862868e-03
# Item_Identifier_FDM28              2.855445e-03
# Item_Identifier_NCL29              2.853138e-03
# Item_Identifier_FDN13              2.846881e-03
# Item_Identifier_FDE14              2.845792e-03
# Item_Identifier_FDY44              2.837609e-03
# Item_Identifier_FDJ08              2.824409e-03
# Item_Identifier_FDL56              2.802608e-03
# Item_Identifier_FDT08              2.798027e-03
# Item_Identifier_NCZ42              2.794770e-03
# Item_Identifier_FDJ52              2.792877e-03
# Item_Identifier_FDU19              2.791713e-03
# Item_Identifier_NCU06              2.785851e-03
# Item_Identifier_FDO04              2.758802e-03
# Item_Identifier_FDI12              2.749413e-03
# Item_Identifier_NCZ30              2.747590e-03
# Item_Identifier_NCW17              2.743768e-03
# Item_Identifier_FDX07              2.740907e-03
# Item_Identifier_FDZ08              2.740475e-03
# Item_Identifier_NCM06              2.733504e-03
# Item_Identifier_DRF49              2.726257e-03
# Item_Identifier_DRK11              2.716957e-03
# Item_Identifier_FDB08              2.716503e-03
# Item_Identifier_FDJ46              2.706398e-03
# Item_Identifier_FDF26              2.693628e-03
# Item_Identifier_DRL60              2.685316e-03
# Item_Identifier_FDM27              2.675430e-03
# Item_Identifier_FDJ28              2.667046e-03
# Item_Identifier_FDT31              2.665045e-03
# Item_Identifier_FDN27              2.652651e-03
# Item_Identifier_NCV54              2.647626e-03
# Item_Identifier_FDY04              2.634148e-03
# Item_Identifier_FDD14              2.630960e-03
# Item_Identifier_FDZ37              2.626880e-03
# Item_Identifier_FDF28              2.604421e-03
# Item_Identifier_FDO40              2.599723e-03
# Item_Identifier_FDB17              2.581518e-03
# Item_Identifier_FDN50              2.559318e-03
# Item_Identifier_NCO42              2.549276e-03
# Item_Identifier_FDL10              2.548611e-03
# Item_Identifier_NCM17              2.531791e-03
# Item_Identifier_NCD07              2.522665e-03
# Item_Identifier_FDU50              2.500504e-03
# Item_Identifier_FDE10              2.496389e-03
# Item_Identifier_FDR13              2.480055e-03
# Item_Identifier_NCM43              2.467761e-03
# Item_Identifier_FDG04              2.466093e-03
# Item_Identifier_NCV41              2.428216e-03
# Item_Identifier_FDG10              2.418694e-03
# Item_Identifier_NCY53              2.408203e-03
# Item_Identifier_FDN22              2.408047e-03
# Item_Identifier_NCF31              2.404787e-03
# Item_Identifier_FDB46              2.384202e-03
# Item_Identifier_NCN54              2.373004e-03
# Item_Identifier_FDX23              2.370810e-03
# Item_Identifier_FDS57              2.370044e-03
# Item_Identifier_FDW28              2.365518e-03
# Item_Identifier_FDJ60              2.361793e-03
# Item_Identifier_FDC11              2.352178e-03
# Item_Identifier_FDB20              2.343052e-03
# Item_Identifier_NCO17              2.325371e-03
# Item_Identifier_FDO10              2.324774e-03
# Item_Identifier_FDE21              2.312200e-03
# Item_Identifier_NCQ02              2.309357e-03
# Item_Identifier_FDZ33              2.304140e-03
# Item_Identifier_NCZ41              2.300320e-03
# Item_Identifier_DRD25              2.297093e-03
# Item_Identifier_FDY46              2.296413e-03
# Item_Identifier_FDW03              2.290398e-03
# Item_Identifier_FDE52              2.283208e-03
# Item_Identifier_DRI11              2.271374e-03
# Item_Identifier_FDC22              2.256473e-03
# Item_Identifier_FDC51              2.255963e-03
# Item_Identifier_DRC13              2.250967e-03
# Item_Identifier_FDI56              2.237056e-03
# Item_Identifier_FDC05              2.226886e-03
# Item_Identifier_FDY15              2.225168e-03
# Item_Identifier_FDH56              2.224578e-03
# Item_Identifier_FDS52              2.219689e-03
# Item_Identifier_FDI53              2.212111e-03
# Item_Identifier_FDO25              2.204344e-03
# Item_Identifier_NCW06              2.204096e-03
# Item_Identifier_DRA12              2.203531e-03
# Item_Identifier_FDN48              2.196267e-03
# Item_Identifier_NCK29              2.190147e-03
# Item_Identifier_DRD24              2.182722e-03
# Item_Identifier_FDB35              2.181489e-03
# Item_Identifier_FDT03              2.169920e-03
# Item_Identifier_FDZ46              2.155637e-03
# Item_Identifier_NCZ53              2.154676e-03
# Item_Identifier_FDS46              2.152540e-03
# Item_Identifier_NCN43              2.149251e-03
# Item_Identifier_FDW25              2.148895e-03
# Item_Identifier_FDW48              2.147798e-03
# Item_Identifier_FDF12              2.146061e-03
# Item_Identifier_FDV48              2.144536e-03
# Item_Identifier_NCF43              2.135126e-03
# Item_Identifier_FDK22              2.126228e-03
# Item_Identifier_FDK14              2.110710e-03
# Item_Identifier_FDD36              6.564377e-04
# Item_Identifier_DRH23              6.527709e-04
# Item_Identifier_DRC25              6.474505e-04
# Item_Identifier_DRE27              6.459305e-04
# Item_Identifier_FDV55              6.367597e-04
# Item_Identifier_FDT45              6.356423e-04
# Item_Identifier_DRG51              6.340253e-04
# Item_Identifier_FDX27              6.331299e-04
# Item_Identifier_FDR10              6.322801e-04
# Item_Identifier_FDB49              6.289514e-04
# Item_Identifier_FDR57              6.265725e-04
# Item_Identifier_NCP50              6.254468e-04
# Item_Identifier_NCQ38              6.253379e-04
# Item_Identifier_NCY17              6.210924e-04
# Item_Identifier_FDR51              6.198421e-04
# Item_Identifier_FDG31              6.106560e-04
# Item_Identifier_NCO06              6.044351e-04
# Item_Identifier_NCQ17              6.038214e-04
# Item_Identifier_FDD52              6.017706e-04
# Item_Identifier_FDP44              5.970500e-04
# Item_Identifier_NCV30              5.962560e-04
# Item_Identifier_FDC40              5.906606e-04
# Item_Identifier_FDS51              5.844604e-04
# Item_Identifier_FDV58              5.798654e-04
# Item_Identifier_FDP38              5.769893e-04
# Item_Identifier_FDK50              5.769004e-04
# Item_Identifier_FDT23              5.754131e-04
# Item_Identifier_FDF24              5.750188e-04
# Item_Identifier_FDO13              5.733240e-04
# Item_Identifier_DRC49              5.654403e-04
# Item_Identifier_NCG43              5.626977e-04
# Item_Identifier_NCA53              5.619049e-04
# Item_Identifier_FDG52              5.564923e-04
# Item_Identifier_FDL48              5.526177e-04
# Item_Identifier_NCK31              5.498038e-04
# Item_Identifier_FDP37              5.485701e-04
# Item_Identifier_FDO32              5.458039e-04
# Item_Identifier_NCP43              5.344123e-04
# Item_Identifier_NCT42              5.334274e-04
# Item_Identifier_DRE12              5.248105e-04
# Item_Identifier_FDO31              5.232222e-04
# Item_Identifier_FDZ47              5.214338e-04
# Item_Identifier_FDE04              5.210149e-04
# Item_Identifier_FDF02              5.196650e-04
# Item_Identifier_FDK56              5.194896e-04
# Item_Identifier_NCE19              5.132541e-04
# Item_Identifier_FDF17              5.083569e-04
# Item_Identifier_FDG59              5.078614e-04
# Item_Identifier_FDO15              5.072283e-04
# Item_Identifier_DRO59              5.069014e-04
# Item_Identifier_FDF50              5.051720e-04
# Item_Identifier_FDK60              5.026200e-04
# Item_Identifier_NCJ06              4.996582e-04
# Item_Identifier_NCP30              4.974509e-04
# Item_Identifier_FDK08              4.972898e-04
# Item_Identifier_FDZ40              4.918967e-04
# Item_Identifier_NCU30              4.849117e-04
# Item_Identifier_NCI17              4.825031e-04
# Item_Identifier_DRD60              4.820655e-04
# Item_Identifier_FDN25              4.777351e-04
# Item_Identifier_FDP39              4.757478e-04
# Item_Identifier_FDQ51              4.743025e-04
# Item_Identifier_NCD19              4.692005e-04
# Item_Identifier_FDC15              4.664637e-04
# Item_Identifier_FDJ45              4.646922e-04
# Item_Identifier_NCP54              4.645852e-04
# Item_Identifier_FDM34              4.604073e-04
# Item_Identifier_FDX48              4.564587e-04
# Item_Identifier_NCN53              4.542815e-04
# Item_Identifier_FDT43              4.535710e-04
# Item_Identifier_FDR58              4.474343e-04
# Item_Identifier_FDI21              4.468812e-04
# Item_Identifier_FDP40              4.430174e-04
# Item_Identifier_NCL30              4.338336e-04
# Item_Identifier_FDX04              4.331633e-04
# Item_Identifier_NCQ42              4.277417e-04
# Item_Identifier_FDE29              4.277390e-04
# Item_Identifier_FDP56              4.263293e-04
# Item_Identifier_FDQ14              4.260284e-04
# Item_Identifier_FDT50              4.203777e-04
# Item_Identifier_FDP46              4.188993e-04
# Item_Identifier_FDW11              4.187363e-04
# Item_Identifier_FDP03              4.156367e-04
# Item_Identifier_FDE59              4.152677e-04
# Item_Identifier_FDI48              4.142350e-04
# Item_Identifier_FDW60              4.135973e-04
# Item_Identifier_FDY01              4.104141e-04
# Item_Identifier_FDH22              4.048058e-04
# Item_Identifier_FDM50              4.026169e-04
# Item_Identifier_FDE32              3.967361e-04
# Item_Identifier_FDA39              3.925818e-04
# Item_Identifier_DRF03              3.913563e-04
# Item_Identifier_FDK27              3.892628e-04
# Item_Identifier_FDT20              3.862643e-04
# Item_Identifier_FDZ13              3.840070e-04
# Item_Identifier_FDD04              3.822526e-04
# Item_Identifier_FDH24              3.779457e-04
# Item_Identifier_NCT54              3.772598e-04
# Item_Identifier_DRJ35              3.766924e-04
# Item_Identifier_FDJ56              3.714841e-04
# Item_Identifier_FDA49              3.701805e-04
# Item_Identifier_DRY23              3.691739e-04
# Item_Identifier_FDK55              3.669195e-04
# Item_Identifier_FDO60              3.618914e-04
# Item_Identifier_DRG01              3.617578e-04
# Item_Identifier_FDB04              3.564889e-04
# Item_Identifier_FDE09              3.546913e-04
# Item_Identifier_FDG41              3.543954e-04
# Item_Identifier_FDS09              3.522561e-04
# Item_Identifier_NCV17              3.436058e-04
# Item_Identifier_FDK43              3.426112e-04
# Item_Identifier_NCC42              3.415331e-04
# Item_Identifier_FDV28              3.394129e-04
# Item_Identifier_FDT10              3.381503e-04
# Item_Identifier_NCL05              3.294683e-04
# Item_Identifier_FDE40              3.261765e-04
# Item_Identifier_FDF09              3.248992e-04
# Item_Identifier_FDC38              3.232222e-04
# Item_Identifier_FDD41              3.225453e-04
# Item_Identifier_NCR54              3.182871e-04
# Item_Identifier_FDS47              3.162083e-04
# Item_Identifier_FDF08              3.143317e-04
# Item_Identifier_DRE03              3.091606e-04
# Item_Identifier_FDR49              3.037245e-04
# Item_Identifier_DRF51              3.028574e-04
# Item_Identifier_FDA57              3.027957e-04
# Item_Identifier_FDS49              2.945510e-04
# Item_Identifier_FDH09              2.944679e-04
# Item_Identifier_FDT35              2.936543e-04
# Item_Identifier_FDW46              2.828330e-04
# Item_Identifier_FDQ22              2.802648e-04
# Item_Identifier_FDP12              2.795965e-04
# Item_Identifier_FDO49              2.709640e-04
# Item_Identifier_NCJ17              2.655094e-04
# Item_Identifier_FDE51              2.627103e-04
# Item_Identifier_NCW54              2.596762e-04
# Item_Identifier_FDO38              2.540916e-04
# Item_Identifier_NCJ29              2.539847e-04
# Item_Identifier_FDA35              2.539683e-04
# Item_Identifier_FDZ07              2.513710e-04
# Item_Identifier_NCY05              2.495760e-04
# Item_Identifier_NCX53              2.484778e-04
# Item_Identifier_NCI31              2.476982e-04
# Item_Identifier_FDV08              2.441481e-04
# Item_Identifier_FDV24              2.439976e-04
# Item_Identifier_FDS24              2.390688e-04
# Item_Identifier_FDB09              2.386448e-04
# Item_Identifier_FDU11              2.333615e-04
# Item_Identifier_NCL07              2.331337e-04
# Item_Identifier_FDS40              2.297892e-04
# Item_Identifier_NCA18              2.292293e-04
# Item_Identifier_FDA51              2.248873e-04
# Item_Identifier_FDT44              2.201476e-04
# Item_Identifier_NCR06              2.172226e-04
# Item_Identifier_DRH25              2.152694e-04
# Item_Identifier_FDA11              2.151418e-04
# Item_Identifier_FDM40              2.142468e-04
# Item_Identifier_FDT46              2.138704e-04
# Item_Identifier_FDM60              2.110953e-04
# Item_Identifier_FDC52              2.100658e-04
# Item_Identifier_FDV40              2.091578e-04
# Item_Identifier_FDR36              2.078648e-04
# Item_Identifier_FDL16              2.025646e-04
# Item_Identifier_NCB55              2.020840e-04
# Item_Identifier_DRJ59              2.010561e-04
# Item_Identifier_NCL41              2.000246e-04
# Item_Identifier_FDC58              1.989274e-04
# Item_Identifier_FDR14              1.949334e-04
# Item_Identifier_FDA13              1.945359e-04
# Item_Identifier_FDE41              1.929539e-04
# Item_Identifier_FDB26              1.928794e-04
# Item_Identifier_FDY20              1.922302e-04
# Item_Identifier_FDF38              1.912761e-04
# Item_Identifier_FDO33              1.881941e-04
# Item_Identifier_FDQ23              1.874768e-04
# Item_Identifier_FDN46              1.870781e-04
# Item_Identifier_NCP02              1.856395e-04
# Item_Identifier_DRD01              1.850878e-04
# Item_Identifier_FDE47              1.849111e-04
# Item_Identifier_DRL23              1.823445e-04
# Item_Identifier_FDQ47              1.821251e-04
# Item_Identifier_FDY52              1.815900e-04
# Item_Identifier_FDL12              1.812425e-04
# Item_Identifier_NCT30              1.784839e-04
# Item_Identifier_FDM46              1.781332e-04
# Item_Identifier_NCG18              1.780480e-04
# Item_Identifier_DRM49              1.756399e-04
# Item_Identifier_FDV16              1.745879e-04
# Item_Identifier_DRK12              1.731316e-04
# Item_Identifier_DRG11              1.711611e-04
# Item_Identifier_DRB48              1.676390e-04
# Item_Identifier_FDY36              1.662110e-04
# Item_Identifier_FDT36              1.600936e-04
# Item_Identifier_NCM42              1.595674e-04
# Item_Identifier_NCP17              1.591024e-04
# Item_Identifier_FDP31              1.589862e-04
# Item_Identifier_FDC21              1.585964e-04
# Item_Identifier_FDR43              1.572721e-04
# Item_Identifier_FDL15              1.555764e-04
# Item_Identifier_FDV34              1.549582e-04
# Item_Identifier_FDE56              1.525057e-04
# Item_Identifier_DRE15              1.516624e-04
# Item_Identifier_FDU39              1.501137e-04
# Item_Identifier_FDW59              1.496580e-04
# Item_Identifier_FDX59              1.483596e-04
# Item_Identifier_FDW38              1.474266e-04
# Item_Identifier_NCM30              1.427658e-04
# Item_Identifier_FDS23              1.418855e-04
# Item_Identifier_NCE31              1.403505e-04
# Item_Identifier_FDE35              1.377132e-04
# Item_Identifier_DRN59              1.370073e-04
# Item_Identifier_FDP04              1.369832e-04
# Item_Identifier_NCD42              1.346497e-04
# Item_Identifier_FDI05              1.336508e-04
# Item_Identifier_NCR18              1.331468e-04
# Item_Identifier_FDH28              1.325437e-04
# Item_Identifier_DRK01              1.323635e-04
# Item_Identifier_FDJ09              1.311768e-04
# Item_Identifier_FDW14              1.308233e-04
# Item_Identifier_DRK35              1.305370e-04
# Item_Identifier_FDV27              1.265890e-04
# Item_Identifier_FDX43              1.263575e-04
# Item_Identifier_DRC01              1.255579e-04
# Item_Identifier_FDT02              1.255020e-04
# Item_Identifier_FDK24              1.187298e-04
# Item_Identifier_FDS39              1.169710e-04
# Item_Identifier_FDU21              1.113852e-04
# Item_Identifier_FDL27              1.085772e-04
# Item_Identifier_FDX40              1.036609e-04
# Item_Identifier_FDK04              1.033790e-04
# Item_Identifier_FDC59              1.027537e-04
# Item_Identifier_FDQ31              1.025024e-04
# Item_Identifier_FDV56              1.024847e-04
# Item_Identifier_DRI37              9.745827e-05
# Item_Identifier_FDS21              9.593393e-05
# Item_Identifier_FDM02              9.567370e-05
# Item_Identifier_FDY12              9.557818e-05
# Item_Identifier_FDI27              9.352585e-05
# Item_Identifier_NCP55              9.312195e-05
# Item_Identifier_FDY48              9.189057e-05
# Item_Identifier_FDJ03              9.035991e-05
# Item_Identifier_FDU15              8.957353e-05
# Item_Identifier_FDT04              8.320639e-05
# Item_Identifier_FDZ27              8.166675e-05
# Item_Identifier_FDV43              8.000605e-05
# Item_Identifier_FDP13              7.936594e-05
# Item_Identifier_FDE44              7.623465e-05
# Item_Identifier_FDH45              7.608986e-05
# Item_Identifier_FDJ50              7.366341e-05
# Item_Identifier_FDD53              6.917858e-05
# Item_Identifier_FDO51              6.917080e-05
# Item_Identifier_FDG40              6.797055e-05
# Item_Identifier_NCD06              6.479374e-05
# Item_Identifier_NCZ05              6.326105e-05
# Item_Identifier_FDD28              6.110855e-05
# Item_Identifier_FDV10              5.733441e-05
# Item_Identifier_FDN49              5.620191e-05
# Item_Identifier_FDD16              5.275795e-05
# Item_Identifier_DRI49              5.060459e-05
# Item_Identifier_FDY40              5.004750e-05
# Item_Identifier_FDD51              4.914550e-05
# Item_Identifier_FDY11              4.840356e-05
# Item_Identifier_FDH04              4.742280e-05
# Item_Identifier_FDV14              4.667327e-05
# Item_Identifier_FDU27              4.212801e-05
# Item_Identifier_FDS14              4.202677e-05
# Item_Identifier_FDX38              4.121650e-05
# Item_Identifier_FDW58              4.104969e-05
# Item_Identifier_FDP36              3.947008e-05
# Item_Identifier_FDL21              3.568317e-05
# Item_Identifier_FDH52              3.085137e-05
# Item_Identifier_FDG22              3.037511e-05
# Item_Identifier_NCV42              2.593484e-05
# Item_Identifier_NCO02              2.581814e-05
# Item_Identifier_DRG27              2.438819e-05
# Item_Identifier_FDT39              2.229692e-05
# Item_Identifier_FDB41              2.071087e-05
# Item_Identifier_FDL28              1.977279e-05
# Item_Identifier_FDU48              1.746652e-05
# Item_Identifier_FDW23              1.676862e-05
# Item_Identifier_NCO14              1.316533e-05
# Item_Identifier_FDS22              6.449924e-06
# Item_Identifier_DRH59              3.272422e-06
# Item_Identifier_FDT51              2.215637e-06
# Item_Identifier_DRL59              1.979779e-06
# Item_Identifier_FDQ60              1.075860e-06
# Item_Identifier_FDQ04              8.363730e-07
# Item_Identifier_FDG12              4.487945e-07
# dtype: float64

# %%
feature_importance_df = pd.DataFrame(ran_for_pipe.named_steps['randomforestregressor'].feature_importances_,
                                   index = final_cols,  
                                   columns=['Feature Importance']).sort_values('Feature Importance', 
                                   ascending=False)

# %%
feature_importance_df.style.format({"Feature Importance":  "{:.2%}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_cd634">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cd634_level0_col0" class="col_heading level0 col0" >Feature Importance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cd634_level0_row0" class="row_heading level0 row0" >Item_MRP</th>
#       <td id="T_cd634_row0_col0" class="data row0 col0" >40.05%</td>
#     </tr>
#     <tr>
#       <th id="T_cd634_level0_row1" class="row_heading level0 row1" >Outlet_Type_Grocery Store</th>
#       <td id="T_cd634_row1_col0" class="data row1 col0" >19.17%</td>
#     </tr>
#     <tr>
#       <th id="T_cd634_level0_row2" class="row_heading level0 row2" >Item_Visibility</th>
#       <td id="T_cd634_row2_col0" class="data row2 col0" >5.62%</td>
#     </tr>
#     <tr>
#       <th id="T_cd634_level0_row3" class="row_heading level0 row3" >Item_Weight</th>
#       <td id="T_cd634_row3_col0" class="data row3 col0" >3.98%</td>
#     </tr>
#     <tr>
#       <th id="T_cd634_level0_row4" class="row_heading level0 row4" >Outlet_Type_Supermarket Type3</th>
#       <td id="T_cd634_row4_col0" class="data row4 col0" >3.82%</td>
#     </tr>
#     <tr>
#       <th id="T_cd634_level0_row5" class="row_heading level0 row5" >Outlet_Identifier_OUT027</th>
#       <td id="T_cd634_row5_col0" class="data row5 col0" >2.72%</td>
#     </tr>
#     <tr>
#       <th id="T_cd634_level0_row6" class="row_heading level0 row6" >Outlet_Establishment_Year</th>
#       <td id="T_cd634_row6_col0" class="data row6 col0" >2.32%</td>
#     </tr>
#     <tr>
#       <th id="T_cd634_level0_row7" class="row_heading level0 row7" >Item_Type_Snack Foods</th>
#       <td id="T_cd634_row7_col0" class="data row7 col0" >0.38%</td>
#     </tr>
#     <tr>
#       <th id="T_cd634_level0_row8" class="row_heading level0 row8" >Item_Type_Fruits and Vegetables</th>
#       <td id="T_cd634_row8_col0" class="data row8 col0" >0.36%</td>
#     </tr>
#     <tr>
#       <th id="T_cd634_level0_row9" class="row_heading level0 row9" >Outlet_Identifier_OUT035</th>
#       <td id="T_cd634_row9_col0" class="data row9 col0" >0.36%</td>
#     </tr>
#     <tr>
#       <th id="T_cd634_level0_row10" class="row_heading level0 row10" >Outlet_Identifier_OUT045</th>
#       <td id="T_cd634_row10_col0" class="data row10 col0" >0.35%</td>
#     </tr>
#     <tr>
#       <th id="T_cd634_level0_row11" class="row_heading level0 row11" >Outlet_Size_Small</th>
#       <td id="T_cd634_row11_col0" class="data row11 col0" >0.35%</td>
#     </tr>
#     <tr>
#       <th id="T_cd634_level0_row12" class="row_heading level0 row12" >Item_Type_Frozen Foods</th>
#       <td id="T_cd634_row12_col0" class="data row12 col0" >0.31%</td>
#     </tr>
#     <tr>
#       <th id="T_cd634_level0_row13" class="row_heading level0 row13" >Outlet_Identifier_OUT046</th>
#       <td id="T_cd634_row13_col0" class="data row13 col0" >0.30%</td>
#     </tr>
#     <tr>
#       <th id="T_cd634_level0_row14" class="row_heading level0 row14" >Item_Type_Household</th>
#       <td id="T_cd634_row14_col0" class="data row14 col0" >0.29%</td>
#     </tr>
#     <tr>
#       <th id="T_cd634_level0_row15" class="row_heading level0 row15" >Outlet_Location_Type_Tier 1</th>
#       <td id="T_cd634_row15_col0" class="data row15 col0" >0.28%</td>
#     </tr>
#     <tr>
#       <th id="T_cd634_level0_row16" class="row_heading level0 row16" >Item_Type_Dairy</th>
#       <td id="T_cd634_row16_col0" class="data row16 col0" >0.28%</td>
#     </tr>
#     <tr>
#       <th id="T_cd634_level0_row17" class="row_heading level0 row17" >Outlet_Size_Medium</th>
#       <td id="T_cd634_row17_col0" class="data row17 col0" >0.28%</td>
#     </tr>
#     <tr>
#       <th id="T_cd634_level0_row18" class="row_heading level0 row18" >Item_Fat_Content_Low Fat</th>
#       <td id="T_cd634_row18_col0" class="data row18 col0" >0.28%</td>
#     </tr>
#     <tr>
#       <th id="T_cd634_level0_row19" class="row_heading level0 row19" >Outlet_Location_Type_Tier 2</th>
#       <td id="T_cd634_row19_col0" class="data row19 col0" >0.28%</td>
#     </tr>
#     <tr>
#       <th id="T_cd634_level0_row20" class="row_heading level0 row20" >Outlet_Identifier_OUT017</th>
#       <td id="T_cd634_row20_col0" class="data row20 col0" >0.27%</td>
#     </tr>
#     <tr>
#       <th id="T_cd634_level0_row21" class="row_heading level0 row21" >Outlet_Size_Unknown</th>
#       <td id="T_cd634_row21_col0" class="data row21 col0" >0.27%</td>
#     </tr>
#     <tr>
#       <th id="T_cd634_level0_row22" class="row_heading level0 row22" >Outlet_Identifier_OUT049</th>
#       <td id="T_cd634_row22_col0" class="data row22 col0" >0.26%</td>
#     </tr>
#     <tr>
#       <th id="T_cd634_level0_row23" class="row_heading level0 row23" >Item_Fat_Content_Regular</th>
#       <td id="T_cd634_row23_col0" class="data row23 col0" >0.26%</td>
#     </tr>
#     <tr>
#       <th id="T_cd634_level0_row24" class="row_heading level0 row24" >Outlet_Location_Type_Tier 3</th>
#       <td id="T_cd634_row24_col0" class="data row24 col0" >0.24%</td>
#     </tr>
#     <tr>
#       <th id="T_cd634_level0_row25" class="row_heading level0 row25" >Item_Identifier_FDQ19</th>
#       <td id="T_cd634_row25_col0" class="data row25 col0" >0.23%</td>
#     </tr>
#     <tr>
#       <th id="T_cd634_level0_row26" class="row_heading level0 row26" >Item_Type_Soft Drinks</th>
#       <td id="T_cd634_row26_col0" class="data row26 col0" >0.22%</td>
#     </tr>
#     <tr>
#       <th id="T_cd634_level0_row27" class="row_heading level0 row27" >Item_Type_Canned</th>
#       <td id="T_cd634_row27_col0" class="data row27 col0" >0.20%</td>
#     </tr>
#     <tr>
#       <th id="T_cd634_level0_row28" class="row_heading level0 row28" >Item_Identifier_NCE42</th>
#       <td id="T_cd634_row28_col0" class="data row28 col0" >0.19%</td>
#     </tr>
#     <tr>
#       <th id="T_cd634_level0_row29" class="row_heading level0 row29" >Item_Type_Baking Goods</th>
#       <td id="T_cd634_row29_col0" class="data row29 col0" >0.18%</td>
#     </tr>
#     <tr>
#       <th id="T_cd634_level0_row30" class="row_heading level0 row30" >Item_Type_Starchy Foods</th>
#       <td id="T_cd634_row30_col0" class="data row30 col0" >0.18%</td>
#     </tr>
#     <tr>
#       <th id="T_cd634_level0_row31" class="row_heading level0 row31" >Outlet_Size_High</th>
#       <td id="T_cd634_row31_col0" class="data row31 col0" >0.17%</td>
#     </tr>
#     <tr>
#       <th id="T_cd634_level0_row32" class="row_heading level0 row32" >Item_Type_Health and Hygiene</th>
#       <td id="T_cd634_row32_col0" class="data row32 col0" >0.17%</td>
#     </tr>
#     <tr>
#       <th id="T_cd634_level0_row33" class="row_heading level0 row33" >Item_Type_Hard Drinks</th>
#       <td id="T_cd634_row33_col0" class="data row33 col0" >0.17%</td>
#     </tr>
#     <tr>
#       <th id="T_cd634_level0_row34" class="row_heading level0 row34" >Item_Identifier_FDZ20</th>
#       <td id="T_cd634_row34_col0" class="data row34 col0" >0.17%</td>
#     </tr>
#     <tr>
#       <th id="T_cd634_level0_row35" class="row_heading level0 row35" >Item_Type_Meat</th>
#       <td id="T_cd634_row35_col0" class="data row35 col0" >0.16%</td>
#     </tr>
#     <tr>
#       <th id="T_cd634_level0_row36" class="row_heading level0 row36" >Outlet_Type_Supermarket Type1</th>
#       <td id="T_cd634_row36_col0" class="data row36 col0" >0.16%</td>
#     </tr>
#     <tr>
#       <th id="T_cd634_level0_row37" class="row_heading level0 row37" >Item_Type_Breakfast</th>
#       <td id="T_cd634_row37_col0" class="data row37 col0" >0.16%</td>
#     </tr>
#     <tr>
#       <th id="T_cd634_level0_row38" class="row_heading level0 row38" >Outlet_Identifier_OUT013</th>
#       <td id="T_cd634_row38_col0" class="data row38 col0" >0.16%</td>
#     </tr>
#     <tr>
#       <th id="T_cd634_level0_row39" class="row_heading level0 row39" >Item_Identifier_FDF39</th>
#       <td id="T_cd634_row39_col0" class="data row39 col0" >0.15%</td>
#     </tr>
#     <tr>
#       <th id="T_cd634_level0_row40" class="row_heading level0 row40" >Item_Identifier_FDR45</th>
#       <td id="T_cd634_row40_col0" class="data row40 col0" >0.14%</td>
#     </tr>
#     <tr>
#       <th id="T_cd634_level0_row41" class="row_heading level0 row41" >Item_Identifier_NCM05</th>
#       <td id="T_cd634_row41_col0" class="
